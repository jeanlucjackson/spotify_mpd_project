# %% [markdown]
# # Parsing Spotify's MPD Dataset
# The MPD dataset is provided as slices, in JSON format. The parsing and preparing process includes:
#
# 1. Convert JSON slices to CSV slices. Outputs (XXXX's signify the slice #):
#     * `mpd_playlists_XXXX-XXXX.csv`
#     * `mpd_tracks_XXXX-XXXX.csv`
# 2. De-duplicate `mpd_tracks_XXXX-XXXX.csv` and save as `unique_mpd_tracks.csv`

# %%
import numpy as np
import pandas as pd
import os
import json
import csv

# %% [markdown]
# NOTE: Make sure that the `spotify_million_playlist_dataset` and its `data` directory are located in the parent folder before proceeding. Otherwise, update the `path` below.

# %%
# Input directory
path = "../spotify_million_playlist_dataset/data/"
mpd_filepath = os.path.relpath(path)
print('Input directory:')
print(mpd_filepath)
# Out:
# Input directory:
# ../spotify_million_playlist_dataset/data

# %%
# Output directories

# Base output directory
path = '../data'
output_filepath_root = os.path.relpath(path)

# Output playlists into playlists directory
playlist_output = os.path.join(output_filepath_root, 'playlists')

# Output tracks into tracks directory
track_output = os.path.join(output_filepath_root, 'tracks')

print('Output directories:')
print(output_filepath_root)
print(playlist_output)
print(track_output)
# Out:
# Output directories:
# ../data
# ../data/playlists
# ../data/tracks

# %% [markdown]
# # 1. Convert JSON slices to CSV slices

# %% [markdown]
# ### JSON to CSV Parsing Function

# %%
def parse_spotify_mpd_json_to_csv(input_filepath, output_filepaths, playlist_csv_name, tracks_csv_name, tracks_per_playlist=15):
    """Parse through Spotify's Million Playlist Dataset (MPD) JSON slice file and produce the following CSV files:
    
        - {playlist_csv_name}.csv
        - {tracks_csv_name}.csv
        
        * Note: '.csv' suffice not required in argument string.
        
        
    The MPD JSON has a *PLAYLIST* field for each playlist row. The *INFO* field is ignored for each slice file.
    
    The JSON is structured in the following format:
    
        ### `info` Field (THE INFO FIELD IS IGNORED)
        

        ### `playlists` field 
        This is an array that typically contains 1,000 playlists. Each playlist is a dictionary that contains the following fields:

            * ***pid*** - integer - playlist id - the MPD ID of this playlist.
            * ***name*** - string - the name of the playlist 
            * ***description*** - optional string - if present, the description given to the playlist.
            * ***modified_at*** - seconds - timestamp (in seconds since the epoch) when this playlist was last updated.
            * ***num_artists*** - the total number of unique artists for the tracks in the playlist.
            * ***num_albums*** - the number of unique albums for the tracks in the playlist
            * ***num_tracks*** - the number of tracks in the playlist
            * ***num_followers*** - the number of followers this playlist had at the time the MPD was created.
            * ***num_edits*** - the number of separate editing sessions.
            * ***duration_ms*** - the total duration of all the tracks in the playlist (in milliseconds)
            * ***collaborative*** -  boolean - if true, the playlist is a collaborative playlist. 
            * ***tracks*** - an array of information about each track in the playlist. Each element is a dictionary with:
               * ***track_name*** - the name of the track
               * ***track_uri*** - the Spotify URI of the track
               * ***album_name*** - the name of the track's album
               * ***album_uri*** - the Spotify URI of the album
               * ***artist_name*** - the name of the track's primary artist
               * ***artist_uri*** - the Spotify URI of track's primary artist
               * ***duration_ms*** - the duration of the track in milliseconds
               * ***pos*** - the position of the track in the playlist (zero-based)
        
    
    This function does not further process the rows, it simply converts the JSON to CSVs.
    Rows are not sorted, duplicates are not removed.
    
    """
    
    # Load JSON from provided filepath
    j = ''
    with open(input_filepath, 'r') as file:
        j = json.load(file)
        
    # Lists to gather from nested JSON
    playlists_json_list = []
    tracks_json_list = []
    
    # MPD JSON structure has PLAYLISTs as outermost dictionary
    # Step through PLAYLISTs
    for playlist in j['playlists']:
        
        # -- Create this playlist's playlist row as JSON for CSV creation
        playlist_json = {}
        playlist_json['pid'] = playlist['pid']
        playlist_json['name'] = playlist['name']

        # Description is an optional field
        if 'description' in playlist:
            playlist_json['description'] = playlist['description']
        else:
            playlist_json['description'] = ''
            
        playlist_json['modified_at'] = playlist['modified_at']
        playlist_json['num_artists'] = playlist['num_artists']
        playlist_json['num_albums'] = playlist['num_albums']
        playlist_json['num_tracks'] = playlist['num_tracks']
        playlist_json['num_followers'] = playlist['num_followers']
        playlist_json['num_edits'] = playlist['num_edits']
        playlist_json['duration_ms'] = playlist['duration_ms']
        playlist_json['collaborative'] = playlist['collaborative']
        
        playlists_json_list.append(playlist_json)
        
        
        # -- Creating tracks csv
        # Each playlist has any number of tracks.
        # Use the *PID* to affiliate tracks with playlists
        
        # -- Saving tracks for each playlist
        # Add n tracks as features to the playlist csv
        # Where n is the input tracks_per_playlist
        # Format: track_1_uri, track_2_uri,...
        #         track_1_album_uri
        #         track_1_artist_uri
        #
        # Use padding where track does not exist (only 5 tracks in playlist when we want 15)

        track_counter = 1
        
        for track in playlist['tracks']:
            
            if track_counter <= tracks_per_playlist:
                
                # Track URI
                track_feature_name = 'track_' + str(track_counter) + '_uri'
                playlist_json[track_feature_name] = track['track_uri']
                
                # Album URI
                album_feature_name = 'track_' + str(track_counter) + '_album_uri'
                playlist_json[album_feature_name] = track['album_uri']
                
                # Arist URI
                artist_feature_name = 'track_' + str(track_counter) + '_artist_uri'
                playlist_json[artist_feature_name] = track['artist_uri']
            
            track_counter += 1

            # Create tracks CSV
            tracks_json = {}
            tracks_json['pid'] = playlist['pid']
            tracks_json['track_name'] = track['track_name']
            tracks_json['track_uri'] = track['track_uri']
            tracks_json['album_name'] = track['album_name']
            tracks_json['album_uri'] = track['album_uri']
            tracks_json['artist_name'] = track['artist_name']
            tracks_json['artist_uri'] = track['artist_uri']
            tracks_json['duration_ms'] = track['duration_ms']
            tracks_json['pos'] = track['pos']
            
            tracks_json_list.append(tracks_json)
            
        # Check if there weren't enough tracks and we need to add padding
        while track_counter <= tracks_per_playlist:
            # Resume track_counter, but now we assign '0' values
            # Track URI
            track_feature_name = 'track_' + str(track_counter) + '_uri'
            playlist_json[track_feature_name] = 0

            # Album URI
            album_feature_name = 'track_' + str(track_counter) + '_album_uri'
            playlist_json[album_feature_name] = 0

            # Arist URI
            artist_feature_name = 'track_' + str(track_counter) + '_artist_uri'
            playlist_json[artist_feature_name] = 0
            
            track_counter += 1
            
#         diff = tracks_per_playlist - len(playlist['tracks'])
#         if diff > 0:
#             resume_numbering = tracks_per_playlist - diff
            
            
            

    # Now that we've parsed through the JSON, save data to CSV
    
    # mpd_playlists.csv
    with open(f"{output_filepaths[0]}/{playlist_csv_name}.csv", 'w') as file:
        dw = csv.DictWriter(file, playlists_json_list[0].keys())
        dw.writeheader()
        dw.writerows(playlists_json_list)
        print(f"{playlist_csv_name}.csv saved to {output_filepaths[0]}")
    
    # mpd_tracks.csv
    with open(f"{output_filepaths[1]}/{tracks_csv_name}.csv", 'w') as file:
        dw = csv.DictWriter(file, tracks_json_list[0].keys())
        dw.writeheader()
        dw.writerows(tracks_json_list)
        print(f"{tracks_csv_name}.csv saved to {output_filepaths[1]}")

# %% [markdown]
# ## Run Parser (User Input)
# If parsing was interrupted or you'd like to freshly parse the raw data for any reason, we begin by deleted any existing files from the `playlists` and `tracks` output directories.

# %%
# Prompt user if files are already found in the cleaned data directories

if len(os.listdir(playlist_output)) > 0 or len(os.listdir(track_output)) > 0:
    if input("Files detected in output directories. Shall I delete them for you? (Y/N) ").lower() == 'y':
        for file in os.listdir(playlist_output):
            path = os.path.join(playlist_output, file)
            
            try:
                os.remove(path)
            except OSError as e:
                print("Error: %s : %s" % (file, e.strerror))
        print(f'Playlist data files deleted from {playlist_output}.')
            
        for file in os.listdir(track_output):
            path = os.path.join(track_output, file)
            
            try:
                os.remove(path)
            except OSError as e:
                print("Error: %s : %s" % (path, e.strerror))
                
        print(f'Track data files deleted from {track_output}.')
        
    else:
        print("No files were deleted.")
else:
    print("No files detected in output folders. You're ready to parse the raw data.")
# Out:
# Files detected in output directories. Shall I delete them for you? (Y/N)  y
# Playlist data files deleted from ../data/playlists.
# Track data files deleted from ../data/tracks.

# %% [markdown]
# # 2. Convert Playlists

# %%
# ------ WARNING!
# This cell can take a while to run (~10 mins)

# Input for number of tracks to include as features for each playlist
num_tracks = 15

# Begin parsing JSON files
print('\nParsing JSONs...\n')
length = len(os.listdir(mpd_filepath))

for ii,ff in enumerate(os.listdir(mpd_filepath)):
    print(f"Slice {ii + 1} of {length}: {ff}")
    suffix = str(ff.split('.')[-2])
    parse_spotify_mpd_json_to_csv(input_filepath=os.path.join(mpd_filepath, ff),
                                  output_filepaths=[playlist_output, track_output],
                                  playlist_csv_name='mpd_playlists_' + suffix,
                                  tracks_csv_name='mpd_tracks_' + suffix,
                                  tracks_per_playlist=num_tracks)
    print()
# Out:
# Parsing JSONs...
#
# Slice 1 of 1000: mpd.slice.549000-549999.json
# mpd_playlists_549000-549999.csv saved to ../data/playlists
# mpd_tracks_549000-549999.csv saved to ../data/tracks
#
# Slice 2 of 1000: mpd.slice.613000-613999.json
# mpd_playlists_613000-613999.csv saved to ../data/playlists
# mpd_tracks_613000-613999.csv saved to ../data/tracks
#
# Slice 3 of 1000: mpd.slice.115000-115999.json
# mpd_playlists_115000-115999.csv saved to ../data/playlists
# mpd_tracks_115000-115999.csv saved to ../data/tracks
#
# Slice 4 of 1000: mpd.slice.778000-778999.json
# mpd_playlists_778000-778999.csv saved to ../data/playlists
# mpd_tracks_778000-778999.csv saved to ../data/tracks
#
# Slice 5 of 1000: mpd.slice.290000-290999.json
# mpd_playlists_290000-290999.csv saved to ../data/playlists
# mpd_tracks_290000-290999.csv saved to ../data/tracks
#
# Slice 6 of 1000: mpd.slice.596000-596999.json
# mpd_playlists_596000-596999.csv saved to ../data/playlists
# mpd_tracks_596000-596999.csv saved to ../data/tracks
#
# Slice 7 of 1000: mpd.slice.324000-324999.json
# mpd_playlists_324000-324999.csv saved to ../data/playlists
# mpd_tracks_324000-324999.csv saved to ../data/tracks
#
# Slice 8 of 1000: mpd.slice.422000-422999.json
# mpd_playlists_422000-422999.csv saved to ../data/playlists
# mpd_tracks_422000-422999.csv saved to ../data/tracks
#
# Slice 9 of 1000: mpd.slice.974000-974999.json
# mpd_playlists_974000-974999.csv saved to ../data/playlists
# mpd_tracks_974000-974999.csv saved to ../data/tracks
#
# Slice 10 of 1000: mpd.slice.679000-679999.json
# mpd_playlists_679000-679999.csv saved to ../data/playlists
# mpd_tracks_679000-679999.csv saved to ../data/tracks
#
# Slice 11 of 1000: mpd.slice.7000-7999.json
# mpd_playlists_7000-7999.csv saved to ../data/playlists
# mpd_tracks_7000-7999.csv saved to ../data/tracks
#
# Slice 12 of 1000: mpd.slice.391000-391999.json
# mpd_playlists_391000-391999.csv saved to ../data/playlists
# mpd_tracks_391000-391999.csv saved to ../data/tracks
#
# Slice 13 of 1000: mpd.slice.497000-497999.json
# mpd_playlists_497000-497999.csv saved to ../data/playlists
# mpd_tracks_497000-497999.csv saved to ../data/tracks
#
# Slice 14 of 1000: mpd.slice.225000-225999.json
# mpd_playlists_225000-225999.csv saved to ../data/playlists
# mpd_tracks_225000-225999.csv saved to ../data/tracks
#
# Slice 15 of 1000: mpd.slice.523000-523999.json
# mpd_playlists_523000-523999.csv saved to ../data/playlists
# mpd_tracks_523000-523999.csv saved to ../data/tracks
#
# Slice 16 of 1000: mpd.slice.875000-875999.json
# mpd_playlists_875000-875999.csv saved to ../data/playlists
# mpd_tracks_875000-875999.csv saved to ../data/tracks
#
# Slice 17 of 1000: mpd.slice.448000-448999.json
# mpd_playlists_448000-448999.csv saved to ../data/playlists
# mpd_tracks_448000-448999.csv saved to ../data/tracks
#
# Slice 18 of 1000: mpd.slice.712000-712999.json
# mpd_playlists_712000-712999.csv saved to ../data/playlists
# mpd_tracks_712000-712999.csv saved to ../data/tracks
#
# Slice 19 of 1000: mpd.slice.193000-193999.json
# mpd_playlists_193000-193999.csv saved to ../data/playlists
# mpd_tracks_193000-193999.csv saved to ../data/tracks
#
# Slice 20 of 1000: mpd.slice.38000-38999.json
# mpd_playlists_38000-38999.csv saved to ../data/playlists
# mpd_tracks_38000-38999.csv saved to ../data/tracks
#
# Slice 21 of 1000: mpd.slice.695000-695999.json
# mpd_playlists_695000-695999.csv saved to ../data/playlists
# mpd_tracks_695000-695999.csv saved to ../data/tracks
#
# Slice 22 of 1000: mpd.slice.899000-899999.json
# mpd_playlists_899000-899999.csv saved to ../data/playlists
# mpd_tracks_899000-899999.csv saved to ../data/tracks
#
# Slice 23 of 1000: mpd.slice.721000-721999.json
# mpd_playlists_721000-721999.csv saved to ../data/playlists
# mpd_tracks_721000-721999.csv saved to ../data/tracks
#
# Slice 24 of 1000: mpd.slice.510000-510999.json
# mpd_playlists_510000-510999.csv saved to ../data/playlists
# mpd_tracks_510000-510999.csv saved to ../data/tracks
#
# Slice 25 of 1000: mpd.slice.846000-846999.json
# mpd_playlists_846000-846999.csv saved to ../data/playlists
# mpd_tracks_846000-846999.csv saved to ../data/tracks
#
# Slice 26 of 1000: mpd.slice.216000-216999.json
# mpd_playlists_216000-216999.csv saved to ../data/playlists
# mpd_tracks_216000-216999.csv saved to ../data/tracks
#
# Slice 27 of 1000: mpd.slice.411000-411999.json
# mpd_playlists_411000-411999.csv saved to ../data/playlists
# mpd_tracks_411000-411999.csv saved to ../data/tracks
#
# Slice 28 of 1000: mpd.slice.947000-947999.json
# mpd_playlists_947000-947999.csv saved to ../data/playlists
# mpd_tracks_947000-947999.csv saved to ../data/tracks
#
# Slice 29 of 1000: mpd.slice.317000-317999.json
# mpd_playlists_317000-317999.csv saved to ../data/playlists
# mpd_tracks_317000-317999.csv saved to ../data/tracks
#
# Slice 30 of 1000: mpd.slice.22000-22999.json
# mpd_playlists_22000-22999.csv saved to ../data/playlists
# mpd_tracks_22000-22999.csv saved to ../data/tracks
#
# Slice 31 of 1000: mpd.slice.794000-794999.json
# mpd_playlists_794000-794999.csv saved to ../data/playlists
# mpd_tracks_794000-794999.csv saved to ../data/tracks
#
# Slice 32 of 1000: mpd.slice.126000-126999.json
# mpd_playlists_126000-126999.csv saved to ../data/playlists
# mpd_tracks_126000-126999.csv saved to ../data/tracks
#
# Slice 33 of 1000: mpd.slice.998000-998999.json
# mpd_playlists_998000-998999.csv saved to ../data/playlists
# mpd_tracks_998000-998999.csv saved to ../data/tracks
#
# Slice 34 of 1000: mpd.slice.620000-620999.json
# mpd_playlists_620000-620999.csv saved to ../data/playlists
# mpd_tracks_620000-620999.csv saved to ../data/tracks
#
# Slice 35 of 1000: mpd.slice.3000-3999.json
# mpd_playlists_3000-3999.csv saved to ../data/playlists
# mpd_tracks_3000-3999.csv saved to ../data/tracks
#
# Slice 36 of 1000: mpd.slice.70000-70999.json
# mpd_playlists_70000-70999.csv saved to ../data/playlists
# mpd_tracks_70000-70999.csv saved to ../data/tracks
#
# Slice 37 of 1000: mpd.slice.597000-597999.json
# mpd_playlists_597000-597999.csv saved to ../data/playlists
# mpd_tracks_597000-597999.csv saved to ../data/tracks
#
# Slice 38 of 1000: mpd.slice.291000-291999.json
# mpd_playlists_291000-291999.csv saved to ../data/playlists
# mpd_tracks_291000-291999.csv saved to ../data/tracks
#
# Slice 39 of 1000: mpd.slice.779000-779999.json
# mpd_playlists_779000-779999.csv saved to ../data/playlists
# mpd_tracks_779000-779999.csv saved to ../data/tracks
#
# Slice 40 of 1000: mpd.slice.423000-423999.json
# mpd_playlists_423000-423999.csv saved to ../data/playlists
# mpd_tracks_423000-423999.csv saved to ../data/tracks
#
# Slice 41 of 1000: mpd.slice.975000-975999.json
# mpd_playlists_975000-975999.csv saved to ../data/playlists
# mpd_tracks_975000-975999.csv saved to ../data/tracks
#
# Slice 42 of 1000: mpd.slice.325000-325999.json
# mpd_playlists_325000-325999.csv saved to ../data/playlists
# mpd_tracks_325000-325999.csv saved to ../data/tracks
#
# Slice 43 of 1000: mpd.slice.548000-548999.json
# mpd_playlists_548000-548999.csv saved to ../data/playlists
# mpd_tracks_548000-548999.csv saved to ../data/tracks
#
# Slice 44 of 1000: mpd.slice.114000-114999.json
# mpd_playlists_114000-114999.csv saved to ../data/playlists
# mpd_tracks_114000-114999.csv saved to ../data/tracks
#
# Slice 45 of 1000: mpd.slice.612000-612999.json
# mpd_playlists_612000-612999.csv saved to ../data/playlists
# mpd_tracks_612000-612999.csv saved to ../data/tracks
#
# Slice 46 of 1000: mpd.slice.449000-449999.json
# mpd_playlists_449000-449999.csv saved to ../data/playlists
# mpd_tracks_449000-449999.csv saved to ../data/tracks
#
# Slice 47 of 1000: mpd.slice.713000-713999.json
# mpd_playlists_713000-713999.csv saved to ../data/playlists
# mpd_tracks_713000-713999.csv saved to ../data/tracks
#
# Slice 48 of 1000: mpd.slice.496000-496999.json
# mpd_playlists_496000-496999.csv saved to ../data/playlists
# mpd_tracks_496000-496999.csv saved to ../data/tracks
#
# Slice 49 of 1000: mpd.slice.390000-390999.json
# mpd_playlists_390000-390999.csv saved to ../data/playlists
# mpd_tracks_390000-390999.csv saved to ../data/tracks
#
# Slice 50 of 1000: mpd.slice.678000-678999.json
# mpd_playlists_678000-678999.csv saved to ../data/playlists
# mpd_tracks_678000-678999.csv saved to ../data/tracks
#
# Slice 51 of 1000: mpd.slice.522000-522999.json
# mpd_playlists_522000-522999.csv saved to ../data/playlists
# mpd_tracks_522000-522999.csv saved to ../data/tracks
#
# Slice 52 of 1000: mpd.slice.874000-874999.json
# mpd_playlists_874000-874999.csv saved to ../data/playlists
# mpd_tracks_874000-874999.csv saved to ../data/tracks
#
# Slice 53 of 1000: mpd.slice.224000-224999.json
# mpd_playlists_224000-224999.csv saved to ../data/playlists
# mpd_tracks_224000-224999.csv saved to ../data/tracks
#
# Slice 54 of 1000: mpd.slice.81000-81999.json
# mpd_playlists_81000-81999.csv saved to ../data/playlists
# mpd_tracks_81000-81999.csv saved to ../data/tracks
#
# Slice 55 of 1000: mpd.slice.217000-217999.json
# mpd_playlists_217000-217999.csv saved to ../data/playlists
# mpd_tracks_217000-217999.csv saved to ../data/tracks
#
# Slice 56 of 1000: mpd.slice.511000-511999.json
# mpd_playlists_511000-511999.csv saved to ../data/playlists
# mpd_tracks_511000-511999.csv saved to ../data/tracks
#
# Slice 57 of 1000: mpd.slice.847000-847999.json
# mpd_playlists_847000-847999.csv saved to ../data/playlists
# mpd_tracks_847000-847999.csv saved to ../data/tracks
#
# Slice 58 of 1000: mpd.slice.694000-694999.json
# mpd_playlists_694000-694999.csv saved to ../data/playlists
# mpd_tracks_694000-694999.csv saved to ../data/tracks
#
# Slice 59 of 1000: mpd.slice.192000-192999.json
# mpd_playlists_192000-192999.csv saved to ../data/playlists
# mpd_tracks_192000-192999.csv saved to ../data/tracks
#
# Slice 60 of 1000: mpd.slice.720000-720999.json
# mpd_playlists_720000-720999.csv saved to ../data/playlists
# mpd_tracks_720000-720999.csv saved to ../data/tracks
#
# Slice 61 of 1000: mpd.slice.898000-898999.json
# mpd_playlists_898000-898999.csv saved to ../data/playlists
# mpd_tracks_898000-898999.csv saved to ../data/tracks
#
# Slice 62 of 1000: mpd.slice.54000-54999.json
# mpd_playlists_54000-54999.csv saved to ../data/playlists
# mpd_tracks_54000-54999.csv saved to ../data/tracks
#
# Slice 63 of 1000: mpd.slice.795000-795999.json
# mpd_playlists_795000-795999.csv saved to ../data/playlists
# mpd_tracks_795000-795999.csv saved to ../data/tracks
#
# Slice 64 of 1000: mpd.slice.621000-621999.json
# mpd_playlists_621000-621999.csv saved to ../data/playlists
# mpd_tracks_621000-621999.csv saved to ../data/tracks
#
# Slice 65 of 1000: mpd.slice.999000-999999.json
# mpd_playlists_999000-999999.csv saved to ../data/playlists
# mpd_tracks_999000-999999.csv saved to ../data/tracks
#
# Slice 66 of 1000: mpd.slice.127000-127999.json
# mpd_playlists_127000-127999.csv saved to ../data/playlists
# mpd_tracks_127000-127999.csv saved to ../data/tracks
#
# Slice 67 of 1000: mpd.slice.316000-316999.json
# mpd_playlists_316000-316999.csv saved to ../data/playlists
# mpd_tracks_316000-316999.csv saved to ../data/tracks
#
# Slice 68 of 1000: mpd.slice.410000-410999.json
# mpd_playlists_410000-410999.csv saved to ../data/playlists
# mpd_tracks_410000-410999.csv saved to ../data/tracks
#
# Slice 69 of 1000: mpd.slice.946000-946999.json
# mpd_playlists_946000-946999.csv saved to ../data/playlists
# mpd_tracks_946000-946999.csv saved to ../data/tracks
#
# Slice 70 of 1000: mpd.slice.227000-227999.json
# mpd_playlists_227000-227999.csv saved to ../data/playlists
# mpd_tracks_227000-227999.csv saved to ../data/tracks
#
# Slice 71 of 1000: mpd.slice.84000-84999.json
# mpd_playlists_84000-84999.csv saved to ../data/playlists
# mpd_tracks_84000-84999.csv saved to ../data/tracks
#
# Slice 72 of 1000: mpd.slice.877000-877999.json
# mpd_playlists_877000-877999.csv saved to ../data/playlists
# mpd_tracks_877000-877999.csv saved to ../data/tracks
#
# Slice 73 of 1000: mpd.slice.521000-521999.json
# mpd_playlists_521000-521999.csv saved to ../data/playlists
# mpd_tracks_521000-521999.csv saved to ../data/tracks
#
# Slice 74 of 1000: mpd.slice.393000-393999.json
# mpd_playlists_393000-393999.csv saved to ../data/playlists
# mpd_tracks_393000-393999.csv saved to ../data/tracks
#
# Slice 75 of 1000: mpd.slice.495000-495999.json
# mpd_playlists_495000-495999.csv saved to ../data/playlists
# mpd_tracks_495000-495999.csv saved to ../data/tracks
#
# Slice 76 of 1000: mpd.slice.710000-710999.json
# mpd_playlists_710000-710999.csv saved to ../data/playlists
# mpd_tracks_710000-710999.csv saved to ../data/tracks
#
# Slice 77 of 1000: mpd.slice.611000-611999.json
# mpd_playlists_611000-611999.csv saved to ../data/playlists
# mpd_tracks_611000-611999.csv saved to ../data/tracks
#
# Slice 78 of 1000: mpd.slice.117000-117999.json
# mpd_playlists_117000-117999.csv saved to ../data/playlists
# mpd_tracks_117000-117999.csv saved to ../data/tracks
#
# Slice 79 of 1000: mpd.slice.51000-51999.json
# mpd_playlists_51000-51999.csv saved to ../data/playlists
# mpd_tracks_51000-51999.csv saved to ../data/tracks
#
# Slice 80 of 1000: mpd.slice.326000-326999.json
# mpd_playlists_326000-326999.csv saved to ../data/playlists
# mpd_tracks_326000-326999.csv saved to ../data/tracks
#
# Slice 81 of 1000: mpd.slice.976000-976999.json
# mpd_playlists_976000-976999.csv saved to ../data/playlists
# mpd_tracks_976000-976999.csv saved to ../data/tracks
#
# Slice 82 of 1000: mpd.slice.420000-420999.json
# mpd_playlists_420000-420999.csv saved to ../data/playlists
# mpd_tracks_420000-420999.csv saved to ../data/tracks
#
# Slice 83 of 1000: mpd.slice.292000-292999.json
# mpd_playlists_292000-292999.csv saved to ../data/playlists
# mpd_tracks_292000-292999.csv saved to ../data/tracks
#
# Slice 84 of 1000: mpd.slice.594000-594999.json
# mpd_playlists_594000-594999.csv saved to ../data/playlists
# mpd_tracks_594000-594999.csv saved to ../data/tracks
#
# Slice 85 of 1000: mpd.slice.945000-945999.json
# mpd_playlists_945000-945999.csv saved to ../data/playlists
# mpd_tracks_945000-945999.csv saved to ../data/tracks
#
# Slice 86 of 1000: mpd.slice.413000-413999.json
# mpd_playlists_413000-413999.csv saved to ../data/playlists
# mpd_tracks_413000-413999.csv saved to ../data/tracks
#
# Slice 87 of 1000: mpd.slice.75000-75999.json
# mpd_playlists_75000-75999.csv saved to ../data/playlists
# mpd_tracks_75000-75999.csv saved to ../data/tracks
#
# Slice 88 of 1000: mpd.slice.315000-315999.json
# mpd_playlists_315000-315999.csv saved to ../data/playlists
# mpd_tracks_315000-315999.csv saved to ../data/tracks
#
# Slice 89 of 1000: mpd.slice.749000-749999.json
# mpd_playlists_749000-749999.csv saved to ../data/playlists
# mpd_tracks_749000-749999.csv saved to ../data/tracks
#
# Slice 90 of 1000: mpd.slice.124000-124999.json
# mpd_playlists_124000-124999.csv saved to ../data/playlists
# mpd_tracks_124000-124999.csv saved to ../data/tracks
#
# Slice 91 of 1000: mpd.slice.622000-622999.json
# mpd_playlists_622000-622999.csv saved to ../data/playlists
# mpd_tracks_622000-622999.csv saved to ../data/tracks
#
# Slice 92 of 1000: mpd.slice.578000-578999.json
# mpd_playlists_578000-578999.csv saved to ../data/playlists
# mpd_tracks_578000-578999.csv saved to ../data/tracks
#
# Slice 93 of 1000: mpd.slice.796000-796999.json
# mpd_playlists_796000-796999.csv saved to ../data/playlists
# mpd_tracks_796000-796999.csv saved to ../data/tracks
#
# Slice 94 of 1000: mpd.slice.723000-723999.json
# mpd_playlists_723000-723999.csv saved to ../data/playlists
# mpd_tracks_723000-723999.csv saved to ../data/tracks
#
# Slice 95 of 1000: mpd.slice.191000-191999.json
# mpd_playlists_191000-191999.csv saved to ../data/playlists
# mpd_tracks_191000-191999.csv saved to ../data/tracks
#
# Slice 96 of 1000: mpd.slice.479000-479999.json
# mpd_playlists_479000-479999.csv saved to ../data/playlists
# mpd_tracks_479000-479999.csv saved to ../data/tracks
#
# Slice 97 of 1000: mpd.slice.697000-697999.json
# mpd_playlists_697000-697999.csv saved to ../data/playlists
# mpd_tracks_697000-697999.csv saved to ../data/tracks
#
# Slice 98 of 1000: mpd.slice.844000-844999.json
# mpd_playlists_844000-844999.csv saved to ../data/playlists
# mpd_tracks_844000-844999.csv saved to ../data/tracks
#
# Slice 99 of 1000: mpd.slice.512000-512999.json
# mpd_playlists_512000-512999.csv saved to ../data/playlists
# mpd_tracks_512000-512999.csv saved to ../data/tracks
#
# Slice 100 of 1000: mpd.slice.214000-214999.json
# mpd_playlists_214000-214999.csv saved to ../data/playlists
# mpd_tracks_214000-214999.csv saved to ../data/tracks
#
# Slice 101 of 1000: mpd.slice.648000-648999.json
# mpd_playlists_648000-648999.csv saved to ../data/playlists
# mpd_tracks_648000-648999.csv saved to ../data/tracks
#
# Slice 102 of 1000: mpd.slice.711000-711999.json
# mpd_playlists_711000-711999.csv saved to ../data/playlists
# mpd_tracks_711000-711999.csv saved to ../data/tracks
#
# Slice 103 of 1000: mpd.slice.876000-876999.json
# mpd_playlists_876000-876999.csv saved to ../data/playlists
# mpd_tracks_876000-876999.csv saved to ../data/tracks
#
# Slice 104 of 1000: mpd.slice.520000-520999.json
# mpd_playlists_520000-520999.csv saved to ../data/playlists
# mpd_tracks_520000-520999.csv saved to ../data/tracks
#
# Slice 105 of 1000: mpd.slice.226000-226999.json
# mpd_playlists_226000-226999.csv saved to ../data/playlists
# mpd_tracks_226000-226999.csv saved to ../data/tracks
#
# Slice 106 of 1000: mpd.slice.494000-494999.json
# mpd_playlists_494000-494999.csv saved to ../data/playlists
# mpd_tracks_494000-494999.csv saved to ../data/tracks
#
# Slice 107 of 1000: mpd.slice.392000-392999.json
# mpd_playlists_392000-392999.csv saved to ../data/playlists
# mpd_tracks_392000-392999.csv saved to ../data/tracks
#
# Slice 108 of 1000: mpd.slice.977000-977999.json
# mpd_playlists_977000-977999.csv saved to ../data/playlists
# mpd_tracks_977000-977999.csv saved to ../data/tracks
#
# Slice 109 of 1000: mpd.slice.421000-421999.json
# mpd_playlists_421000-421999.csv saved to ../data/playlists
# mpd_tracks_421000-421999.csv saved to ../data/tracks
#
# Slice 110 of 1000: mpd.slice.327000-327999.json
# mpd_playlists_327000-327999.csv saved to ../data/playlists
# mpd_tracks_327000-327999.csv saved to ../data/tracks
#
# Slice 111 of 1000: mpd.slice.595000-595999.json
# mpd_playlists_595000-595999.csv saved to ../data/playlists
# mpd_tracks_595000-595999.csv saved to ../data/tracks
#
# Slice 112 of 1000: mpd.slice.293000-293999.json
# mpd_playlists_293000-293999.csv saved to ../data/playlists
# mpd_tracks_293000-293999.csv saved to ../data/tracks
#
# Slice 113 of 1000: mpd.slice.116000-116999.json
# mpd_playlists_116000-116999.csv saved to ../data/playlists
# mpd_tracks_116000-116999.csv saved to ../data/tracks
#
# Slice 114 of 1000: mpd.slice.610000-610999.json
# mpd_playlists_610000-610999.csv saved to ../data/playlists
# mpd_tracks_610000-610999.csv saved to ../data/tracks
#
# Slice 115 of 1000: mpd.slice.27000-27999.json
# mpd_playlists_27000-27999.csv saved to ../data/playlists
# mpd_tracks_27000-27999.csv saved to ../data/tracks
#
# Slice 116 of 1000: mpd.slice.6000-6999.json
# mpd_playlists_6000-6999.csv saved to ../data/playlists
# mpd_tracks_6000-6999.csv saved to ../data/tracks
#
# Slice 117 of 1000: mpd.slice.623000-623999.json
# mpd_playlists_623000-623999.csv saved to ../data/playlists
# mpd_tracks_623000-623999.csv saved to ../data/tracks
#
# Slice 118 of 1000: mpd.slice.125000-125999.json
# mpd_playlists_125000-125999.csv saved to ../data/playlists
# mpd_tracks_125000-125999.csv saved to ../data/tracks
#
# Slice 119 of 1000: mpd.slice.797000-797999.json
# mpd_playlists_797000-797999.csv saved to ../data/playlists
# mpd_tracks_797000-797999.csv saved to ../data/tracks
#
# Slice 120 of 1000: mpd.slice.579000-579999.json
# mpd_playlists_579000-579999.csv saved to ../data/playlists
# mpd_tracks_579000-579999.csv saved to ../data/tracks
#
# Slice 121 of 1000: mpd.slice.314000-314999.json
# mpd_playlists_314000-314999.csv saved to ../data/playlists
# mpd_tracks_314000-314999.csv saved to ../data/tracks
#
# Slice 122 of 1000: mpd.slice.944000-944999.json
# mpd_playlists_944000-944999.csv saved to ../data/playlists
# mpd_tracks_944000-944999.csv saved to ../data/tracks
#
# Slice 123 of 1000: mpd.slice.412000-412999.json
# mpd_playlists_412000-412999.csv saved to ../data/playlists
# mpd_tracks_412000-412999.csv saved to ../data/tracks
#
# Slice 124 of 1000: mpd.slice.748000-748999.json
# mpd_playlists_748000-748999.csv saved to ../data/playlists
# mpd_tracks_748000-748999.csv saved to ../data/tracks
#
# Slice 125 of 1000: mpd.slice.215000-215999.json
# mpd_playlists_215000-215999.csv saved to ../data/playlists
# mpd_tracks_215000-215999.csv saved to ../data/tracks
#
# Slice 126 of 1000: mpd.slice.19000-19999.json
# mpd_playlists_19000-19999.csv saved to ../data/playlists
# mpd_tracks_19000-19999.csv saved to ../data/tracks
#
# Slice 127 of 1000: mpd.slice.845000-845999.json
# mpd_playlists_845000-845999.csv saved to ../data/playlists
# mpd_tracks_845000-845999.csv saved to ../data/tracks
#
# Slice 128 of 1000: mpd.slice.513000-513999.json
# mpd_playlists_513000-513999.csv saved to ../data/playlists
# mpd_tracks_513000-513999.csv saved to ../data/tracks
#
# Slice 129 of 1000: mpd.slice.2000-2999.json
# mpd_playlists_2000-2999.csv saved to ../data/playlists
# mpd_tracks_2000-2999.csv saved to ../data/tracks
#
# Slice 130 of 1000: mpd.slice.649000-649999.json
# mpd_playlists_649000-649999.csv saved to ../data/playlists
# mpd_tracks_649000-649999.csv saved to ../data/tracks
#
# Slice 131 of 1000: mpd.slice.722000-722999.json
# mpd_playlists_722000-722999.csv saved to ../data/playlists
# mpd_tracks_722000-722999.csv saved to ../data/tracks
#
# Slice 132 of 1000: mpd.slice.696000-696999.json
# mpd_playlists_696000-696999.csv saved to ../data/playlists
# mpd_tracks_696000-696999.csv saved to ../data/tracks
#
# Slice 133 of 1000: mpd.slice.478000-478999.json
# mpd_playlists_478000-478999.csv saved to ../data/playlists
# mpd_tracks_478000-478999.csv saved to ../data/tracks
#
# Slice 134 of 1000: mpd.slice.190000-190999.json
# mpd_playlists_190000-190999.csv saved to ../data/playlists
# mpd_tracks_190000-190999.csv saved to ../data/tracks
#
# Slice 135 of 1000: mpd.slice.540000-540999.json
# mpd_playlists_540000-540999.csv saved to ../data/playlists
# mpd_tracks_540000-540999.csv saved to ../data/tracks
#
# Slice 136 of 1000: mpd.slice.816000-816999.json
# mpd_playlists_816000-816999.csv saved to ../data/playlists
# mpd_tracks_816000-816999.csv saved to ../data/tracks
#
# Slice 137 of 1000: mpd.slice.246000-246999.json
# mpd_playlists_246000-246999.csv saved to ../data/playlists
# mpd_tracks_246000-246999.csv saved to ../data/tracks
#
# Slice 138 of 1000: mpd.slice.37000-37999.json
# mpd_playlists_37000-37999.csv saved to ../data/playlists
# mpd_tracks_37000-37999.csv saved to ../data/tracks
#
# Slice 139 of 1000: mpd.slice.299000-299999.json
# mpd_playlists_299000-299999.csv saved to ../data/playlists
# mpd_tracks_299000-299999.csv saved to ../data/tracks
#
# Slice 140 of 1000: mpd.slice.771000-771999.json
# mpd_playlists_771000-771999.csv saved to ../data/playlists
# mpd_tracks_771000-771999.csv saved to ../data/tracks
#
# Slice 141 of 1000: mpd.slice.176000-176999.json
# mpd_playlists_176000-176999.csv saved to ../data/playlists
# mpd_tracks_176000-176999.csv saved to ../data/tracks
#
# Slice 142 of 1000: mpd.slice.398000-398999.json
# mpd_playlists_398000-398999.csv saved to ../data/playlists
# mpd_tracks_398000-398999.csv saved to ../data/tracks
#
# Slice 143 of 1000: mpd.slice.670000-670999.json
# mpd_playlists_670000-670999.csv saved to ../data/playlists
# mpd_tracks_670000-670999.csv saved to ../data/tracks
#
# Slice 144 of 1000: mpd.slice.441000-441999.json
# mpd_playlists_441000-441999.csv saved to ../data/playlists
# mpd_tracks_441000-441999.csv saved to ../data/tracks
#
# Slice 145 of 1000: mpd.slice.917000-917999.json
# mpd_playlists_917000-917999.csv saved to ../data/playlists
# mpd_tracks_917000-917999.csv saved to ../data/tracks
#
# Slice 146 of 1000: mpd.slice.347000-347999.json
# mpd_playlists_347000-347999.csv saved to ../data/playlists
# mpd_tracks_347000-347999.csv saved to ../data/tracks
#
# Slice 147 of 1000: mpd.slice.374000-374999.json
# mpd_playlists_374000-374999.csv saved to ../data/playlists
# mpd_tracks_374000-374999.csv saved to ../data/tracks
#
# Slice 148 of 1000: mpd.slice.472000-472999.json
# mpd_playlists_472000-472999.csv saved to ../data/playlists
# mpd_tracks_472000-472999.csv saved to ../data/tracks
#
# Slice 149 of 1000: mpd.slice.924000-924999.json
# mpd_playlists_924000-924999.csv saved to ../data/playlists
# mpd_tracks_924000-924999.csv saved to ../data/tracks
#
# Slice 150 of 1000: mpd.slice.728000-728999.json
# mpd_playlists_728000-728999.csv saved to ../data/playlists
# mpd_tracks_728000-728999.csv saved to ../data/tracks
#
# Slice 151 of 1000: mpd.slice.890000-890999.json
# mpd_playlists_890000-890999.csv saved to ../data/playlists
# mpd_tracks_890000-890999.csv saved to ../data/tracks
#
# Slice 152 of 1000: mpd.slice.643000-643999.json
# mpd_playlists_643000-643999.csv saved to ../data/playlists
# mpd_tracks_643000-643999.csv saved to ../data/tracks
#
# Slice 153 of 1000: mpd.slice.145000-145999.json
# mpd_playlists_145000-145999.csv saved to ../data/playlists
# mpd_tracks_145000-145999.csv saved to ../data/tracks
#
# Slice 154 of 1000: mpd.slice.519000-519999.json
# mpd_playlists_519000-519999.csv saved to ../data/playlists
# mpd_tracks_519000-519999.csv saved to ../data/tracks
#
# Slice 155 of 1000: mpd.slice.742000-742999.json
# mpd_playlists_742000-742999.csv saved to ../data/playlists
# mpd_tracks_742000-742999.csv saved to ../data/tracks
#
# Slice 156 of 1000: mpd.slice.13000-13999.json
# mpd_playlists_13000-13999.csv saved to ../data/playlists
# mpd_tracks_13000-13999.csv saved to ../data/tracks
#
# Slice 157 of 1000: mpd.slice.418000-418999.json
# mpd_playlists_418000-418999.csv saved to ../data/playlists
# mpd_tracks_418000-418999.csv saved to ../data/tracks
#
# Slice 158 of 1000: mpd.slice.8000-8999.json
# mpd_playlists_8000-8999.csv saved to ../data/playlists
# mpd_tracks_8000-8999.csv saved to ../data/tracks
#
# Slice 159 of 1000: mpd.slice.275000-275999.json
# mpd_playlists_275000-275999.csv saved to ../data/playlists
# mpd_tracks_275000-275999.csv saved to ../data/tracks
#
# Slice 160 of 1000: mpd.slice.573000-573999.json
# mpd_playlists_573000-573999.csv saved to ../data/playlists
# mpd_tracks_573000-573999.csv saved to ../data/tracks
#
# Slice 161 of 1000: mpd.slice.825000-825999.json
# mpd_playlists_825000-825999.csv saved to ../data/playlists
# mpd_tracks_825000-825999.csv saved to ../data/tracks
#
# Slice 162 of 1000: mpd.slice.629000-629999.json
# mpd_playlists_629000-629999.csv saved to ../data/playlists
# mpd_tracks_629000-629999.csv saved to ../data/tracks
#
# Slice 163 of 1000: mpd.slice.991000-991999.json
# mpd_playlists_991000-991999.csv saved to ../data/playlists
# mpd_tracks_991000-991999.csv saved to ../data/tracks
#
# Slice 164 of 1000: mpd.slice.770000-770999.json
# mpd_playlists_770000-770999.csv saved to ../data/playlists
# mpd_tracks_770000-770999.csv saved to ../data/tracks
#
# Slice 165 of 1000: mpd.slice.298000-298999.json
# mpd_playlists_298000-298999.csv saved to ../data/playlists
# mpd_tracks_298000-298999.csv saved to ../data/tracks
#
# Slice 166 of 1000: mpd.slice.247000-247999.json
# mpd_playlists_247000-247999.csv saved to ../data/playlists
# mpd_tracks_247000-247999.csv saved to ../data/tracks
#
# Slice 167 of 1000: mpd.slice.541000-541999.json
# mpd_playlists_541000-541999.csv saved to ../data/playlists
# mpd_tracks_541000-541999.csv saved to ../data/tracks
#
# Slice 168 of 1000: mpd.slice.817000-817999.json
# mpd_playlists_817000-817999.csv saved to ../data/playlists
# mpd_tracks_817000-817999.csv saved to ../data/tracks
#
# Slice 169 of 1000: mpd.slice.41000-41999.json
# mpd_playlists_41000-41999.csv saved to ../data/playlists
# mpd_tracks_41000-41999.csv saved to ../data/tracks
#
# Slice 170 of 1000: mpd.slice.346000-346999.json
# mpd_playlists_346000-346999.csv saved to ../data/playlists
# mpd_tracks_346000-346999.csv saved to ../data/tracks
#
# Slice 171 of 1000: mpd.slice.440000-440999.json
# mpd_playlists_440000-440999.csv saved to ../data/playlists
# mpd_tracks_440000-440999.csv saved to ../data/tracks
#
# Slice 172 of 1000: mpd.slice.916000-916999.json
# mpd_playlists_916000-916999.csv saved to ../data/playlists
# mpd_tracks_916000-916999.csv saved to ../data/tracks
#
# Slice 173 of 1000: mpd.slice.671000-671999.json
# mpd_playlists_671000-671999.csv saved to ../data/playlists
# mpd_tracks_671000-671999.csv saved to ../data/tracks
#
# Slice 174 of 1000: mpd.slice.399000-399999.json
# mpd_playlists_399000-399999.csv saved to ../data/playlists
# mpd_tracks_399000-399999.csv saved to ../data/tracks
#
# Slice 175 of 1000: mpd.slice.177000-177999.json
# mpd_playlists_177000-177999.csv saved to ../data/playlists
# mpd_tracks_177000-177999.csv saved to ../data/tracks
#
# Slice 176 of 1000: mpd.slice.94000-94999.json
# mpd_playlists_94000-94999.csv saved to ../data/playlists
# mpd_tracks_94000-94999.csv saved to ../data/tracks
#
# Slice 177 of 1000: mpd.slice.144000-144999.json
# mpd_playlists_144000-144999.csv saved to ../data/playlists
# mpd_tracks_144000-144999.csv saved to ../data/tracks
#
# Slice 178 of 1000: mpd.slice.642000-642999.json
# mpd_playlists_642000-642999.csv saved to ../data/playlists
# mpd_tracks_642000-642999.csv saved to ../data/tracks
#
# Slice 179 of 1000: mpd.slice.518000-518999.json
# mpd_playlists_518000-518999.csv saved to ../data/playlists
# mpd_tracks_518000-518999.csv saved to ../data/tracks
#
# Slice 180 of 1000: mpd.slice.473000-473999.json
# mpd_playlists_473000-473999.csv saved to ../data/playlists
# mpd_tracks_473000-473999.csv saved to ../data/tracks
#
# Slice 181 of 1000: mpd.slice.925000-925999.json
# mpd_playlists_925000-925999.csv saved to ../data/playlists
# mpd_tracks_925000-925999.csv saved to ../data/tracks
#
# Slice 182 of 1000: mpd.slice.375000-375999.json
# mpd_playlists_375000-375999.csv saved to ../data/playlists
# mpd_tracks_375000-375999.csv saved to ../data/tracks
#
# Slice 183 of 1000: mpd.slice.891000-891999.json
# mpd_playlists_891000-891999.csv saved to ../data/playlists
# mpd_tracks_891000-891999.csv saved to ../data/tracks
#
# Slice 184 of 1000: mpd.slice.729000-729999.json
# mpd_playlists_729000-729999.csv saved to ../data/playlists
# mpd_tracks_729000-729999.csv saved to ../data/tracks
#
# Slice 185 of 1000: mpd.slice.572000-572999.json
# mpd_playlists_572000-572999.csv saved to ../data/playlists
# mpd_tracks_572000-572999.csv saved to ../data/tracks
#
# Slice 186 of 1000: mpd.slice.824000-824999.json
# mpd_playlists_824000-824999.csv saved to ../data/playlists
# mpd_tracks_824000-824999.csv saved to ../data/tracks
#
# Slice 187 of 1000: mpd.slice.274000-274999.json
# mpd_playlists_274000-274999.csv saved to ../data/playlists
# mpd_tracks_274000-274999.csv saved to ../data/tracks
#
# Slice 188 of 1000: mpd.slice.990000-990999.json
# mpd_playlists_990000-990999.csv saved to ../data/playlists
# mpd_tracks_990000-990999.csv saved to ../data/tracks
#
# Slice 189 of 1000: mpd.slice.628000-628999.json
# mpd_playlists_628000-628999.csv saved to ../data/playlists
# mpd_tracks_628000-628999.csv saved to ../data/tracks
#
# Slice 190 of 1000: mpd.slice.743000-743999.json
# mpd_playlists_743000-743999.csv saved to ../data/playlists
# mpd_tracks_743000-743999.csv saved to ../data/tracks
#
# Slice 191 of 1000: mpd.slice.419000-419999.json
# mpd_playlists_419000-419999.csv saved to ../data/playlists
# mpd_tracks_419000-419999.csv saved to ../data/tracks
#
# Slice 192 of 1000: mpd.slice.65000-65999.json
# mpd_playlists_65000-65999.csv saved to ../data/playlists
# mpd_tracks_65000-65999.csv saved to ../data/tracks
#
# Slice 193 of 1000: mpd.slice.528000-528999.json
# mpd_playlists_528000-528999.csv saved to ../data/playlists
# mpd_tracks_528000-528999.csv saved to ../data/tracks
#
# Slice 194 of 1000: mpd.slice.174000-174999.json
# mpd_playlists_174000-174999.csv saved to ../data/playlists
# mpd_tracks_174000-174999.csv saved to ../data/tracks
#
# Slice 195 of 1000: mpd.slice.672000-672999.json
# mpd_playlists_672000-672999.csv saved to ../data/playlists
# mpd_tracks_672000-672999.csv saved to ../data/tracks
#
# Slice 196 of 1000: mpd.slice.719000-719999.json
# mpd_playlists_719000-719999.csv saved to ../data/playlists
# mpd_tracks_719000-719999.csv saved to ../data/tracks
#
# Slice 197 of 1000: mpd.slice.915000-915999.json
# mpd_playlists_915000-915999.csv saved to ../data/playlists
# mpd_tracks_915000-915999.csv saved to ../data/tracks
#
# Slice 198 of 1000: mpd.slice.443000-443999.json
# mpd_playlists_443000-443999.csv saved to ../data/playlists
# mpd_tracks_443000-443999.csv saved to ../data/tracks
#
# Slice 199 of 1000: mpd.slice.345000-345999.json
# mpd_playlists_345000-345999.csv saved to ../data/playlists
# mpd_tracks_345000-345999.csv saved to ../data/tracks
#
# Slice 200 of 1000: mpd.slice.618000-618999.json
# mpd_playlists_618000-618999.csv saved to ../data/playlists
# mpd_tracks_618000-618999.csv saved to ../data/tracks
#
# Slice 201 of 1000: mpd.slice.814000-814999.json
# mpd_playlists_814000-814999.csv saved to ../data/playlists
# mpd_tracks_814000-814999.csv saved to ../data/tracks
#
# Slice 202 of 1000: mpd.slice.542000-542999.json
# mpd_playlists_542000-542999.csv saved to ../data/playlists
# mpd_tracks_542000-542999.csv saved to ../data/tracks
#
# Slice 203 of 1000: mpd.slice.244000-244999.json
# mpd_playlists_244000-244999.csv saved to ../data/playlists
# mpd_tracks_244000-244999.csv saved to ../data/tracks
#
# Slice 204 of 1000: mpd.slice.429000-429999.json
# mpd_playlists_429000-429999.csv saved to ../data/playlists
# mpd_tracks_429000-429999.csv saved to ../data/tracks
#
# Slice 205 of 1000: mpd.slice.773000-773999.json
# mpd_playlists_773000-773999.csv saved to ../data/playlists
# mpd_tracks_773000-773999.csv saved to ../data/tracks
#
# Slice 206 of 1000: mpd.slice.60000-60999.json
# mpd_playlists_60000-60999.csv saved to ../data/playlists
# mpd_tracks_60000-60999.csv saved to ../data/tracks
#
# Slice 207 of 1000: mpd.slice.740000-740999.json
# mpd_playlists_740000-740999.csv saved to ../data/playlists
# mpd_tracks_740000-740999.csv saved to ../data/tracks
#
# Slice 208 of 1000: mpd.slice.993000-993999.json
# mpd_playlists_993000-993999.csv saved to ../data/playlists
# mpd_tracks_993000-993999.csv saved to ../data/tracks
#
# Slice 209 of 1000: mpd.slice.277000-277999.json
# mpd_playlists_277000-277999.csv saved to ../data/playlists
# mpd_tracks_277000-277999.csv saved to ../data/tracks
#
# Slice 210 of 1000: mpd.slice.827000-827999.json
# mpd_playlists_827000-827999.csv saved to ../data/playlists
# mpd_tracks_827000-827999.csv saved to ../data/tracks
#
# Slice 211 of 1000: mpd.slice.571000-571999.json
# mpd_playlists_571000-571999.csv saved to ../data/playlists
# mpd_tracks_571000-571999.csv saved to ../data/tracks
#
# Slice 212 of 1000: mpd.slice.44000-44999.json
# mpd_playlists_44000-44999.csv saved to ../data/playlists
# mpd_tracks_44000-44999.csv saved to ../data/tracks
#
# Slice 213 of 1000: mpd.slice.892000-892999.json
# mpd_playlists_892000-892999.csv saved to ../data/playlists
# mpd_tracks_892000-892999.csv saved to ../data/tracks
#
# Slice 214 of 1000: mpd.slice.376000-376999.json
# mpd_playlists_376000-376999.csv saved to ../data/playlists
# mpd_tracks_376000-376999.csv saved to ../data/tracks
#
# Slice 215 of 1000: mpd.slice.926000-926999.json
# mpd_playlists_926000-926999.csv saved to ../data/playlists
# mpd_tracks_926000-926999.csv saved to ../data/tracks
#
# Slice 216 of 1000: mpd.slice.470000-470999.json
# mpd_playlists_470000-470999.csv saved to ../data/playlists
# mpd_tracks_470000-470999.csv saved to ../data/tracks
#
# Slice 217 of 1000: mpd.slice.198000-198999.json
# mpd_playlists_198000-198999.csv saved to ../data/playlists
# mpd_tracks_198000-198999.csv saved to ../data/tracks
#
# Slice 218 of 1000: mpd.slice.91000-91999.json
# mpd_playlists_91000-91999.csv saved to ../data/playlists
# mpd_tracks_91000-91999.csv saved to ../data/tracks
#
# Slice 219 of 1000: mpd.slice.641000-641999.json
# mpd_playlists_641000-641999.csv saved to ../data/playlists
# mpd_tracks_641000-641999.csv saved to ../data/tracks
#
# Slice 220 of 1000: mpd.slice.147000-147999.json
# mpd_playlists_147000-147999.csv saved to ../data/playlists
# mpd_tracks_147000-147999.csv saved to ../data/tracks
#
# Slice 221 of 1000: mpd.slice.718000-718999.json
# mpd_playlists_718000-718999.csv saved to ../data/playlists
# mpd_tracks_718000-718999.csv saved to ../data/tracks
#
# Slice 222 of 1000: mpd.slice.344000-344999.json
# mpd_playlists_344000-344999.csv saved to ../data/playlists
# mpd_tracks_344000-344999.csv saved to ../data/tracks
#
# Slice 223 of 1000: mpd.slice.914000-914999.json
# mpd_playlists_914000-914999.csv saved to ../data/playlists
# mpd_tracks_914000-914999.csv saved to ../data/tracks
#
# Slice 224 of 1000: mpd.slice.442000-442999.json
# mpd_playlists_442000-442999.csv saved to ../data/playlists
# mpd_tracks_442000-442999.csv saved to ../data/tracks
#
# Slice 225 of 1000: mpd.slice.529000-529999.json
# mpd_playlists_529000-529999.csv saved to ../data/playlists
# mpd_tracks_529000-529999.csv saved to ../data/tracks
#
# Slice 226 of 1000: mpd.slice.673000-673999.json
# mpd_playlists_673000-673999.csv saved to ../data/playlists
# mpd_tracks_673000-673999.csv saved to ../data/tracks
#
# Slice 227 of 1000: mpd.slice.175000-175999.json
# mpd_playlists_175000-175999.csv saved to ../data/playlists
# mpd_tracks_175000-175999.csv saved to ../data/tracks
#
# Slice 228 of 1000: mpd.slice.428000-428999.json
# mpd_playlists_428000-428999.csv saved to ../data/playlists
# mpd_tracks_428000-428999.csv saved to ../data/tracks
#
# Slice 229 of 1000: mpd.slice.772000-772999.json
# mpd_playlists_772000-772999.csv saved to ../data/playlists
# mpd_tracks_772000-772999.csv saved to ../data/tracks
#
# Slice 230 of 1000: mpd.slice.16000-16999.json
# mpd_playlists_16000-16999.csv saved to ../data/playlists
# mpd_tracks_16000-16999.csv saved to ../data/tracks
#
# Slice 231 of 1000: mpd.slice.619000-619999.json
# mpd_playlists_619000-619999.csv saved to ../data/playlists
# mpd_tracks_619000-619999.csv saved to ../data/tracks
#
# Slice 232 of 1000: mpd.slice.245000-245999.json
# mpd_playlists_245000-245999.csv saved to ../data/playlists
# mpd_tracks_245000-245999.csv saved to ../data/tracks
#
# Slice 233 of 1000: mpd.slice.815000-815999.json
# mpd_playlists_815000-815999.csv saved to ../data/playlists
# mpd_tracks_815000-815999.csv saved to ../data/tracks
#
# Slice 234 of 1000: mpd.slice.543000-543999.json
# mpd_playlists_543000-543999.csv saved to ../data/playlists
# mpd_tracks_543000-543999.csv saved to ../data/tracks
#
# Slice 235 of 1000: mpd.slice.992000-992999.json
# mpd_playlists_992000-992999.csv saved to ../data/playlists
# mpd_tracks_992000-992999.csv saved to ../data/tracks
#
# Slice 236 of 1000: mpd.slice.826000-826999.json
# mpd_playlists_826000-826999.csv saved to ../data/playlists
# mpd_tracks_826000-826999.csv saved to ../data/tracks
#
# Slice 237 of 1000: mpd.slice.570000-570999.json
# mpd_playlists_570000-570999.csv saved to ../data/playlists
# mpd_tracks_570000-570999.csv saved to ../data/tracks
#
# Slice 238 of 1000: mpd.slice.32000-32999.json
# mpd_playlists_32000-32999.csv saved to ../data/playlists
# mpd_tracks_32000-32999.csv saved to ../data/tracks
#
# Slice 239 of 1000: mpd.slice.276000-276999.json
# mpd_playlists_276000-276999.csv saved to ../data/playlists
# mpd_tracks_276000-276999.csv saved to ../data/tracks
#
# Slice 240 of 1000: mpd.slice.741000-741999.json
# mpd_playlists_741000-741999.csv saved to ../data/playlists
# mpd_tracks_741000-741999.csv saved to ../data/tracks
#
# Slice 241 of 1000: mpd.slice.146000-146999.json
# mpd_playlists_146000-146999.csv saved to ../data/playlists
# mpd_tracks_146000-146999.csv saved to ../data/tracks
#
# Slice 242 of 1000: mpd.slice.640000-640999.json
# mpd_playlists_640000-640999.csv saved to ../data/playlists
# mpd_tracks_640000-640999.csv saved to ../data/tracks
#
# Slice 243 of 1000: mpd.slice.893000-893999.json
# mpd_playlists_893000-893999.csv saved to ../data/playlists
# mpd_tracks_893000-893999.csv saved to ../data/tracks
#
# Slice 244 of 1000: mpd.slice.9000-9999.json
# mpd_playlists_9000-9999.csv saved to ../data/playlists
# mpd_tracks_9000-9999.csv saved to ../data/tracks
#
# Slice 245 of 1000: mpd.slice.199000-199999.json
# mpd_playlists_199000-199999.csv saved to ../data/playlists
# mpd_tracks_199000-199999.csv saved to ../data/tracks
#
# Slice 246 of 1000: mpd.slice.927000-927999.json
# mpd_playlists_927000-927999.csv saved to ../data/playlists
# mpd_tracks_927000-927999.csv saved to ../data/tracks
#
# Slice 247 of 1000: mpd.slice.471000-471999.json
# mpd_playlists_471000-471999.csv saved to ../data/playlists
# mpd_tracks_471000-471999.csv saved to ../data/tracks
#
# Slice 248 of 1000: mpd.slice.28000-28999.json
# mpd_playlists_28000-28999.csv saved to ../data/playlists
# mpd_tracks_28000-28999.csv saved to ../data/tracks
#
# Slice 249 of 1000: mpd.slice.377000-377999.json
# mpd_playlists_377000-377999.csv saved to ../data/playlists
# mpd_tracks_377000-377999.csv saved to ../data/tracks
#
# Slice 250 of 1000: mpd.slice.880000-880999.json
# mpd_playlists_880000-880999.csv saved to ../data/playlists
# mpd_tracks_880000-880999.csv saved to ../data/tracks
#
# Slice 251 of 1000: mpd.slice.738000-738999.json
# mpd_playlists_738000-738999.csv saved to ../data/playlists
# mpd_tracks_738000-738999.csv saved to ../data/tracks
#
# Slice 252 of 1000: mpd.slice.934000-934999.json
# mpd_playlists_934000-934999.csv saved to ../data/playlists
# mpd_tracks_934000-934999.csv saved to ../data/tracks
#
# Slice 253 of 1000: mpd.slice.462000-462999.json
# mpd_playlists_462000-462999.csv saved to ../data/playlists
# mpd_tracks_462000-462999.csv saved to ../data/tracks
#
# Slice 254 of 1000: mpd.slice.364000-364999.json
# mpd_playlists_364000-364999.csv saved to ../data/playlists
# mpd_tracks_364000-364999.csv saved to ../data/tracks
#
# Slice 255 of 1000: mpd.slice.509000-509999.json
# mpd_playlists_509000-509999.csv saved to ../data/playlists
# mpd_tracks_509000-509999.csv saved to ../data/tracks
#
# Slice 256 of 1000: mpd.slice.155000-155999.json
# mpd_playlists_155000-155999.csv saved to ../data/playlists
# mpd_tracks_155000-155999.csv saved to ../data/tracks
#
# Slice 257 of 1000: mpd.slice.653000-653999.json
# mpd_playlists_653000-653999.csv saved to ../data/playlists
# mpd_tracks_653000-653999.csv saved to ../data/tracks
#
# Slice 258 of 1000: mpd.slice.408000-408999.json
# mpd_playlists_408000-408999.csv saved to ../data/playlists
# mpd_tracks_408000-408999.csv saved to ../data/tracks
#
# Slice 259 of 1000: mpd.slice.10000-10999.json
# mpd_playlists_10000-10999.csv saved to ../data/playlists
# mpd_tracks_10000-10999.csv saved to ../data/tracks
#
# Slice 260 of 1000: mpd.slice.752000-752999.json
# mpd_playlists_752000-752999.csv saved to ../data/playlists
# mpd_tracks_752000-752999.csv saved to ../data/tracks
#
# Slice 261 of 1000: mpd.slice.981000-981999.json
# mpd_playlists_981000-981999.csv saved to ../data/playlists
# mpd_tracks_981000-981999.csv saved to ../data/tracks
#
# Slice 262 of 1000: mpd.slice.639000-639999.json
# mpd_playlists_639000-639999.csv saved to ../data/playlists
# mpd_tracks_639000-639999.csv saved to ../data/tracks
#
# Slice 263 of 1000: mpd.slice.835000-835999.json
# mpd_playlists_835000-835999.csv saved to ../data/playlists
# mpd_tracks_835000-835999.csv saved to ../data/tracks
#
# Slice 264 of 1000: mpd.slice.563000-563999.json
# mpd_playlists_563000-563999.csv saved to ../data/playlists
# mpd_tracks_563000-563999.csv saved to ../data/tracks
#
# Slice 265 of 1000: mpd.slice.265000-265999.json
# mpd_playlists_265000-265999.csv saved to ../data/playlists
# mpd_tracks_265000-265999.csv saved to ../data/tracks
#
# Slice 266 of 1000: mpd.slice.34000-34999.json
# mpd_playlists_34000-34999.csv saved to ../data/playlists
# mpd_tracks_34000-34999.csv saved to ../data/tracks
#
# Slice 267 of 1000: mpd.slice.256000-256999.json
# mpd_playlists_256000-256999.csv saved to ../data/playlists
# mpd_tracks_256000-256999.csv saved to ../data/tracks
#
# Slice 268 of 1000: mpd.slice.806000-806999.json
# mpd_playlists_806000-806999.csv saved to ../data/playlists
# mpd_tracks_806000-806999.csv saved to ../data/tracks
#
# Slice 269 of 1000: mpd.slice.550000-550999.json
# mpd_playlists_550000-550999.csv saved to ../data/playlists
# mpd_tracks_550000-550999.csv saved to ../data/tracks
#
# Slice 270 of 1000: mpd.slice.289000-289999.json
# mpd_playlists_289000-289999.csv saved to ../data/playlists
# mpd_tracks_289000-289999.csv saved to ../data/tracks
#
# Slice 271 of 1000: mpd.slice.761000-761999.json
# mpd_playlists_761000-761999.csv saved to ../data/playlists
# mpd_tracks_761000-761999.csv saved to ../data/tracks
#
# Slice 272 of 1000: mpd.slice.388000-388999.json
# mpd_playlists_388000-388999.csv saved to ../data/playlists
# mpd_tracks_388000-388999.csv saved to ../data/tracks
#
# Slice 273 of 1000: mpd.slice.660000-660999.json
# mpd_playlists_660000-660999.csv saved to ../data/playlists
# mpd_tracks_660000-660999.csv saved to ../data/tracks
#
# Slice 274 of 1000: mpd.slice.166000-166999.json
# mpd_playlists_166000-166999.csv saved to ../data/playlists
# mpd_tracks_166000-166999.csv saved to ../data/tracks
#
# Slice 275 of 1000: mpd.slice.357000-357999.json
# mpd_playlists_357000-357999.csv saved to ../data/playlists
# mpd_tracks_357000-357999.csv saved to ../data/tracks
#
# Slice 276 of 1000: mpd.slice.907000-907999.json
# mpd_playlists_907000-907999.csv saved to ../data/playlists
# mpd_tracks_907000-907999.csv saved to ../data/tracks
#
# Slice 277 of 1000: mpd.slice.451000-451999.json
# mpd_playlists_451000-451999.csv saved to ../data/playlists
# mpd_tracks_451000-451999.csv saved to ../data/tracks
#
# Slice 278 of 1000: mpd.slice.508000-508999.json
# mpd_playlists_508000-508999.csv saved to ../data/playlists
# mpd_tracks_508000-508999.csv saved to ../data/tracks
#
# Slice 279 of 1000: mpd.slice.652000-652999.json
# mpd_playlists_652000-652999.csv saved to ../data/playlists
# mpd_tracks_652000-652999.csv saved to ../data/tracks
#
# Slice 280 of 1000: mpd.slice.154000-154999.json
# mpd_playlists_154000-154999.csv saved to ../data/playlists
# mpd_tracks_154000-154999.csv saved to ../data/tracks
#
# Slice 281 of 1000: mpd.slice.739000-739999.json
# mpd_playlists_739000-739999.csv saved to ../data/playlists
# mpd_tracks_739000-739999.csv saved to ../data/tracks
#
# Slice 282 of 1000: mpd.slice.881000-881999.json
# mpd_playlists_881000-881999.csv saved to ../data/playlists
# mpd_tracks_881000-881999.csv saved to ../data/tracks
#
# Slice 283 of 1000: mpd.slice.365000-365999.json
# mpd_playlists_365000-365999.csv saved to ../data/playlists
# mpd_tracks_365000-365999.csv saved to ../data/tracks
#
# Slice 284 of 1000: mpd.slice.935000-935999.json
# mpd_playlists_935000-935999.csv saved to ../data/playlists
# mpd_tracks_935000-935999.csv saved to ../data/tracks
#
# Slice 285 of 1000: mpd.slice.463000-463999.json
# mpd_playlists_463000-463999.csv saved to ../data/playlists
# mpd_tracks_463000-463999.csv saved to ../data/tracks
#
# Slice 286 of 1000: mpd.slice.638000-638999.json
# mpd_playlists_638000-638999.csv saved to ../data/playlists
# mpd_tracks_638000-638999.csv saved to ../data/tracks
#
# Slice 287 of 1000: mpd.slice.980000-980999.json
# mpd_playlists_980000-980999.csv saved to ../data/playlists
# mpd_tracks_980000-980999.csv saved to ../data/tracks
#
# Slice 288 of 1000: mpd.slice.264000-264999.json
# mpd_playlists_264000-264999.csv saved to ../data/playlists
# mpd_tracks_264000-264999.csv saved to ../data/tracks
#
# Slice 289 of 1000: mpd.slice.834000-834999.json
# mpd_playlists_834000-834999.csv saved to ../data/playlists
# mpd_tracks_834000-834999.csv saved to ../data/tracks
#
# Slice 290 of 1000: mpd.slice.562000-562999.json
# mpd_playlists_562000-562999.csv saved to ../data/playlists
# mpd_tracks_562000-562999.csv saved to ../data/tracks
#
# Slice 291 of 1000: mpd.slice.66000-66999.json
# mpd_playlists_66000-66999.csv saved to ../data/playlists
# mpd_tracks_66000-66999.csv saved to ../data/tracks
#
# Slice 292 of 1000: mpd.slice.409000-409999.json
# mpd_playlists_409000-409999.csv saved to ../data/playlists
# mpd_tracks_409000-409999.csv saved to ../data/tracks
#
# Slice 293 of 1000: mpd.slice.753000-753999.json
# mpd_playlists_753000-753999.csv saved to ../data/playlists
# mpd_tracks_753000-753999.csv saved to ../data/tracks
#
# Slice 294 of 1000: mpd.slice.760000-760999.json
# mpd_playlists_760000-760999.csv saved to ../data/playlists
# mpd_tracks_760000-760999.csv saved to ../data/tracks
#
# Slice 295 of 1000: mpd.slice.288000-288999.json
# mpd_playlists_288000-288999.csv saved to ../data/playlists
# mpd_tracks_288000-288999.csv saved to ../data/tracks
#
# Slice 296 of 1000: mpd.slice.42000-42999.json
# mpd_playlists_42000-42999.csv saved to ../data/playlists
# mpd_tracks_42000-42999.csv saved to ../data/tracks
#
# Slice 297 of 1000: mpd.slice.807000-807999.json
# mpd_playlists_807000-807999.csv saved to ../data/playlists
# mpd_tracks_807000-807999.csv saved to ../data/tracks
#
# Slice 298 of 1000: mpd.slice.551000-551999.json
# mpd_playlists_551000-551999.csv saved to ../data/playlists
# mpd_tracks_551000-551999.csv saved to ../data/tracks
#
# Slice 299 of 1000: mpd.slice.257000-257999.json
# mpd_playlists_257000-257999.csv saved to ../data/playlists
# mpd_tracks_257000-257999.csv saved to ../data/tracks
#
# Slice 300 of 1000: mpd.slice.58000-58999.json
# mpd_playlists_58000-58999.csv saved to ../data/playlists
# mpd_tracks_58000-58999.csv saved to ../data/tracks
#
# ...
# mpd_tracks_506000-506999.csv saved to ../data/tracks
#
# Slice 902 of 1000: mpd.slice.850000-850999.json
# mpd_playlists_850000-850999.csv saved to ../data/playlists
# mpd_tracks_850000-850999.csv saved to ../data/tracks
#
# Slice 903 of 1000: mpd.slice.705000-705999.json
# mpd_playlists_705000-705999.csv saved to ../data/playlists
# mpd_tracks_705000-705999.csv saved to ../data/tracks
#
# Slice 904 of 1000: mpd.slice.359000-359999.json
# mpd_playlists_359000-359999.csv saved to ../data/playlists
# mpd_tracks_359000-359999.csv saved to ../data/tracks
#
# Slice 905 of 1000: mpd.slice.909000-909999.json
# mpd_playlists_909000-909999.csv saved to ../data/playlists
# mpd_tracks_909000-909999.csv saved to ../data/tracks
#
# Slice 906 of 1000: mpd.slice.232000-232999.json
# mpd_playlists_232000-232999.csv saved to ../data/playlists
# mpd_tracks_232000-232999.csv saved to ../data/tracks
#
# Slice 907 of 1000: mpd.slice.534000-534999.json
# mpd_playlists_534000-534999.csv saved to ../data/playlists
# mpd_tracks_534000-534999.csv saved to ../data/tracks
#
# Slice 908 of 1000: mpd.slice.862000-862999.json
# mpd_playlists_862000-862999.csv saved to ../data/playlists
# mpd_tracks_862000-862999.csv saved to ../data/tracks
#
# Slice 909 of 1000: mpd.slice.386000-386999.json
# mpd_playlists_386000-386999.csv saved to ../data/playlists
# mpd_tracks_386000-386999.csv saved to ../data/tracks
#
# Slice 910 of 1000: mpd.slice.45000-45999.json
# mpd_playlists_45000-45999.csv saved to ../data/playlists
# mpd_tracks_45000-45999.csv saved to ../data/tracks
#
# Slice 911 of 1000: mpd.slice.168000-168999.json
# mpd_playlists_168000-168999.csv saved to ../data/playlists
# mpd_tracks_168000-168999.csv saved to ../data/tracks
#
# Slice 912 of 1000: mpd.slice.480000-480999.json
# mpd_playlists_480000-480999.csv saved to ../data/playlists
# mpd_tracks_480000-480999.csv saved to ../data/tracks
#
# Slice 913 of 1000: mpd.slice.333000-333999.json
# mpd_playlists_333000-333999.csv saved to ../data/playlists
# mpd_tracks_333000-333999.csv saved to ../data/tracks
#
# Slice 914 of 1000: mpd.slice.435000-435999.json
# mpd_playlists_435000-435999.csv saved to ../data/playlists
# mpd_tracks_435000-435999.csv saved to ../data/tracks
#
# Slice 915 of 1000: mpd.slice.963000-963999.json
# mpd_playlists_963000-963999.csv saved to ../data/playlists
# mpd_tracks_963000-963999.csv saved to ../data/tracks
#
# Slice 916 of 1000: mpd.slice.287000-287999.json
# mpd_playlists_287000-287999.csv saved to ../data/playlists
# mpd_tracks_287000-287999.csv saved to ../data/tracks
#
# Slice 917 of 1000: mpd.slice.581000-581999.json
# mpd_playlists_581000-581999.csv saved to ../data/playlists
# mpd_tracks_581000-581999.csv saved to ../data/tracks
#
# Slice 918 of 1000: mpd.slice.604000-604999.json
# mpd_playlists_604000-604999.csv saved to ../data/playlists
# mpd_tracks_604000-604999.csv saved to ../data/tracks
#
# Slice 919 of 1000: mpd.slice.102000-102999.json
# mpd_playlists_102000-102999.csv saved to ../data/playlists
# mpd_tracks_102000-102999.csv saved to ../data/tracks
#
# Slice 920 of 1000: mpd.slice.258000-258999.json
# mpd_playlists_258000-258999.csv saved to ../data/playlists
# mpd_tracks_258000-258999.csv saved to ../data/tracks
#
# Slice 921 of 1000: mpd.slice.808000-808999.json
# mpd_playlists_808000-808999.csv saved to ../data/playlists
# mpd_tracks_808000-808999.csv saved to ../data/tracks
#
# Slice 922 of 1000: mpd.slice.90000-90999.json
# mpd_playlists_90000-90999.csv saved to ../data/playlists
# mpd_tracks_90000-90999.csv saved to ../data/tracks
#
# Slice 923 of 1000: mpd.slice.131000-131999.json
# mpd_playlists_131000-131999.csv saved to ../data/playlists
# mpd_tracks_131000-131999.csv saved to ../data/tracks
#
# Slice 924 of 1000: mpd.slice.637000-637999.json
# mpd_playlists_637000-637999.csv saved to ../data/playlists
# mpd_tracks_637000-637999.csv saved to ../data/tracks
#
# Slice 925 of 1000: mpd.slice.783000-783999.json
# mpd_playlists_783000-783999.csv saved to ../data/playlists
# mpd_tracks_783000-783999.csv saved to ../data/tracks
#
# Slice 926 of 1000: mpd.slice.406000-406999.json
# mpd_playlists_406000-406999.csv saved to ../data/playlists
# mpd_tracks_406000-406999.csv saved to ../data/tracks
#
# Slice 927 of 1000: mpd.slice.950000-950999.json
# mpd_playlists_950000-950999.csv saved to ../data/playlists
# mpd_tracks_950000-950999.csv saved to ../data/tracks
#
# Slice 928 of 1000: mpd.slice.300000-300999.json
# mpd_playlists_300000-300999.csv saved to ../data/playlists
# mpd_tracks_300000-300999.csv saved to ../data/tracks
#
# Slice 929 of 1000: mpd.slice.507000-507999.json
# mpd_playlists_507000-507999.csv saved to ../data/playlists
# mpd_tracks_507000-507999.csv saved to ../data/tracks
#
# Slice 930 of 1000: mpd.slice.851000-851999.json
# mpd_playlists_851000-851999.csv saved to ../data/playlists
# mpd_tracks_851000-851999.csv saved to ../data/tracks
#
# Slice 931 of 1000: mpd.slice.201000-201999.json
# mpd_playlists_201000-201999.csv saved to ../data/playlists
# mpd_tracks_201000-201999.csv saved to ../data/tracks
#
# Slice 932 of 1000: mpd.slice.736000-736999.json
# mpd_playlists_736000-736999.csv saved to ../data/playlists
# mpd_tracks_736000-736999.csv saved to ../data/tracks
#
# Slice 933 of 1000: mpd.slice.61000-61999.json
# mpd_playlists_61000-61999.csv saved to ../data/playlists
# mpd_tracks_61000-61999.csv saved to ../data/tracks
#
# Slice 934 of 1000: mpd.slice.184000-184999.json
# mpd_playlists_184000-184999.csv saved to ../data/playlists
# mpd_tracks_184000-184999.csv saved to ../data/tracks
#
# Slice 935 of 1000: mpd.slice.682000-682999.json
# mpd_playlists_682000-682999.csv saved to ../data/playlists
# mpd_tracks_682000-682999.csv saved to ../data/tracks
#
# Slice 936 of 1000: mpd.slice.101000-101999.json
# mpd_playlists_101000-101999.csv saved to ../data/playlists
# mpd_tracks_101000-101999.csv saved to ../data/tracks
#
# Slice 937 of 1000: mpd.slice.607000-607999.json
# mpd_playlists_607000-607999.csv saved to ../data/playlists
# mpd_tracks_607000-607999.csv saved to ../data/tracks
#
# Slice 938 of 1000: mpd.slice.582000-582999.json
# mpd_playlists_582000-582999.csv saved to ../data/playlists
# mpd_tracks_582000-582999.csv saved to ../data/tracks
#
# Slice 939 of 1000: mpd.slice.284000-284999.json
# mpd_playlists_284000-284999.csv saved to ../data/playlists
# mpd_tracks_284000-284999.csv saved to ../data/tracks
#
# Slice 940 of 1000: mpd.slice.960000-960999.json
# mpd_playlists_960000-960999.csv saved to ../data/playlists
# mpd_tracks_960000-960999.csv saved to ../data/tracks
#
# Slice 941 of 1000: mpd.slice.436000-436999.json
# mpd_playlists_436000-436999.csv saved to ../data/playlists
# mpd_tracks_436000-436999.csv saved to ../data/tracks
#
# Slice 942 of 1000: mpd.slice.330000-330999.json
# mpd_playlists_330000-330999.csv saved to ../data/playlists
# mpd_tracks_330000-330999.csv saved to ../data/tracks
#
# Slice 943 of 1000: mpd.slice.483000-483999.json
# mpd_playlists_483000-483999.csv saved to ../data/playlists
# mpd_tracks_483000-483999.csv saved to ../data/tracks
#
# Slice 944 of 1000: mpd.slice.385000-385999.json
# mpd_playlists_385000-385999.csv saved to ../data/playlists
# mpd_tracks_385000-385999.csv saved to ../data/tracks
#
# Slice 945 of 1000: mpd.slice.861000-861999.json
# mpd_playlists_861000-861999.csv saved to ../data/playlists
# mpd_tracks_861000-861999.csv saved to ../data/tracks
#
# Slice 946 of 1000: mpd.slice.537000-537999.json
# mpd_playlists_537000-537999.csv saved to ../data/playlists
# mpd_tracks_537000-537999.csv saved to ../data/tracks
#
# Slice 947 of 1000: mpd.slice.231000-231999.json
# mpd_playlists_231000-231999.csv saved to ../data/playlists
# mpd_tracks_231000-231999.csv saved to ../data/tracks
#
# Slice 948 of 1000: mpd.slice.64000-64999.json
# mpd_playlists_64000-64999.csv saved to ../data/playlists
# mpd_tracks_64000-64999.csv saved to ../data/tracks
#
# Slice 949 of 1000: mpd.slice.706000-706999.json
# mpd_playlists_706000-706999.csv saved to ../data/playlists
# mpd_tracks_706000-706999.csv saved to ../data/tracks
#
# Slice 950 of 1000: mpd.slice.369000-369999.json
# mpd_playlists_369000-369999.csv saved to ../data/playlists
# mpd_tracks_369000-369999.csv saved to ../data/tracks
#
# Slice 951 of 1000: mpd.slice.681000-681999.json
# mpd_playlists_681000-681999.csv saved to ../data/playlists
# mpd_tracks_681000-681999.csv saved to ../data/tracks
#
# Slice 952 of 1000: mpd.slice.939000-939999.json
# mpd_playlists_939000-939999.csv saved to ../data/playlists
# mpd_tracks_939000-939999.csv saved to ../data/tracks
#
# Slice 953 of 1000: mpd.slice.187000-187999.json
# mpd_playlists_187000-187999.csv saved to ../data/playlists
# mpd_tracks_187000-187999.csv saved to ../data/tracks
#
# Slice 954 of 1000: mpd.slice.735000-735999.json
# mpd_playlists_735000-735999.csv saved to ../data/playlists
# mpd_tracks_735000-735999.csv saved to ../data/tracks
#
# Slice 955 of 1000: mpd.slice.158000-158999.json
# mpd_playlists_158000-158999.csv saved to ../data/playlists
# mpd_tracks_158000-158999.csv saved to ../data/tracks
#
# Slice 956 of 1000: mpd.slice.202000-202999.json
# mpd_playlists_202000-202999.csv saved to ../data/playlists
# mpd_tracks_202000-202999.csv saved to ../data/tracks
#
# Slice 957 of 1000: mpd.slice.40000-40999.json
# mpd_playlists_40000-40999.csv saved to ../data/playlists
# mpd_tracks_40000-40999.csv saved to ../data/tracks
#
# Slice 958 of 1000: mpd.slice.852000-852999.json
# mpd_playlists_852000-852999.csv saved to ../data/playlists
# mpd_tracks_852000-852999.csv saved to ../data/tracks
#
# Slice 959 of 1000: mpd.slice.504000-504999.json
# mpd_playlists_504000-504999.csv saved to ../data/playlists
# mpd_tracks_504000-504999.csv saved to ../data/tracks
#
# Slice 960 of 1000: mpd.slice.303000-303999.json
# mpd_playlists_303000-303999.csv saved to ../data/playlists
# mpd_tracks_303000-303999.csv saved to ../data/tracks
#
# Slice 961 of 1000: mpd.slice.953000-953999.json
# mpd_playlists_953000-953999.csv saved to ../data/playlists
# mpd_tracks_953000-953999.csv saved to ../data/tracks
#
# Slice 962 of 1000: mpd.slice.405000-405999.json
# mpd_playlists_405000-405999.csv saved to ../data/playlists
# mpd_tracks_405000-405999.csv saved to ../data/tracks
#
# Slice 963 of 1000: mpd.slice.268000-268999.json
# mpd_playlists_268000-268999.csv saved to ../data/playlists
# mpd_tracks_268000-268999.csv saved to ../data/tracks
#
# Slice 964 of 1000: mpd.slice.780000-780999.json
# mpd_playlists_780000-780999.csv saved to ../data/playlists
# mpd_tracks_780000-780999.csv saved to ../data/tracks
#
# Slice 965 of 1000: mpd.slice.838000-838999.json
# mpd_playlists_838000-838999.csv saved to ../data/playlists
# mpd_tracks_838000-838999.csv saved to ../data/tracks
#
# Slice 966 of 1000: mpd.slice.634000-634999.json
# mpd_playlists_634000-634999.csv saved to ../data/playlists
# mpd_tracks_634000-634999.csv saved to ../data/tracks
#
# Slice 967 of 1000: mpd.slice.95000-95999.json
# mpd_playlists_95000-95999.csv saved to ../data/playlists
# mpd_tracks_95000-95999.csv saved to ../data/tracks
#
# Slice 968 of 1000: mpd.slice.132000-132999.json
# mpd_playlists_132000-132999.csv saved to ../data/playlists
# mpd_tracks_132000-132999.csv saved to ../data/tracks
#
# Slice 969 of 1000: mpd.slice.285000-285999.json
# mpd_playlists_285000-285999.csv saved to ../data/playlists
# mpd_tracks_285000-285999.csv saved to ../data/tracks
#
# Slice 970 of 1000: mpd.slice.583000-583999.json
# mpd_playlists_583000-583999.csv saved to ../data/playlists
# mpd_tracks_583000-583999.csv saved to ../data/tracks
#
# Slice 971 of 1000: mpd.slice.331000-331999.json
# mpd_playlists_331000-331999.csv saved to ../data/playlists
# mpd_tracks_331000-331999.csv saved to ../data/tracks
#
# Slice 972 of 1000: mpd.slice.961000-961999.json
# mpd_playlists_961000-961999.csv saved to ../data/playlists
# mpd_tracks_961000-961999.csv saved to ../data/tracks
#
# Slice 973 of 1000: mpd.slice.437000-437999.json
# mpd_playlists_437000-437999.csv saved to ../data/playlists
# mpd_tracks_437000-437999.csv saved to ../data/tracks
#
# Slice 974 of 1000: mpd.slice.606000-606999.json
# mpd_playlists_606000-606999.csv saved to ../data/playlists
# mpd_tracks_606000-606999.csv saved to ../data/tracks
#
# Slice 975 of 1000: mpd.slice.100000-100999.json
# mpd_playlists_100000-100999.csv saved to ../data/playlists
# mpd_tracks_100000-100999.csv saved to ../data/tracks
#
# Slice 976 of 1000: mpd.slice.707000-707999.json
# mpd_playlists_707000-707999.csv saved to ../data/playlists
# mpd_tracks_707000-707999.csv saved to ../data/tracks
#
# Slice 977 of 1000: mpd.slice.12000-12999.json
# mpd_playlists_12000-12999.csv saved to ../data/playlists
# mpd_tracks_12000-12999.csv saved to ../data/tracks
#
# Slice 978 of 1000: mpd.slice.384000-384999.json
# mpd_playlists_384000-384999.csv saved to ../data/playlists
# mpd_tracks_384000-384999.csv saved to ../data/tracks
#
# Slice 979 of 1000: mpd.slice.482000-482999.json
# mpd_playlists_482000-482999.csv saved to ../data/playlists
# mpd_tracks_482000-482999.csv saved to ../data/tracks
#
# Slice 980 of 1000: mpd.slice.230000-230999.json
# mpd_playlists_230000-230999.csv saved to ../data/playlists
# mpd_tracks_230000-230999.csv saved to ../data/tracks
#
# Slice 981 of 1000: mpd.slice.860000-860999.json
# mpd_playlists_860000-860999.csv saved to ../data/playlists
# mpd_tracks_860000-860999.csv saved to ../data/tracks
#
# Slice 982 of 1000: mpd.slice.536000-536999.json
# mpd_playlists_536000-536999.csv saved to ../data/playlists
# mpd_tracks_536000-536999.csv saved to ../data/tracks
#
# Slice 983 of 1000: mpd.slice.159000-159999.json
# mpd_playlists_159000-159999.csv saved to ../data/playlists
# mpd_tracks_159000-159999.csv saved to ../data/tracks
#
# Slice 984 of 1000: mpd.slice.853000-853999.json
# mpd_playlists_853000-853999.csv saved to ../data/playlists
# mpd_tracks_853000-853999.csv saved to ../data/tracks
#
# Slice 985 of 1000: mpd.slice.505000-505999.json
# mpd_playlists_505000-505999.csv saved to ../data/playlists
# mpd_tracks_505000-505999.csv saved to ../data/tracks
#
# Slice 986 of 1000: mpd.slice.36000-36999.json
# mpd_playlists_36000-36999.csv saved to ../data/playlists
# mpd_tracks_36000-36999.csv saved to ../data/tracks
#
# Slice 987 of 1000: mpd.slice.203000-203999.json
# mpd_playlists_203000-203999.csv saved to ../data/playlists
# mpd_tracks_203000-203999.csv saved to ../data/tracks
#
# Slice 988 of 1000: mpd.slice.186000-186999.json
# mpd_playlists_186000-186999.csv saved to ../data/playlists
# mpd_tracks_186000-186999.csv saved to ../data/tracks
#
# Slice 989 of 1000: mpd.slice.938000-938999.json
# mpd_playlists_938000-938999.csv saved to ../data/playlists
# mpd_tracks_938000-938999.csv saved to ../data/tracks
#
# Slice 990 of 1000: mpd.slice.680000-680999.json
# mpd_playlists_680000-680999.csv saved to ../data/playlists
# mpd_tracks_680000-680999.csv saved to ../data/tracks
#
# Slice 991 of 1000: mpd.slice.368000-368999.json
# mpd_playlists_368000-368999.csv saved to ../data/playlists
# mpd_tracks_368000-368999.csv saved to ../data/tracks
#
# Slice 992 of 1000: mpd.slice.734000-734999.json
# mpd_playlists_734000-734999.csv saved to ../data/playlists
# mpd_tracks_734000-734999.csv saved to ../data/tracks
#
# Slice 993 of 1000: mpd.slice.839000-839999.json
# mpd_playlists_839000-839999.csv saved to ../data/playlists
# mpd_tracks_839000-839999.csv saved to ../data/tracks
#
# Slice 994 of 1000: mpd.slice.781000-781999.json
# mpd_playlists_781000-781999.csv saved to ../data/playlists
# mpd_tracks_781000-781999.csv saved to ../data/tracks
#
# Slice 995 of 1000: mpd.slice.269000-269999.json
# mpd_playlists_269000-269999.csv saved to ../data/playlists
# mpd_tracks_269000-269999.csv saved to ../data/tracks
#
# Slice 996 of 1000: mpd.slice.133000-133999.json
# mpd_playlists_133000-133999.csv saved to ../data/playlists
# mpd_tracks_133000-133999.csv saved to ../data/tracks
#
# Slice 997 of 1000: mpd.slice.635000-635999.json
# mpd_playlists_635000-635999.csv saved to ../data/playlists
# mpd_tracks_635000-635999.csv saved to ../data/tracks
#
# Slice 998 of 1000: mpd.slice.952000-952999.json
# mpd_playlists_952000-952999.csv saved to ../data/playlists
# mpd_tracks_952000-952999.csv saved to ../data/tracks
#
# Slice 999 of 1000: mpd.slice.404000-404999.json
# mpd_playlists_404000-404999.csv saved to ../data/playlists
# mpd_tracks_404000-404999.csv saved to ../data/tracks
#
# Slice 1000 of 1000: mpd.slice.302000-302999.json
# mpd_playlists_302000-302999.csv saved to ../data/playlists
# mpd_tracks_302000-302999.csv saved to ../data/tracks

# %%
# Load all CSV slices into DF that will be exported for future easy loading
playlist_slices = os.listdir(playlist_output)

# Load the first one to get the DF formatted
df = pd.read_csv(os.path.join(playlist_output, playlist_slices.pop()))

length = len(playlist_slices) + 1

# Loop through and load the rest of the files
for num, playlist in enumerate(playlist_slices):
    print(f"Concatenating slice #{num + 2} of {length}")
    df2 = pd.read_csv(os.path.join(playlist_output, playlist))
    df = pd.concat([df, df2], ignore_index=True)

print('\nDone.\n')
# Out:
# Concatenating slice #2 of 1000
# Concatenating slice #3 of 1000
# Concatenating slice #4 of 1000
# Concatenating slice #5 of 1000
# Concatenating slice #6 of 1000
# Concatenating slice #7 of 1000
# Concatenating slice #8 of 1000
# Concatenating slice #9 of 1000
# Concatenating slice #10 of 1000
# Concatenating slice #11 of 1000
# Concatenating slice #12 of 1000
# Concatenating slice #13 of 1000
# Concatenating slice #14 of 1000
# Concatenating slice #15 of 1000
# Concatenating slice #16 of 1000
# Concatenating slice #17 of 1000
# Concatenating slice #18 of 1000
# Concatenating slice #19 of 1000
# Concatenating slice #20 of 1000
# Concatenating slice #21 of 1000
# Concatenating slice #22 of 1000
# Concatenating slice #23 of 1000
# Concatenating slice #24 of 1000
# Concatenating slice #25 of 1000
# Concatenating slice #26 of 1000
# Concatenating slice #27 of 1000
# Concatenating slice #28 of 1000
# Concatenating slice #29 of 1000
# Concatenating slice #30 of 1000
# Concatenating slice #31 of 1000
# Concatenating slice #32 of 1000
# Concatenating slice #33 of 1000
# Concatenating slice #34 of 1000
# Concatenating slice #35 of 1000
# Concatenating slice #36 of 1000
# Concatenating slice #37 of 1000
# Concatenating slice #38 of 1000
# Concatenating slice #39 of 1000
# Concatenating slice #40 of 1000
# Concatenating slice #41 of 1000
# Concatenating slice #42 of 1000
# Concatenating slice #43 of 1000
# Concatenating slice #44 of 1000
# Concatenating slice #45 of 1000
# Concatenating slice #46 of 1000
# Concatenating slice #47 of 1000
# Concatenating slice #48 of 1000
# Concatenating slice #49 of 1000
# Concatenating slice #50 of 1000
# Concatenating slice #51 of 1000
# Concatenating slice #52 of 1000
# Concatenating slice #53 of 1000
# Concatenating slice #54 of 1000
# Concatenating slice #55 of 1000
# Concatenating slice #56 of 1000
# Concatenating slice #57 of 1000
# Concatenating slice #58 of 1000
# Concatenating slice #59 of 1000
# Concatenating slice #60 of 1000
# Concatenating slice #61 of 1000
# Concatenating slice #62 of 1000
# Concatenating slice #63 of 1000
# Concatenating slice #64 of 1000
# Concatenating slice #65 of 1000
# Concatenating slice #66 of 1000
# Concatenating slice #67 of 1000
# Concatenating slice #68 of 1000
# Concatenating slice #69 of 1000
# Concatenating slice #70 of 1000
# Concatenating slice #71 of 1000
# Concatenating slice #72 of 1000
# Concatenating slice #73 of 1000
# Concatenating slice #74 of 1000
# Concatenating slice #75 of 1000
# Concatenating slice #76 of 1000
# Concatenating slice #77 of 1000
# Concatenating slice #78 of 1000
# Concatenating slice #79 of 1000
# Concatenating slice #80 of 1000
# Concatenating slice #81 of 1000
# Concatenating slice #82 of 1000
# Concatenating slice #83 of 1000
# Concatenating slice #84 of 1000
# Concatenating slice #85 of 1000
# Concatenating slice #86 of 1000
# Concatenating slice #87 of 1000
# Concatenating slice #88 of 1000
# Concatenating slice #89 of 1000
# Concatenating slice #90 of 1000
# Concatenating slice #91 of 1000
# Concatenating slice #92 of 1000
# Concatenating slice #93 of 1000
# Concatenating slice #94 of 1000
# Concatenating slice #95 of 1000
# Concatenating slice #96 of 1000
# Concatenating slice #97 of 1000
# Concatenating slice #98 of 1000
# Concatenating slice #99 of 1000
# Concatenating slice #100 of 1000
# Concatenating slice #101 of 1000
# Concatenating slice #102 of 1000
# Concatenating slice #103 of 1000
# Concatenating slice #104 of 1000
# Concatenating slice #105 of 1000
# Concatenating slice #106 of 1000
# Concatenating slice #107 of 1000
# Concatenating slice #108 of 1000
# Concatenating slice #109 of 1000
# Concatenating slice #110 of 1000
# Concatenating slice #111 of 1000
# Concatenating slice #112 of 1000
# Concatenating slice #113 of 1000
# Concatenating slice #114 of 1000
# Concatenating slice #115 of 1000
# Concatenating slice #116 of 1000
# Concatenating slice #117 of 1000
# Concatenating slice #118 of 1000
# Concatenating slice #119 of 1000
# Concatenating slice #120 of 1000
# Concatenating slice #121 of 1000
# Concatenating slice #122 of 1000
# Concatenating slice #123 of 1000
# Concatenating slice #124 of 1000
# Concatenating slice #125 of 1000
# Concatenating slice #126 of 1000
# Concatenating slice #127 of 1000
# Concatenating slice #128 of 1000
# Concatenating slice #129 of 1000
# Concatenating slice #130 of 1000
# Concatenating slice #131 of 1000
# Concatenating slice #132 of 1000
# Concatenating slice #133 of 1000
# Concatenating slice #134 of 1000
# Concatenating slice #135 of 1000
# Concatenating slice #136 of 1000
# Concatenating slice #137 of 1000
# Concatenating slice #138 of 1000
# Concatenating slice #139 of 1000
# Concatenating slice #140 of 1000
# Concatenating slice #141 of 1000
# Concatenating slice #142 of 1000
# Concatenating slice #143 of 1000
# Concatenating slice #144 of 1000
# Concatenating slice #145 of 1000
# Concatenating slice #146 of 1000
# Concatenating slice #147 of 1000
# Concatenating slice #148 of 1000
# Concatenating slice #149 of 1000
# Concatenating slice #150 of 1000
# Concatenating slice #151 of 1000
# Concatenating slice #152 of 1000
# Concatenating slice #153 of 1000
# Concatenating slice #154 of 1000
# Concatenating slice #155 of 1000
# Concatenating slice #156 of 1000
# Concatenating slice #157 of 1000
# Concatenating slice #158 of 1000
# Concatenating slice #159 of 1000
# Concatenating slice #160 of 1000
# Concatenating slice #161 of 1000
# Concatenating slice #162 of 1000
# Concatenating slice #163 of 1000
# Concatenating slice #164 of 1000
# Concatenating slice #165 of 1000
# Concatenating slice #166 of 1000
# Concatenating slice #167 of 1000
# Concatenating slice #168 of 1000
# Concatenating slice #169 of 1000
# Concatenating slice #170 of 1000
# Concatenating slice #171 of 1000
# Concatenating slice #172 of 1000
# Concatenating slice #173 of 1000
# Concatenating slice #174 of 1000
# Concatenating slice #175 of 1000
# Concatenating slice #176 of 1000
# Concatenating slice #177 of 1000
# Concatenating slice #178 of 1000
# Concatenating slice #179 of 1000
# Concatenating slice #180 of 1000
# Concatenating slice #181 of 1000
# Concatenating slice #182 of 1000
# Concatenating slice #183 of 1000
# Concatenating slice #184 of 1000
# Concatenating slice #185 of 1000
# Concatenating slice #186 of 1000
# Concatenating slice #187 of 1000
# Concatenating slice #188 of 1000
# Concatenating slice #189 of 1000
# Concatenating slice #190 of 1000
# Concatenating slice #191 of 1000
# Concatenating slice #192 of 1000
# Concatenating slice #193 of 1000
# Concatenating slice #194 of 1000
# Concatenating slice #195 of 1000
# Concatenating slice #196 of 1000
# Concatenating slice #197 of 1000
# Concatenating slice #198 of 1000
# Concatenating slice #199 of 1000
# Concatenating slice #200 of 1000
# Concatenating slice #201 of 1000
# Concatenating slice #202 of 1000
# Concatenating slice #203 of 1000
# Concatenating slice #204 of 1000
# Concatenating slice #205 of 1000
# Concatenating slice #206 of 1000
# Concatenating slice #207 of 1000
# Concatenating slice #208 of 1000
# Concatenating slice #209 of 1000
# Concatenating slice #210 of 1000
# Concatenating slice #211 of 1000
# Concatenating slice #212 of 1000
# Concatenating slice #213 of 1000
# Concatenating slice #214 of 1000
# Concatenating slice #215 of 1000
# Concatenating slice #216 of 1000
# Concatenating slice #217 of 1000
# Concatenating slice #218 of 1000
# Concatenating slice #219 of 1000
# Concatenating slice #220 of 1000
# Concatenating slice #221 of 1000
# Concatenating slice #222 of 1000
# Concatenating slice #223 of 1000
# Concatenating slice #224 of 1000
# Concatenating slice #225 of 1000
# Concatenating slice #226 of 1000
# Concatenating slice #227 of 1000
# Concatenating slice #228 of 1000
# Concatenating slice #229 of 1000
# Concatenating slice #230 of 1000
# Concatenating slice #231 of 1000
# Concatenating slice #232 of 1000
# Concatenating slice #233 of 1000
# Concatenating slice #234 of 1000
# Concatenating slice #235 of 1000
# Concatenating slice #236 of 1000
# Concatenating slice #237 of 1000
# Concatenating slice #238 of 1000
# Concatenating slice #239 of 1000
# Concatenating slice #240 of 1000
# Concatenating slice #241 of 1000
# Concatenating slice #242 of 1000
# Concatenating slice #243 of 1000
# Concatenating slice #244 of 1000
# Concatenating slice #245 of 1000
# Concatenating slice #246 of 1000
# Concatenating slice #247 of 1000
# Concatenating slice #248 of 1000
# Concatenating slice #249 of 1000
# Concatenating slice #250 of 1000
# Concatenating slice #251 of 1000
# Concatenating slice #252 of 1000
# Concatenating slice #253 of 1000
# Concatenating slice #254 of 1000
# Concatenating slice #255 of 1000
# Concatenating slice #256 of 1000
# Concatenating slice #257 of 1000
# Concatenating slice #258 of 1000
# Concatenating slice #259 of 1000
# Concatenating slice #260 of 1000
# Concatenating slice #261 of 1000
# Concatenating slice #262 of 1000
# Concatenating slice #263 of 1000
# Concatenating slice #264 of 1000
# Concatenating slice #265 of 1000
# Concatenating slice #266 of 1000
# Concatenating slice #267 of 1000
# Concatenating slice #268 of 1000
# Concatenating slice #269 of 1000
# Concatenating slice #270 of 1000
# Concatenating slice #271 of 1000
# Concatenating slice #272 of 1000
# Concatenating slice #273 of 1000
# Concatenating slice #274 of 1000
# Concatenating slice #275 of 1000
# Concatenating slice #276 of 1000
# Concatenating slice #277 of 1000
# Concatenating slice #278 of 1000
# Concatenating slice #279 of 1000
# Concatenating slice #280 of 1000
# Concatenating slice #281 of 1000
# Concatenating slice #282 of 1000
# Concatenating slice #283 of 1000
# Concatenating slice #284 of 1000
# Concatenating slice #285 of 1000
# Concatenating slice #286 of 1000
# Concatenating slice #287 of 1000
# Concatenating slice #288 of 1000
# Concatenating slice #289 of 1000
# Concatenating slice #290 of 1000
# Concatenating slice #291 of 1000
# Concatenating slice #292 of 1000
# Concatenating slice #293 of 1000
# Concatenating slice #294 of 1000
# Concatenating slice #295 of 1000
# Concatenating slice #296 of 1000
# Concatenating slice #297 of 1000
# Concatenating slice #298 of 1000
# Concatenating slice #299 of 1000
# Concatenating slice #300 of 1000
# Concatenating slice #301 of 1000
# Concatenating slice #302 of 1000
# Concatenating slice #303 of 1000
# Concatenating slice #304 of 1000
# Concatenating slice #305 of 1000
# Concatenating slice #306 of 1000
# Concatenating slice #307 of 1000
# Concatenating slice #308 of 1000
# Concatenating slice #309 of 1000
# Concatenating slice #310 of 1000
# Concatenating slice #311 of 1000
# Concatenating slice #312 of 1000
# Concatenating slice #313 of 1000
# Concatenating slice #314 of 1000
# Concatenating slice #315 of 1000
# Concatenating slice #316 of 1000
# Concatenating slice #317 of 1000
# Concatenating slice #318 of 1000
# Concatenating slice #319 of 1000
# Concatenating slice #320 of 1000
# Concatenating slice #321 of 1000
# Concatenating slice #322 of 1000
# Concatenating slice #323 of 1000
# Concatenating slice #324 of 1000
# Concatenating slice #325 of 1000
# Concatenating slice #326 of 1000
# Concatenating slice #327 of 1000
# Concatenating slice #328 of 1000
# Concatenating slice #329 of 1000
# Concatenating slice #330 of 1000
# Concatenating slice #331 of 1000
# Concatenating slice #332 of 1000
# Concatenating slice #333 of 1000
# Concatenating slice #334 of 1000
# Concatenating slice #335 of 1000
# Concatenating slice #336 of 1000
# Concatenating slice #337 of 1000
# Concatenating slice #338 of 1000
# Concatenating slice #339 of 1000
# Concatenating slice #340 of 1000
# Concatenating slice #341 of 1000
# Concatenating slice #342 of 1000
# Concatenating slice #343 of 1000
# Concatenating slice #344 of 1000
# Concatenating slice #345 of 1000
# Concatenating slice #346 of 1000
# Concatenating slice #347 of 1000
# Concatenating slice #348 of 1000
# Concatenating slice #349 of 1000
# Concatenating slice #350 of 1000
# Concatenating slice #351 of 1000
# Concatenating slice #352 of 1000
# Concatenating slice #353 of 1000
# Concatenating slice #354 of 1000
# Concatenating slice #355 of 1000
# Concatenating slice #356 of 1000
# Concatenating slice #357 of 1000
# Concatenating slice #358 of 1000
# Concatenating slice #359 of 1000
# Concatenating slice #360 of 1000
# Concatenating slice #361 of 1000
# Concatenating slice #362 of 1000
# Concatenating slice #363 of 1000
# Concatenating slice #364 of 1000
# Concatenating slice #365 of 1000
# Concatenating slice #366 of 1000
# Concatenating slice #367 of 1000
# Concatenating slice #368 of 1000
# Concatenating slice #369 of 1000
# Concatenating slice #370 of 1000
# Concatenating slice #371 of 1000
# Concatenating slice #372 of 1000
# Concatenating slice #373 of 1000
# Concatenating slice #374 of 1000
# Concatenating slice #375 of 1000
# Concatenating slice #376 of 1000
# Concatenating slice #377 of 1000
# Concatenating slice #378 of 1000
# Concatenating slice #379 of 1000
# Concatenating slice #380 of 1000
# Concatenating slice #381 of 1000
# Concatenating slice #382 of 1000
# Concatenating slice #383 of 1000
# Concatenating slice #384 of 1000
# Concatenating slice #385 of 1000
# Concatenating slice #386 of 1000
# Concatenating slice #387 of 1000
# Concatenating slice #388 of 1000
# Concatenating slice #389 of 1000
# Concatenating slice #390 of 1000
# Concatenating slice #391 of 1000
# Concatenating slice #392 of 1000
# Concatenating slice #393 of 1000
# Concatenating slice #394 of 1000
# Concatenating slice #395 of 1000
# Concatenating slice #396 of 1000
# Concatenating slice #397 of 1000
# Concatenating slice #398 of 1000
# Concatenating slice #399 of 1000
# Concatenating slice #400 of 1000
# Concatenating slice #401 of 1000
# Concatenating slice #402 of 1000
# Concatenating slice #403 of 1000
# Concatenating slice #404 of 1000
# Concatenating slice #405 of 1000
# Concatenating slice #406 of 1000
# Concatenating slice #407 of 1000
# Concatenating slice #408 of 1000
# Concatenating slice #409 of 1000
# Concatenating slice #410 of 1000
# Concatenating slice #411 of 1000
# Concatenating slice #412 of 1000
# Concatenating slice #413 of 1000
# Concatenating slice #414 of 1000
# Concatenating slice #415 of 1000
# Concatenating slice #416 of 1000
# Concatenating slice #417 of 1000
# Concatenating slice #418 of 1000
# Concatenating slice #419 of 1000
# Concatenating slice #420 of 1000
# Concatenating slice #421 of 1000
# Concatenating slice #422 of 1000
# Concatenating slice #423 of 1000
# Concatenating slice #424 of 1000
# Concatenating slice #425 of 1000
# Concatenating slice #426 of 1000
# Concatenating slice #427 of 1000
# Concatenating slice #428 of 1000
# Concatenating slice #429 of 1000
# Concatenating slice #430 of 1000
# Concatenating slice #431 of 1000
# Concatenating slice #432 of 1000
# Concatenating slice #433 of 1000
# Concatenating slice #434 of 1000
# Concatenating slice #435 of 1000
# Concatenating slice #436 of 1000
# Concatenating slice #437 of 1000
# Concatenating slice #438 of 1000
# Concatenating slice #439 of 1000
# Concatenating slice #440 of 1000
# Concatenating slice #441 of 1000
# Concatenating slice #442 of 1000
# Concatenating slice #443 of 1000
# Concatenating slice #444 of 1000
# Concatenating slice #445 of 1000
# Concatenating slice #446 of 1000
# Concatenating slice #447 of 1000
# Concatenating slice #448 of 1000
# Concatenating slice #449 of 1000
# Concatenating slice #450 of 1000
# Concatenating slice #451 of 1000
# Concatenating slice #452 of 1000
# Concatenating slice #453 of 1000
# Concatenating slice #454 of 1000
# Concatenating slice #455 of 1000
# Concatenating slice #456 of 1000
# Concatenating slice #457 of 1000
# Concatenating slice #458 of 1000
# Concatenating slice #459 of 1000
# Concatenating slice #460 of 1000
# Concatenating slice #461 of 1000
# Concatenating slice #462 of 1000
# Concatenating slice #463 of 1000
# Concatenating slice #464 of 1000
# Concatenating slice #465 of 1000
# Concatenating slice #466 of 1000
# Concatenating slice #467 of 1000
# Concatenating slice #468 of 1000
# Concatenating slice #469 of 1000
# Concatenating slice #470 of 1000
# Concatenating slice #471 of 1000
# Concatenating slice #472 of 1000
# Concatenating slice #473 of 1000
# Concatenating slice #474 of 1000
# Concatenating slice #475 of 1000
# Concatenating slice #476 of 1000
# Concatenating slice #477 of 1000
# Concatenating slice #478 of 1000
# Concatenating slice #479 of 1000
# Concatenating slice #480 of 1000
# Concatenating slice #481 of 1000
# Concatenating slice #482 of 1000
# Concatenating slice #483 of 1000
# Concatenating slice #484 of 1000
# Concatenating slice #485 of 1000
# Concatenating slice #486 of 1000
# Concatenating slice #487 of 1000
# Concatenating slice #488 of 1000
# Concatenating slice #489 of 1000
# Concatenating slice #490 of 1000
# Concatenating slice #491 of 1000
# Concatenating slice #492 of 1000
# Concatenating slice #493 of 1000
# Concatenating slice #494 of 1000
# Concatenating slice #495 of 1000
# Concatenating slice #496 of 1000
# Concatenating slice #497 of 1000
# Concatenating slice #498 of 1000
# Concatenating slice #499 of 1000
# Concatenating slice #500 of 1000
# Concatenating slice #501 of 1000
# Concatenating slice #502 of 1000
# Concatenating slice #503 of 1000
# Concatenating slice #504 of 1000
# Concatenating slice #505 of 1000
# Concatenating slice #506 of 1000
# Concatenating slice #507 of 1000
# Concatenating slice #508 of 1000
# Concatenating slice #509 of 1000
# Concatenating slice #510 of 1000
# Concatenating slice #511 of 1000
# Concatenating slice #512 of 1000
# Concatenating slice #513 of 1000
# Concatenating slice #514 of 1000
# Concatenating slice #515 of 1000
# Concatenating slice #516 of 1000
# Concatenating slice #517 of 1000
# Concatenating slice #518 of 1000
# Concatenating slice #519 of 1000
# Concatenating slice #520 of 1000
# Concatenating slice #521 of 1000
# Concatenating slice #522 of 1000
# Concatenating slice #523 of 1000
# Concatenating slice #524 of 1000
# Concatenating slice #525 of 1000
# Concatenating slice #526 of 1000
# Concatenating slice #527 of 1000
# Concatenating slice #528 of 1000
# Concatenating slice #529 of 1000
# Concatenating slice #530 of 1000
# Concatenating slice #531 of 1000
# Concatenating slice #532 of 1000
# Concatenating slice #533 of 1000
# Concatenating slice #534 of 1000
# Concatenating slice #535 of 1000
# Concatenating slice #536 of 1000
# Concatenating slice #537 of 1000
# Concatenating slice #538 of 1000
# Concatenating slice #539 of 1000
# Concatenating slice #540 of 1000
# Concatenating slice #541 of 1000
# Concatenating slice #542 of 1000
# Concatenating slice #543 of 1000
# Concatenating slice #544 of 1000
# Concatenating slice #545 of 1000
# Concatenating slice #546 of 1000
# Concatenating slice #547 of 1000
# Concatenating slice #548 of 1000
# Concatenating slice #549 of 1000
# Concatenating slice #550 of 1000
# Concatenating slice #551 of 1000
# Concatenating slice #552 of 1000
# Concatenating slice #553 of 1000
# Concatenating slice #554 of 1000
# Concatenating slice #555 of 1000
# Concatenating slice #556 of 1000
# Concatenating slice #557 of 1000
# Concatenating slice #558 of 1000
# Concatenating slice #559 of 1000
# Concatenating slice #560 of 1000
# Concatenating slice #561 of 1000
# Concatenating slice #562 of 1000
# Concatenating slice #563 of 1000
# Concatenating slice #564 of 1000
# Concatenating slice #565 of 1000
# Concatenating slice #566 of 1000
# Concatenating slice #567 of 1000
# Concatenating slice #568 of 1000
# Concatenating slice #569 of 1000
# Concatenating slice #570 of 1000
# Concatenating slice #571 of 1000
# Concatenating slice #572 of 1000
# Concatenating slice #573 of 1000
# Concatenating slice #574 of 1000
# Concatenating slice #575 of 1000
# Concatenating slice #576 of 1000
# Concatenating slice #577 of 1000
# Concatenating slice #578 of 1000
# Concatenating slice #579 of 1000
# Concatenating slice #580 of 1000
# Concatenating slice #581 of 1000
# Concatenating slice #582 of 1000
# Concatenating slice #583 of 1000
# Concatenating slice #584 of 1000
# Concatenating slice #585 of 1000
# Concatenating slice #586 of 1000
# Concatenating slice #587 of 1000
# Concatenating slice #588 of 1000
# Concatenating slice #589 of 1000
# Concatenating slice #590 of 1000
# Concatenating slice #591 of 1000
# Concatenating slice #592 of 1000
# Concatenating slice #593 of 1000
# Concatenating slice #594 of 1000
# Concatenating slice #595 of 1000
# Concatenating slice #596 of 1000
# Concatenating slice #597 of 1000
# Concatenating slice #598 of 1000
# Concatenating slice #599 of 1000
# Concatenating slice #600 of 1000
# Concatenating slice #601 of 1000
# Concatenating slice #602 of 1000
# Concatenating slice #603 of 1000
# Concatenating slice #604 of 1000
# Concatenating slice #605 of 1000
# Concatenating slice #606 of 1000
# Concatenating slice #607 of 1000
# Concatenating slice #608 of 1000
# Concatenating slice #609 of 1000
# Concatenating slice #610 of 1000
# Concatenating slice #611 of 1000
# Concatenating slice #612 of 1000
# Concatenating slice #613 of 1000
# Concatenating slice #614 of 1000
# Concatenating slice #615 of 1000
# Concatenating slice #616 of 1000
# Concatenating slice #617 of 1000
# Concatenating slice #618 of 1000
# Concatenating slice #619 of 1000
# Concatenating slice #620 of 1000
# Concatenating slice #621 of 1000
# Concatenating slice #622 of 1000
# Concatenating slice #623 of 1000
# Concatenating slice #624 of 1000
# Concatenating slice #625 of 1000
# Concatenating slice #626 of 1000
# Concatenating slice #627 of 1000
# Concatenating slice #628 of 1000
# Concatenating slice #629 of 1000
# Concatenating slice #630 of 1000
# Concatenating slice #631 of 1000
# Concatenating slice #632 of 1000
# Concatenating slice #633 of 1000
# Concatenating slice #634 of 1000
# Concatenating slice #635 of 1000
# Concatenating slice #636 of 1000
# Concatenating slice #637 of 1000
# Concatenating slice #638 of 1000
# Concatenating slice #639 of 1000
# Concatenating slice #640 of 1000
# Concatenating slice #641 of 1000
# Concatenating slice #642 of 1000
# Concatenating slice #643 of 1000
# Concatenating slice #644 of 1000
# Concatenating slice #645 of 1000
# Concatenating slice #646 of 1000
# Concatenating slice #647 of 1000
# Concatenating slice #648 of 1000
# Concatenating slice #649 of 1000
# Concatenating slice #650 of 1000
# Concatenating slice #651 of 1000
# Concatenating slice #652 of 1000
# Concatenating slice #653 of 1000
# Concatenating slice #654 of 1000
# Concatenating slice #655 of 1000
# Concatenating slice #656 of 1000
# Concatenating slice #657 of 1000
# Concatenating slice #658 of 1000
# Concatenating slice #659 of 1000
# Concatenating slice #660 of 1000
# Concatenating slice #661 of 1000
# Concatenating slice #662 of 1000
# Concatenating slice #663 of 1000
# Concatenating slice #664 of 1000
# Concatenating slice #665 of 1000
# Concatenating slice #666 of 1000
# Concatenating slice #667 of 1000
# Concatenating slice #668 of 1000
# Concatenating slice #669 of 1000
# Concatenating slice #670 of 1000
# Concatenating slice #671 of 1000
# Concatenating slice #672 of 1000
# Concatenating slice #673 of 1000
# Concatenating slice #674 of 1000
# Concatenating slice #675 of 1000
# Concatenating slice #676 of 1000
# Concatenating slice #677 of 1000
# Concatenating slice #678 of 1000
# Concatenating slice #679 of 1000
# Concatenating slice #680 of 1000
# Concatenating slice #681 of 1000
# Concatenating slice #682 of 1000
# Concatenating slice #683 of 1000
# Concatenating slice #684 of 1000
# Concatenating slice #685 of 1000
# Concatenating slice #686 of 1000
# Concatenating slice #687 of 1000
# Concatenating slice #688 of 1000
# Concatenating slice #689 of 1000
# Concatenating slice #690 of 1000
# Concatenating slice #691 of 1000
# Concatenating slice #692 of 1000
# Concatenating slice #693 of 1000
# Concatenating slice #694 of 1000
# Concatenating slice #695 of 1000
# Concatenating slice #696 of 1000
# Concatenating slice #697 of 1000
# Concatenating slice #698 of 1000
# Concatenating slice #699 of 1000
# Concatenating slice #700 of 1000
# Concatenating slice #701 of 1000
# Concatenating slice #702 of 1000
# Concatenating slice #703 of 1000
# Concatenating slice #704 of 1000
# Concatenating slice #705 of 1000
# Concatenating slice #706 of 1000
# Concatenating slice #707 of 1000
# Concatenating slice #708 of 1000
# Concatenating slice #709 of 1000
# Concatenating slice #710 of 1000
# Concatenating slice #711 of 1000
# Concatenating slice #712 of 1000
# Concatenating slice #713 of 1000
# Concatenating slice #714 of 1000
# Concatenating slice #715 of 1000
# Concatenating slice #716 of 1000
# Concatenating slice #717 of 1000
# Concatenating slice #718 of 1000
# Concatenating slice #719 of 1000
# Concatenating slice #720 of 1000
# Concatenating slice #721 of 1000
# Concatenating slice #722 of 1000
# Concatenating slice #723 of 1000
# Concatenating slice #724 of 1000
# Concatenating slice #725 of 1000
# Concatenating slice #726 of 1000
# Concatenating slice #727 of 1000
# Concatenating slice #728 of 1000
# Concatenating slice #729 of 1000
# Concatenating slice #730 of 1000
# Concatenating slice #731 of 1000
# Concatenating slice #732 of 1000
# Concatenating slice #733 of 1000
# Concatenating slice #734 of 1000
# Concatenating slice #735 of 1000
# Concatenating slice #736 of 1000
# Concatenating slice #737 of 1000
# Concatenating slice #738 of 1000
# Concatenating slice #739 of 1000
# Concatenating slice #740 of 1000
# Concatenating slice #741 of 1000
# Concatenating slice #742 of 1000
# Concatenating slice #743 of 1000
# Concatenating slice #744 of 1000
# Concatenating slice #745 of 1000
# Concatenating slice #746 of 1000
# Concatenating slice #747 of 1000
# Concatenating slice #748 of 1000
# Concatenating slice #749 of 1000
# Concatenating slice #750 of 1000
# Concatenating slice #751 of 1000
# Concatenating slice #752 of 1000
# Concatenating slice #753 of 1000
# Concatenating slice #754 of 1000
# Concatenating slice #755 of 1000
# Concatenating slice #756 of 1000
# Concatenating slice #757 of 1000
# Concatenating slice #758 of 1000
# Concatenating slice #759 of 1000
# Concatenating slice #760 of 1000
# Concatenating slice #761 of 1000
# Concatenating slice #762 of 1000
# Concatenating slice #763 of 1000
# Concatenating slice #764 of 1000
# Concatenating slice #765 of 1000
# Concatenating slice #766 of 1000
# Concatenating slice #767 of 1000
# Concatenating slice #768 of 1000
# Concatenating slice #769 of 1000
# Concatenating slice #770 of 1000
# Concatenating slice #771 of 1000
# Concatenating slice #772 of 1000
# Concatenating slice #773 of 1000
# Concatenating slice #774 of 1000
# Concatenating slice #775 of 1000
# Concatenating slice #776 of 1000
# Concatenating slice #777 of 1000
# Concatenating slice #778 of 1000
# Concatenating slice #779 of 1000
# Concatenating slice #780 of 1000
# Concatenating slice #781 of 1000
# Concatenating slice #782 of 1000
# Concatenating slice #783 of 1000
# Concatenating slice #784 of 1000
# Concatenating slice #785 of 1000
# Concatenating slice #786 of 1000
# Concatenating slice #787 of 1000
# Concatenating slice #788 of 1000
# Concatenating slice #789 of 1000
# Concatenating slice #790 of 1000
# Concatenating slice #791 of 1000
# Concatenating slice #792 of 1000
# Concatenating slice #793 of 1000
# Concatenating slice #794 of 1000
# Concatenating slice #795 of 1000
# Concatenating slice #796 of 1000
# Concatenating slice #797 of 1000
# Concatenating slice #798 of 1000
# Concatenating slice #799 of 1000
# Concatenating slice #800 of 1000
# Concatenating slice #801 of 1000
# Concatenating slice #802 of 1000
# Concatenating slice #803 of 1000
# Concatenating slice #804 of 1000
# Concatenating slice #805 of 1000
# Concatenating slice #806 of 1000
# Concatenating slice #807 of 1000
# Concatenating slice #808 of 1000
# Concatenating slice #809 of 1000
# Concatenating slice #810 of 1000
# Concatenating slice #811 of 1000
# Concatenating slice #812 of 1000
# Concatenating slice #813 of 1000
# Concatenating slice #814 of 1000
# Concatenating slice #815 of 1000
# Concatenating slice #816 of 1000
# Concatenating slice #817 of 1000
# Concatenating slice #818 of 1000
# Concatenating slice #819 of 1000
# Concatenating slice #820 of 1000
# Concatenating slice #821 of 1000
# Concatenating slice #822 of 1000
# Concatenating slice #823 of 1000
# Concatenating slice #824 of 1000
# Concatenating slice #825 of 1000
# Concatenating slice #826 of 1000
# Concatenating slice #827 of 1000
# Concatenating slice #828 of 1000
# Concatenating slice #829 of 1000
# Concatenating slice #830 of 1000
# Concatenating slice #831 of 1000
# Concatenating slice #832 of 1000
# Concatenating slice #833 of 1000
# Concatenating slice #834 of 1000
# Concatenating slice #835 of 1000
# Concatenating slice #836 of 1000
# Concatenating slice #837 of 1000
# Concatenating slice #838 of 1000
# Concatenating slice #839 of 1000
# Concatenating slice #840 of 1000
# Concatenating slice #841 of 1000
# Concatenating slice #842 of 1000
# Concatenating slice #843 of 1000
# Concatenating slice #844 of 1000
# Concatenating slice #845 of 1000
# Concatenating slice #846 of 1000
# Concatenating slice #847 of 1000
# Concatenating slice #848 of 1000
# Concatenating slice #849 of 1000
# Concatenating slice #850 of 1000
# Concatenating slice #851 of 1000
# Concatenating slice #852 of 1000
# Concatenating slice #853 of 1000
# Concatenating slice #854 of 1000
# Concatenating slice #855 of 1000
# Concatenating slice #856 of 1000
# Concatenating slice #857 of 1000
# Concatenating slice #858 of 1000
# Concatenating slice #859 of 1000
# Concatenating slice #860 of 1000
# Concatenating slice #861 of 1000
# Concatenating slice #862 of 1000
# Concatenating slice #863 of 1000
# Concatenating slice #864 of 1000
# Concatenating slice #865 of 1000
# Concatenating slice #866 of 1000
# Concatenating slice #867 of 1000
# Concatenating slice #868 of 1000
# Concatenating slice #869 of 1000
# Concatenating slice #870 of 1000
# Concatenating slice #871 of 1000
# Concatenating slice #872 of 1000
# Concatenating slice #873 of 1000
# Concatenating slice #874 of 1000
# Concatenating slice #875 of 1000
# Concatenating slice #876 of 1000
# Concatenating slice #877 of 1000
# Concatenating slice #878 of 1000
# Concatenating slice #879 of 1000
# Concatenating slice #880 of 1000
# Concatenating slice #881 of 1000
# Concatenating slice #882 of 1000
# Concatenating slice #883 of 1000
# Concatenating slice #884 of 1000
# Concatenating slice #885 of 1000
# Concatenating slice #886 of 1000
# Concatenating slice #887 of 1000
# Concatenating slice #888 of 1000
# Concatenating slice #889 of 1000
# Concatenating slice #890 of 1000
# Concatenating slice #891 of 1000
# Concatenating slice #892 of 1000
# Concatenating slice #893 of 1000
# Concatenating slice #894 of 1000
# Concatenating slice #895 of 1000
# Concatenating slice #896 of 1000
# Concatenating slice #897 of 1000
# Concatenating slice #898 of 1000
# Concatenating slice #899 of 1000
# Concatenating slice #900 of 1000
# Concatenating slice #901 of 1000
# Concatenating slice #902 of 1000
# Concatenating slice #903 of 1000
# Concatenating slice #904 of 1000
# Concatenating slice #905 of 1000
# Concatenating slice #906 of 1000
# Concatenating slice #907 of 1000
# Concatenating slice #908 of 1000
# Concatenating slice #909 of 1000
# Concatenating slice #910 of 1000
# Concatenating slice #911 of 1000
# Concatenating slice #912 of 1000
# Concatenating slice #913 of 1000
# Concatenating slice #914 of 1000
# Concatenating slice #915 of 1000
# Concatenating slice #916 of 1000
# Concatenating slice #917 of 1000
# Concatenating slice #918 of 1000
# Concatenating slice #919 of 1000
# Concatenating slice #920 of 1000
# Concatenating slice #921 of 1000
# Concatenating slice #922 of 1000
# Concatenating slice #923 of 1000
# Concatenating slice #924 of 1000
# Concatenating slice #925 of 1000
# Concatenating slice #926 of 1000
# Concatenating slice #927 of 1000
# Concatenating slice #928 of 1000
# Concatenating slice #929 of 1000
# Concatenating slice #930 of 1000
# Concatenating slice #931 of 1000
# Concatenating slice #932 of 1000
# Concatenating slice #933 of 1000
# Concatenating slice #934 of 1000
# Concatenating slice #935 of 1000
# Concatenating slice #936 of 1000
# Concatenating slice #937 of 1000
# Concatenating slice #938 of 1000
# Concatenating slice #939 of 1000
# Concatenating slice #940 of 1000
# Concatenating slice #941 of 1000
# Concatenating slice #942 of 1000
# Concatenating slice #943 of 1000
# Concatenating slice #944 of 1000
# Concatenating slice #945 of 1000
# Concatenating slice #946 of 1000
# Concatenating slice #947 of 1000
# Concatenating slice #948 of 1000
# Concatenating slice #949 of 1000
# Concatenating slice #950 of 1000
# Concatenating slice #951 of 1000
# Concatenating slice #952 of 1000
# Concatenating slice #953 of 1000
# Concatenating slice #954 of 1000
# Concatenating slice #955 of 1000
# Concatenating slice #956 of 1000
# Concatenating slice #957 of 1000
# Concatenating slice #958 of 1000
# Concatenating slice #959 of 1000
# Concatenating slice #960 of 1000
# Concatenating slice #961 of 1000
# Concatenating slice #962 of 1000
# Concatenating slice #963 of 1000
# Concatenating slice #964 of 1000
# Concatenating slice #965 of 1000
# Concatenating slice #966 of 1000
# Concatenating slice #967 of 1000
# Concatenating slice #968 of 1000
# Concatenating slice #969 of 1000
# Concatenating slice #970 of 1000
# Concatenating slice #971 of 1000
# Concatenating slice #972 of 1000
# Concatenating slice #973 of 1000
# Concatenating slice #974 of 1000
# Concatenating slice #975 of 1000
# Concatenating slice #976 of 1000
# Concatenating slice #977 of 1000
# Concatenating slice #978 of 1000
# Concatenating slice #979 of 1000
# Concatenating slice #980 of 1000
# Concatenating slice #981 of 1000
# Concatenating slice #982 of 1000
# Concatenating slice #983 of 1000
# Concatenating slice #984 of 1000
# Concatenating slice #985 of 1000
# Concatenating slice #986 of 1000
# Concatenating slice #987 of 1000
# Concatenating slice #988 of 1000
# Concatenating slice #989 of 1000
# Concatenating slice #990 of 1000
# Concatenating slice #991 of 1000
# Concatenating slice #992 of 1000
# Concatenating slice #993 of 1000
# Concatenating slice #994 of 1000
# Concatenating slice #995 of 1000
# Concatenating slice #996 of 1000
# Concatenating slice #997 of 1000
# Concatenating slice #998 of 1000
# Concatenating slice #999 of 1000
# Concatenating slice #1000 of 1000
#
# Done.

# %%
df
# Out:
#            pid             name description  modified_at  num_artists  \
# 0       434000              Sad         NaN   1488240000           24
# 1       434001             pb&j   faves tbh   1487808000           35
# 2       434002        Sexy Time         NaN   1473379200           36
# 3       434003          bedroom         NaN   1436572800           14
# 4       434004         Whatever         NaN   1506816000           36
# ...        ...              ...         ...          ...          ...
# 999995  546995            feels         NaN   1509408000           49
# 999996  546996         Fall '15         NaN   1452902400          126
# 999997  546997           oldies         NaN   1507161600           52
# 999998  546998      Summer 2014         NaN   1408579200            8
# 999999  546999  2015 Top Tracks         NaN   1449446400           71
#
#         num_albums  num_tracks  num_followers  num_edits  duration_ms  ...  \
# 0               26          27              1          6      6081757  ...
# 1               38          39              1          9      8959761  ...
# 2               57          67             21         43     17493934  ...
# 3               15          15              1         12      3334671  ...
# 4               57          79              1         46     18874072  ...
# ...            ...         ...            ...        ...          ...  ...
# 999995          56          63              6         36     14977345  ...
# 999996         135         144              2         58     31938990  ...
# 999997          69          91              4         25     20987893  ...
# 999998           8           8              1          4      1659303  ...
# 999999          84         100              1          2     23164861  ...
#
#                           track_12_artist_uri  \
# 0       spotify:artist:5lKZWd6HiSCLfnDGrq9RAm
# 1       spotify:artist:5T0MSzX9RC5NA6gAI6irSn
# 2       spotify:artist:1P8IfcNKwrkQP5xJWuhaOC
# 3       spotify:artist:2iojnBLj0qIMiKPvVhLnsH
# 4       spotify:artist:6l3HvQ5sa6mXTsMTB19rO5
# ...                                       ...
# 999995  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 999996  spotify:artist:4OtFSn9UYWzNX9bGUf5G9W
# 999997  spotify:artist:6jJ0s89eD6GaHleKKya26X
# 999998                                      0
# 999999  spotify:artist:7ITd48RbLVpUfheE7B86o2
#
#                                 track_13_uri  \
# 0       spotify:track:1aBO5KPwxqLESNTTJBR6VP
# 1       spotify:track:7BHPGtpuuWWsvE7cCaMuEU
# 2       spotify:track:6Ms01Gqi8gVBs14YrNUlVZ
# 3       spotify:track:4xNbgOhQHofZJySyySbPG1
# 4       spotify:track:1yYzuNd0KRyHVJ3NH8apBt
# ...                                      ...
# 999995  spotify:track:3OMh7VdOoWgtKhJimQQywz
# 999996  spotify:track:7BC0mX45eSWGubU13m6dH8
# 999997  spotify:track:5fVZC9GiM4e8vu99W0Xf6J
# 999998                                     0
# 999999  spotify:track:3omXshBamrREltcf24gYDC
#
#                           track_13_album_uri  \
# 0       spotify:album:0KMy4eY3BziwZPkVfFHP5v
# 1       spotify:album:03JPFQvZRnHHysSZrSFmKY
# 2       spotify:album:1MXR2vMRldZITKc1Zk6bLe
# 3       spotify:album:0DMQC8fJn3TR3xUgLU6jDg
# 4       spotify:album:2kuF4nm4R2bcwBKvnvRbTW
# ...                                      ...
# 999995  spotify:album:07WV4Vf6503k6K1yGNWG8X
# 999996  spotify:album:1oQUa18tr6i27gKmO7LX1J
# 999997  spotify:album:1IM3GwptCGYjRkzCBolyFK
# 999998                                     0
# 999999  spotify:album:2H09itV5a5yUcGyk9u9HwY
#
#                           track_13_artist_uri  \
# 0       spotify:artist:5UOLfDoNQJBGlGAKQg9Iwc
# 1       spotify:artist:1GLtl8uqKmnyCWxHmw9tL4
# 2       spotify:artist:336vr2M3Va0FjyvB55lJEd
# 3       spotify:artist:1Xfmvd48oOhEWkscWyEbh9
# 4       spotify:artist:4LLpKhyESsyAXpc4laK94U
# ...                                       ...
# 999995  spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH
# 999996  spotify:artist:536osqBGKzeozje8BfcGsa
# 999997  spotify:artist:0zOcE3mg9nS6l3yxt1Y0bK
# 999998                                      0
# 999999  spotify:artist:6VDdCwrBM4qQaGxoAyxyJC
#
#                                 track_14_uri  \
# 0       spotify:track:2iFvY1l5o2mmUAjBq1L9Mh
# 1       spotify:track:3ZOEytgrvLwQaqXreDs2Jx
# 2       spotify:track:7cvkXf3AwPGT041PyOi5VX
# 3       spotify:track:3XVBdLihbNbxUwZosxcGuJ
# 4       spotify:track:6GnhWMhgJb7uyiiPEiEkDA
# ...                                      ...
# 999995  spotify:track:0fioLzGM8ngbD1w6fMmm45
# 999996  spotify:track:3LfO09R3zh96w0qGURCvrr
# 999997  spotify:track:3Q4WeJmzxuDpzMu9QjQqbM
# 999998                                     0
# 999999  spotify:track:1FejelrM94Ik1mlI64Ofpb
#
#                           track_14_album_uri  \
# 0       spotify:album:4M9Ti6t5h54aDMX4SizDfT
# 1       spotify:album:6deiaArbeoqp1xPEGdEKp1
# 2       spotify:album:1gIC63gC3B7o7FfpPACZQJ
# 3       spotify:album:6TqRKHLjDu5QZuC8u5Woij
# 4       spotify:album:2Tyx5dLhHYkx6zeAdVaTzN
# ...                                      ...
# 999995  spotify:album:2Jg7JZ0ZXOGje1bkq7CVgK
# 999996  spotify:album:6V7UTQKQXzg6jwNTxPxd2w
# 999997  spotify:album:0jwuTvP3hp2jFY08VLgvnD
# 999998                                     0
# 999999  spotify:album:3QObDcHrfzA2813ggWE5Ks
#
#                           track_14_artist_uri  \
# 0       spotify:artist:4vVfuZfXWu18vk5Z4C7wbm
# 1       spotify:artist:0L8ExT028jH3ddEcZwqJJ5
# 2       spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3       spotify:artist:3DiDSECUqqY1AuBP8qtaIa
# 4       spotify:artist:4LLpKhyESsyAXpc4laK94U
# ...                                       ...
# 999995  spotify:artist:2wY79sveU1sp5g7SokKOiI
# 999996  spotify:artist:6ZUjdwG0NvY6MT7vvmluhV
# 999997  spotify:artist:3r17AfJCCUqC9Lf0OAc73G
# 999998                                      0
# 999999  spotify:artist:39vA9YljbnOApXKniLWBZv
#
#                                 track_15_uri  \
# 0       spotify:track:3yrVRdwCbEeKODZgG2mVZX
# 1       spotify:track:5E30LdtzQTGqRvNd7l6kG5
# 2       spotify:track:5KyznPsIMzQpzPcNnb67rd
# 3       spotify:track:2U5NrHirVZusBLQlohTbnZ
# 4       spotify:track:0htTZnlk6okQ1HIq4EvFQ6
# ...                                      ...
# 999995  spotify:track:4sPmO7WMQUAf45kwMOtONw
# 999996  spotify:track:0LIU3eOAwXCZlWOiHuItkj
# 999997  spotify:track:6C7RJEIUDqKkJRZVWdkfkH
# 999998                                     0
# 999999  spotify:track:3n69hLUdIsSa1WlRmjMZlW
#
#                           track_15_album_uri  \
# 0       spotify:album:3SCJmoy3Z45p84IfuaM9YQ
# 1       spotify:album:18iFxjZugvKhuNNMbLjZJF
# 2       spotify:album:0NrP6lZ1RSuqE7xpmeKlNa
# 3       spotify:album:2p8MgaWfMYTrDtJxJMeuqG
# 4       spotify:album:6liIoWzpvrff945pUI7fHt
# ...                                      ...
# 999995  spotify:album:0K4pIOOsfJ9lK8OjrZfXzd
# 999996  spotify:album:6HizrEcHCJCX8JEfD50L7Z
# 999997  spotify:album:3SZr5Pco2oqKFORCP3WNj9
# 999998                                     0
# 999999  spotify:album:6k3vC8nep1BfqAIJ81L6OL
#
#                           track_15_artist_uri
# 0       spotify:artist:2EO56JK4txid1Pss9GVbOL
# 1       spotify:artist:77SW9BnxLY8rJ0RciFqkHh
# 2       spotify:artist:0ZrpamOxcZybMHGg1AYtHP
# 3       spotify:artist:23zg3TcAtWQy7J6upgbUnj
# 4       spotify:artist:02kJSzxNuaWGqwubyUba0Z
# ...                                       ...
# 999995  spotify:artist:4dpARuHxo51G3z768sgnrY
# 999996  spotify:artist:0O7NhieDairfQvi9jr66Cx
# 999997  spotify:artist:5K4W6rqBFWDnAN6FQUkS6x
# 999998                                      0
# 999999  spotify:artist:3XHO7cRUPCLOr6jwp8vsx5
#
# [1000000 rows x 56 columns]

# %%
# Save to csv
print('Saving to csv.')
df.to_csv(f"{output_filepath_root}/playlists.csv", index=False)
print(f'Saved to {output_filepath_root}/playlists.csv')
# Out:
# Saving to csv.
# Saved to ../data/playlists.csv

# %% [markdown]
# # 3. Create the Unique Tracks DataFrame — In Pieces!

# %%
# Number of segments to break the sum of data into.
# ex: 8 means we process 1/8th of the slices and have 8 DFs to merge at the end.

num_data_batches = 20

# Get list of all files in data/tracks
track_filenames = os.listdir(track_output)

# Break into N batches with numpy's array_split
batched_track_filenames = np.array_split(track_filenames, num_data_batches)

# Save each batch's DF in a list
batch_dfs = []

# Loop through N batches
for batch_num, batch in enumerate(batched_track_filenames):
    
    print(f"\nBeginning batch #{batch_num + 1} of {num_data_batches}\n")
    
    # Get the filenames for this batch
    track_filenames = batch.tolist()
    
    # Load the first file in this batch into a DataFrame to get started
    df = pd.read_csv(os.path.join(track_output, track_filenames[0]))
    print(f"df beginning with shape {df.shape}\n")

    # pid and pos are no longer relevant & de-duplicate
    df.drop(columns=['pid', 'pos'], inplace=True)
    df.drop_duplicates(subset=['track_uri'], inplace=True)

    length = len(track_filenames)

    # Loop through the remaining track files and de-duplicate as we go
    for ii,ff in enumerate(track_filenames):
        print(f'Batch {batch_num + 1}/{num_data_batches} | Processing file {ii + 1} of {length}')

        # Keep track of this file's shape for reporting
        df_s0 = df.shape

        # Load new slice
        df2 = pd.read_csv(os.path.join(track_output, ff))

        # Drop pid, pos columns & de-duplicate
        df2.drop(columns=['pid', 'pos'], inplace=True)
        df2.drop_duplicates(subset=['track_uri'], inplace=True)

        # Concatenate this slice to our existing DF
        # df = pd.concat([df,df2], ignore_index=True, verify_integrity=True)
        df = pd.concat([df, df2], ignore_index=True).drop_duplicates().reset_index(drop=True)


        # Report
        df_s1 = df.shape
        print(f'{df2.shape[0]} tracks processed, {df_s1[0] - df_s0[0]} unique tracks added.\n')
        
    print(f"\nBatch {batch_num + 1} complete.\n")
    print(f"df final shape {df.shape}.")
    print('___________________________________________________________________\n')
    batch_dfs.append(df)

print("\nNow combining batches...\n")
    
# Combine all DFs in the collected list
df_join = batch_dfs.pop()

for d in batch_dfs:
    df_join = pd.concat([df_join, d], ignore_index=True).drop_duplicates().reset_index(drop=True)

# Save df to single csv
print("\nNow saving unique tracks to csv...")
try:
    df_join.to_csv(f"{output_filepath_root}/unique_tracks.csv", index=False)
    print(f"unique_tracks.csv saved to {output_filepath_root}")
except:
    print("Failed to save csv.")
# Out:
# Beginning batch #1 of 20
#
# df beginning with shape (63574, 9)
#
# Batch 1/20 | Processing file 1 of 50
# 32791 tracks processed, 0 unique tracks added.
#
# Batch 1/20 | Processing file 2 of 50
# 34583 tracks processed, 22571 unique tracks added.
#
# Batch 1/20 | Processing file 3 of 50
# 35516 tracks processed, 19527 unique tracks added.
#
# Batch 1/20 | Processing file 4 of 50
# 34239 tracks processed, 16465 unique tracks added.
#
# Batch 1/20 | Processing file 5 of 50
# 34630 tracks processed, 15015 unique tracks added.
#
# Batch 1/20 | Processing file 6 of 50
# 35332 tracks processed, 14173 unique tracks added.
#
# Batch 1/20 | Processing file 7 of 50
# 34926 tracks processed, 12934 unique tracks added.
#
# Batch 1/20 | Processing file 8 of 50
# 36207 tracks processed, 13366 unique tracks added.
#
# Batch 1/20 | Processing file 9 of 50
# 36489 tracks processed, 12399 unique tracks added.
#
# Batch 1/20 | Processing file 10 of 50
# 36754 tracks processed, 13204 unique tracks added.
#
# Batch 1/20 | Processing file 11 of 50
# 35497 tracks processed, 10816 unique tracks added.
#
# Batch 1/20 | Processing file 12 of 50
# 35796 tracks processed, 10684 unique tracks added.
#
# Batch 1/20 | Processing file 13 of 50
# 33241 tracks processed, 8907 unique tracks added.
#
# Batch 1/20 | Processing file 14 of 50
# 34484 tracks processed, 9739 unique tracks added.
#
# Batch 1/20 | Processing file 15 of 50
# 35670 tracks processed, 9989 unique tracks added.
#
# Batch 1/20 | Processing file 16 of 50
# 35026 tracks processed, 9209 unique tracks added.
#
# Batch 1/20 | Processing file 17 of 50
# 34752 tracks processed, 9272 unique tracks added.
#
# Batch 1/20 | Processing file 18 of 50
# 34481 tracks processed, 8620 unique tracks added.
#
# Batch 1/20 | Processing file 19 of 50
# 34788 tracks processed, 9250 unique tracks added.
#
# Batch 1/20 | Processing file 20 of 50
# 35252 tracks processed, 8634 unique tracks added.
#
# Batch 1/20 | Processing file 21 of 50
# 33746 tracks processed, 7883 unique tracks added.
#
# Batch 1/20 | Processing file 22 of 50
# 33502 tracks processed, 7198 unique tracks added.
#
# Batch 1/20 | Processing file 23 of 50
# 34069 tracks processed, 7119 unique tracks added.
#
# Batch 1/20 | Processing file 24 of 50
# 35201 tracks processed, 7835 unique tracks added.
#
# Batch 1/20 | Processing file 25 of 50
# 35814 tracks processed, 7436 unique tracks added.
#
# Batch 1/20 | Processing file 26 of 50
# 36656 tracks processed, 7592 unique tracks added.
#
# Batch 1/20 | Processing file 27 of 50
# 34301 tracks processed, 6519 unique tracks added.
#
# Batch 1/20 | Processing file 28 of 50
# 35143 tracks processed, 7984 unique tracks added.
#
# Batch 1/20 | Processing file 29 of 50
# 34916 tracks processed, 6932 unique tracks added.
#
# Batch 1/20 | Processing file 30 of 50
# 34636 tracks processed, 7446 unique tracks added.
#
# Batch 1/20 | Processing file 31 of 50
# 35423 tracks processed, 6850 unique tracks added.
#
# Batch 1/20 | Processing file 32 of 50
# 33871 tracks processed, 6438 unique tracks added.
#
# Batch 1/20 | Processing file 33 of 50
# 35961 tracks processed, 7364 unique tracks added.
#
# Batch 1/20 | Processing file 34 of 50
# 34435 tracks processed, 5602 unique tracks added.
#
# Batch 1/20 | Processing file 35 of 50
# 35251 tracks processed, 6203 unique tracks added.
#
# Batch 1/20 | Processing file 36 of 50
# 34035 tracks processed, 5956 unique tracks added.
#
# Batch 1/20 | Processing file 37 of 50
# 36493 tracks processed, 7000 unique tracks added.
#
# Batch 1/20 | Processing file 38 of 50
# 36061 tracks processed, 6659 unique tracks added.
#
# Batch 1/20 | Processing file 39 of 50
# 36287 tracks processed, 6545 unique tracks added.
#
# Batch 1/20 | Processing file 40 of 50
# 35516 tracks processed, 6168 unique tracks added.
#
# Batch 1/20 | Processing file 41 of 50
# 34896 tracks processed, 6045 unique tracks added.
#
# Batch 1/20 | Processing file 42 of 50
# 35919 tracks processed, 6317 unique tracks added.
#
# Batch 1/20 | Processing file 43 of 50
# 36203 tracks processed, 6239 unique tracks added.
#
# Batch 1/20 | Processing file 44 of 50
# 34674 tracks processed, 5822 unique tracks added.
#
# Batch 1/20 | Processing file 45 of 50
# 34838 tracks processed, 5835 unique tracks added.
#
# Batch 1/20 | Processing file 46 of 50
# 35020 tracks processed, 5306 unique tracks added.
#
# Batch 1/20 | Processing file 47 of 50
# 36004 tracks processed, 6043 unique tracks added.
#
# Batch 1/20 | Processing file 48 of 50
# 35193 tracks processed, 5576 unique tracks added.
#
# Batch 1/20 | Processing file 49 of 50
# 35289 tracks processed, 5427 unique tracks added.
#
# Batch 1/20 | Processing file 50 of 50
# 35190 tracks processed, 5467 unique tracks added.
#
#
# Batch 1 complete.
#
# df final shape (464371, 7).
# ___________________________________________________________________
#
#
# Beginning batch #2 of 20
#
# df beginning with shape (66473, 9)
#
# Batch 2/20 | Processing file 1 of 50
# 35037 tracks processed, 0 unique tracks added.
#
# Batch 2/20 | Processing file 2 of 50
# 34829 tracks processed, 22842 unique tracks added.
#
# Batch 2/20 | Processing file 3 of 50
# 33120 tracks processed, 17541 unique tracks added.
#
# Batch 2/20 | Processing file 4 of 50
# 33962 tracks processed, 16082 unique tracks added.
#
# Batch 2/20 | Processing file 5 of 50
# 35058 tracks processed, 15601 unique tracks added.
#
# Batch 2/20 | Processing file 6 of 50
# 34223 tracks processed, 13830 unique tracks added.
#
# Batch 2/20 | Processing file 7 of 50
# 36694 tracks processed, 14335 unique tracks added.
#
# Batch 2/20 | Processing file 8 of 50
# 34525 tracks processed, 12124 unique tracks added.
#
# Batch 2/20 | Processing file 9 of 50
# 34411 tracks processed, 11479 unique tracks added.
#
# Batch 2/20 | Processing file 10 of 50
# 35654 tracks processed, 11750 unique tracks added.
#
# Batch 2/20 | Processing file 11 of 50
# 36681 tracks processed, 11490 unique tracks added.
#
# Batch 2/20 | Processing file 12 of 50
# 34739 tracks processed, 9914 unique tracks added.
#
# Batch 2/20 | Processing file 13 of 50
# 35183 tracks processed, 9696 unique tracks added.
#
# Batch 2/20 | Processing file 14 of 50
# 35516 tracks processed, 9828 unique tracks added.
#
# Batch 2/20 | Processing file 15 of 50
# 35341 tracks processed, 9010 unique tracks added.
#
# Batch 2/20 | Processing file 16 of 50
# 34239 tracks processed, 9079 unique tracks added.
#
# Batch 2/20 | Processing file 17 of 50
# 34175 tracks processed, 9114 unique tracks added.
#
# Batch 2/20 | Processing file 18 of 50
# 33562 tracks processed, 7894 unique tracks added.
#
# Batch 2/20 | Processing file 19 of 50
# 35124 tracks processed, 9250 unique tracks added.
#
# Batch 2/20 | Processing file 20 of 50
# 35572 tracks processed, 8447 unique tracks added.
#
# Batch 2/20 | Processing file 21 of 50
# 35011 tracks processed, 8246 unique tracks added.
#
# Batch 2/20 | Processing file 22 of 50
# 37521 tracks processed, 8929 unique tracks added.
#
# Batch 2/20 | Processing file 23 of 50
# 34532 tracks processed, 7545 unique tracks added.
#
# Batch 2/20 | Processing file 24 of 50
# 35035 tracks processed, 7511 unique tracks added.
#
# Batch 2/20 | Processing file 25 of 50
# 34785 tracks processed, 7799 unique tracks added.
#
# Batch 2/20 | Processing file 26 of 50
# 34887 tracks processed, 7155 unique tracks added.
#
# Batch 2/20 | Processing file 27 of 50
# 34764 tracks processed, 7543 unique tracks added.
#
# Batch 2/20 | Processing file 28 of 50
# 35080 tracks processed, 7274 unique tracks added.
#
# Batch 2/20 | Processing file 29 of 50
# 35056 tracks processed, 6646 unique tracks added.
#
# Batch 2/20 | Processing file 30 of 50
# 34191 tracks processed, 6427 unique tracks added.
#
# Batch 2/20 | Processing file 31 of 50
# 35097 tracks processed, 7100 unique tracks added.
#
# Batch 2/20 | Processing file 32 of 50
# 35165 tracks processed, 6466 unique tracks added.
#
# Batch 2/20 | Processing file 33 of 50
# 34095 tracks processed, 6285 unique tracks added.
#
# Batch 2/20 | Processing file 34 of 50
# 34247 tracks processed, 6282 unique tracks added.
#
# Batch 2/20 | Processing file 35 of 50
# 37262 tracks processed, 6819 unique tracks added.
#
# Batch 2/20 | Processing file 36 of 50
# 35533 tracks processed, 6704 unique tracks added.
#
# Batch 2/20 | Processing file 37 of 50
# 35397 tracks processed, 6198 unique tracks added.
#
# Batch 2/20 | Processing file 38 of 50
# 35272 tracks processed, 6767 unique tracks added.
#
# Batch 2/20 | Processing file 39 of 50
# 35957 tracks processed, 6171 unique tracks added.
#
# Batch 2/20 | Processing file 40 of 50
# 35421 tracks processed, 5965 unique tracks added.
#
# Batch 2/20 | Processing file 41 of 50
# 33988 tracks processed, 5964 unique tracks added.
#
# Batch 2/20 | Processing file 42 of 50
# 36506 tracks processed, 6415 unique tracks added.
#
# Batch 2/20 | Processing file 43 of 50
# 35160 tracks processed, 6070 unique tracks added.
#
# Batch 2/20 | Processing file 44 of 50
# 33670 tracks processed, 5637 unique tracks added.
#
# Batch 2/20 | Processing file 45 of 50
# 35344 tracks processed, 5808 unique tracks added.
#
# Batch 2/20 | Processing file 46 of 50
# 35563 tracks processed, 6048 unique tracks added.
#
# Batch 2/20 | Processing file 47 of 50
# 33948 tracks processed, 4716 unique tracks added.
#
# Batch 2/20 | Processing file 48 of 50
# 34167 tracks processed, 5003 unique tracks added.
#
# Batch 2/20 | Processing file 49 of 50
# 32315 tracks processed, 4727 unique tracks added.
#
# Batch 2/20 | Processing file 50 of 50
# 34659 tracks processed, 5617 unique tracks added.
#
#
# Batch 2 complete.
#
# df final shape (460180, 7).
# ___________________________________________________________________
#
#
# Beginning batch #3 of 20
#
# df beginning with shape (64300, 9)
#
# Batch 3/20 | Processing file 1 of 50
# 33984 tracks processed, 0 unique tracks added.
#
# Batch 3/20 | Processing file 2 of 50
# 35250 tracks processed, 23014 unique tracks added.
#
# Batch 3/20 | Processing file 3 of 50
# 35665 tracks processed, 19126 unique tracks added.
#
# Batch 3/20 | Processing file 4 of 50
# 35468 tracks processed, 17239 unique tracks added.
#
# Batch 3/20 | Processing file 5 of 50
# 34730 tracks processed, 15197 unique tracks added.
#
# Batch 3/20 | Processing file 6 of 50
# 34797 tracks processed, 14144 unique tracks added.
#
# Batch 3/20 | Processing file 7 of 50
# 34606 tracks processed, 12730 unique tracks added.
#
# Batch 3/20 | Processing file 8 of 50
# 36383 tracks processed, 13428 unique tracks added.
#
# Batch 3/20 | Processing file 9 of 50
# 34709 tracks processed, 11208 unique tracks added.
#
# Batch 3/20 | Processing file 10 of 50
# 36048 tracks processed, 11712 unique tracks added.
#
# Batch 3/20 | Processing file 11 of 50
# 34898 tracks processed, 10729 unique tracks added.
#
# Batch 3/20 | Processing file 12 of 50
# 33445 tracks processed, 10016 unique tracks added.
#
# Batch 3/20 | Processing file 13 of 50
# 36622 tracks processed, 11254 unique tracks added.
#
# Batch 3/20 | Processing file 14 of 50
# 35214 tracks processed, 9694 unique tracks added.
#
# Batch 3/20 | Processing file 15 of 50
# 34881 tracks processed, 9260 unique tracks added.
#
# Batch 3/20 | Processing file 16 of 50
# 34570 tracks processed, 9404 unique tracks added.
#
# Batch 3/20 | Processing file 17 of 50
# 35408 tracks processed, 9554 unique tracks added.
#
# Batch 3/20 | Processing file 18 of 50
# 33401 tracks processed, 8087 unique tracks added.
#
# Batch 3/20 | Processing file 19 of 50
# 35066 tracks processed, 8855 unique tracks added.
#
# Batch 3/20 | Processing file 20 of 50
# 35534 tracks processed, 8605 unique tracks added.
#
# Batch 3/20 | Processing file 21 of 50
# 35937 tracks processed, 8499 unique tracks added.
#
# Batch 3/20 | Processing file 22 of 50
# 35526 tracks processed, 8159 unique tracks added.
#
# Batch 3/20 | Processing file 23 of 50
# 34199 tracks processed, 6988 unique tracks added.
#
# Batch 3/20 | Processing file 24 of 50
# 35869 tracks processed, 8301 unique tracks added.
#
# Batch 3/20 | Processing file 25 of 50
# 34716 tracks processed, 7589 unique tracks added.
#
# Batch 3/20 | Processing file 26 of 50
# 33779 tracks processed, 6712 unique tracks added.
#
# Batch 3/20 | Processing file 27 of 50
# 35370 tracks processed, 7357 unique tracks added.
#
# Batch 3/20 | Processing file 28 of 50
# 36143 tracks processed, 7519 unique tracks added.
#
# Batch 3/20 | Processing file 29 of 50
# 36119 tracks processed, 6896 unique tracks added.
#
# Batch 3/20 | Processing file 30 of 50
# 36567 tracks processed, 7486 unique tracks added.
#
# Batch 3/20 | Processing file 31 of 50
# 35344 tracks processed, 6788 unique tracks added.
#
# Batch 3/20 | Processing file 32 of 50
# 35570 tracks processed, 6687 unique tracks added.
#
# Batch 3/20 | Processing file 33 of 50
# 36457 tracks processed, 7307 unique tracks added.
#
# Batch 3/20 | Processing file 34 of 50
# 35094 tracks processed, 6613 unique tracks added.
#
# Batch 3/20 | Processing file 35 of 50
# 35852 tracks processed, 6885 unique tracks added.
#
# Batch 3/20 | Processing file 36 of 50
# 35882 tracks processed, 6562 unique tracks added.
#
# Batch 3/20 | Processing file 37 of 50
# 32586 tracks processed, 5019 unique tracks added.
#
# Batch 3/20 | Processing file 38 of 50
# 35183 tracks processed, 6229 unique tracks added.
#
# Batch 3/20 | Processing file 39 of 50
# 34929 tracks processed, 6060 unique tracks added.
#
# Batch 3/20 | Processing file 40 of 50
# 35471 tracks processed, 6297 unique tracks added.
#
# Batch 3/20 | Processing file 41 of 50
# 33399 tracks processed, 5156 unique tracks added.
#
# Batch 3/20 | Processing file 42 of 50
# 36435 tracks processed, 7004 unique tracks added.
#
# Batch 3/20 | Processing file 43 of 50
# 33143 tracks processed, 5281 unique tracks added.
#
# Batch 3/20 | Processing file 44 of 50
# 35022 tracks processed, 5013 unique tracks added.
#
# Batch 3/20 | Processing file 45 of 50
# 35035 tracks processed, 5589 unique tracks added.
#
# Batch 3/20 | Processing file 46 of 50
# 35624 tracks processed, 5684 unique tracks added.
#
# Batch 3/20 | Processing file 47 of 50
# 32746 tracks processed, 5189 unique tracks added.
#
# Batch 3/20 | Processing file 48 of 50
# 34481 tracks processed, 5145 unique tracks added.
#
# Batch 3/20 | Processing file 49 of 50
# 35480 tracks processed, 5652 unique tracks added.
#
# Batch 3/20 | Processing file 50 of 50
# 37226 tracks processed, 6013 unique tracks added.
#
#
# Batch 3 complete.
#
# df final shape (462919, 7).
# ___________________________________________________________________
#
#
# Beginning batch #4 of 20
#
# df beginning with shape (67751, 9)
#
# Batch 4/20 | Processing file 1 of 50
# 35848 tracks processed, 0 unique tracks added.
#
# Batch 4/20 | Processing file 2 of 50
# 34880 tracks processed, 22630 unique tracks added.
#
# Batch 4/20 | Processing file 3 of 50
# 36211 tracks processed, 20199 unique tracks added.
#
# Batch 4/20 | Processing file 4 of 50
# 36293 tracks processed, 17760 unique tracks added.
#
# Batch 4/20 | Processing file 5 of 50
# 35790 tracks processed, 15597 unique tracks added.
#
# Batch 4/20 | Processing file 6 of 50
# 35070 tracks processed, 14464 unique tracks added.
#
# Batch 4/20 | Processing file 7 of 50
# 35652 tracks processed, 13663 unique tracks added.
#
# Batch 4/20 | Processing file 8 of 50
# 36277 tracks processed, 13788 unique tracks added.
#
# Batch 4/20 | Processing file 9 of 50
# 34968 tracks processed, 11889 unique tracks added.
#
# Batch 4/20 | Processing file 10 of 50
# 34781 tracks processed, 11435 unique tracks added.
#
# Batch 4/20 | Processing file 11 of 50
# 36535 tracks processed, 11582 unique tracks added.
#
# Batch 4/20 | Processing file 12 of 50
# 35672 tracks processed, 11135 unique tracks added.
#
# Batch 4/20 | Processing file 13 of 50
# 34876 tracks processed, 9878 unique tracks added.
#
# Batch 4/20 | Processing file 14 of 50
# 35105 tracks processed, 9470 unique tracks added.
#
# Batch 4/20 | Processing file 15 of 50
# 35488 tracks processed, 9765 unique tracks added.
#
# Batch 4/20 | Processing file 16 of 50
# 35126 tracks processed, 9056 unique tracks added.
#
# Batch 4/20 | Processing file 17 of 50
# 35970 tracks processed, 9527 unique tracks added.
#
# Batch 4/20 | Processing file 18 of 50
# 34103 tracks processed, 8538 unique tracks added.
#
# Batch 4/20 | Processing file 19 of 50
# 35694 tracks processed, 8465 unique tracks added.
#
# Batch 4/20 | Processing file 20 of 50
# 35777 tracks processed, 8414 unique tracks added.
#
# Batch 4/20 | Processing file 21 of 50
# 35611 tracks processed, 8031 unique tracks added.
#
# Batch 4/20 | Processing file 22 of 50
# 35670 tracks processed, 8145 unique tracks added.
#
# Batch 4/20 | Processing file 23 of 50
# 34985 tracks processed, 7383 unique tracks added.
#
# Batch 4/20 | Processing file 24 of 50
# 34651 tracks processed, 7568 unique tracks added.
#
# Batch 4/20 | Processing file 25 of 50
# 34065 tracks processed, 6503 unique tracks added.
#
# Batch 4/20 | Processing file 26 of 50
# 35540 tracks processed, 7976 unique tracks added.
#
# Batch 4/20 | Processing file 27 of 50
# 34801 tracks processed, 6842 unique tracks added.
#
# Batch 4/20 | Processing file 28 of 50
# 34086 tracks processed, 6134 unique tracks added.
#
# Batch 4/20 | Processing file 29 of 50
# 34990 tracks processed, 7241 unique tracks added.
#
# Batch 4/20 | Processing file 30 of 50
# 34491 tracks processed, 6720 unique tracks added.
#
# Batch 4/20 | Processing file 31 of 50
# 34011 tracks processed, 6455 unique tracks added.
#
# Batch 4/20 | Processing file 32 of 50
# 35805 tracks processed, 7805 unique tracks added.
#
# Batch 4/20 | Processing file 33 of 50
# 35293 tracks processed, 6800 unique tracks added.
#
# Batch 4/20 | Processing file 34 of 50
# 36855 tracks processed, 7131 unique tracks added.
#
# Batch 4/20 | Processing file 35 of 50
# 35359 tracks processed, 6175 unique tracks added.
#
# Batch 4/20 | Processing file 36 of 50
# 36134 tracks processed, 6573 unique tracks added.
#
# Batch 4/20 | Processing file 37 of 50
# 33603 tracks processed, 5660 unique tracks added.
#
# Batch 4/20 | Processing file 38 of 50
# 36023 tracks processed, 6804 unique tracks added.
#
# Batch 4/20 | Processing file 39 of 50
# 36117 tracks processed, 6295 unique tracks added.
#
# Batch 4/20 | Processing file 40 of 50
# 35367 tracks processed, 6435 unique tracks added.
#
# Batch 4/20 | Processing file 41 of 50
# 34778 tracks processed, 6357 unique tracks added.
#
# Batch 4/20 | Processing file 42 of 50
# 35793 tracks processed, 6130 unique tracks added.
#
# Batch 4/20 | Processing file 43 of 50
# 34771 tracks processed, 5726 unique tracks added.
#
# Batch 4/20 | Processing file 44 of 50
# 34010 tracks processed, 5162 unique tracks added.
#
# Batch 4/20 | Processing file 45 of 50
# 35271 tracks processed, 5496 unique tracks added.
#
# Batch 4/20 | Processing file 46 of 50
# 34171 tracks processed, 4894 unique tracks added.
#
# Batch 4/20 | Processing file 47 of 50
# 33659 tracks processed, 5137 unique tracks added.
#
# Batch 4/20 | Processing file 48 of 50
# 35252 tracks processed, 5647 unique tracks added.
#
# Batch 4/20 | Processing file 49 of 50
# 34399 tracks processed, 5451 unique tracks added.
#
# Batch 4/20 | Processing file 50 of 50
# 33906 tracks processed, 4812 unique tracks added.
#
#
# Batch 4 complete.
#
# df final shape (466591, 7).
# ___________________________________________________________________
#
#
# Beginning batch #5 of 20
#
# df beginning with shape (65320, 9)
#
# Batch 5/20 | Processing file 1 of 50
# 34183 tracks processed, 0 unique tracks added.
#
# Batch 5/20 | Processing file 2 of 50
# 35872 tracks processed, 23325 unique tracks added.
#
# Batch 5/20 | Processing file 3 of 50
# 35671 tracks processed, 19586 unique tracks added.
#
# Batch 5/20 | Processing file 4 of 50
# 34859 tracks processed, 17049 unique tracks added.
#
# Batch 5/20 | Processing file 5 of 50
# 36767 tracks processed, 16590 unique tracks added.
#
# Batch 5/20 | Processing file 6 of 50
# 34289 tracks processed, 13609 unique tracks added.
#
# Batch 5/20 | Processing file 7 of 50
# 35972 tracks processed, 13958 unique tracks added.
#
# Batch 5/20 | Processing file 8 of 50
# 34399 tracks processed, 12033 unique tracks added.
#
# Batch 5/20 | Processing file 9 of 50
# 36913 tracks processed, 13136 unique tracks added.
#
# Batch 5/20 | Processing file 10 of 50
# 35585 tracks processed, 11786 unique tracks added.
#
# Batch 5/20 | Processing file 11 of 50
# 34615 tracks processed, 10735 unique tracks added.
#
# Batch 5/20 | Processing file 12 of 50
# 32572 tracks processed, 9172 unique tracks added.
#
# Batch 5/20 | Processing file 13 of 50
# 35457 tracks processed, 10480 unique tracks added.
#
# Batch 5/20 | Processing file 14 of 50
# 36720 tracks processed, 10352 unique tracks added.
#
# Batch 5/20 | Processing file 15 of 50
# 34924 tracks processed, 8999 unique tracks added.
#
# Batch 5/20 | Processing file 16 of 50
# 34024 tracks processed, 8541 unique tracks added.
#
# Batch 5/20 | Processing file 17 of 50
# 36548 tracks processed, 9684 unique tracks added.
#
# Batch 5/20 | Processing file 18 of 50
# 34046 tracks processed, 8257 unique tracks added.
#
# Batch 5/20 | Processing file 19 of 50
# 34223 tracks processed, 8114 unique tracks added.
#
# Batch 5/20 | Processing file 20 of 50
# 33791 tracks processed, 7768 unique tracks added.
#
# Batch 5/20 | Processing file 21 of 50
# 34841 tracks processed, 8129 unique tracks added.
#
# Batch 5/20 | Processing file 22 of 50
# 35953 tracks processed, 8649 unique tracks added.
#
# Batch 5/20 | Processing file 23 of 50
# 33843 tracks processed, 6969 unique tracks added.
#
# Batch 5/20 | Processing file 24 of 50
# 35673 tracks processed, 8226 unique tracks added.
#
# Batch 5/20 | Processing file 25 of 50
# 35484 tracks processed, 7816 unique tracks added.
#
# Batch 5/20 | Processing file 26 of 50
# 34026 tracks processed, 6518 unique tracks added.
#
# Batch 5/20 | Processing file 27 of 50
# 35282 tracks processed, 7213 unique tracks added.
#
# Batch 5/20 | Processing file 28 of 50
# 34868 tracks processed, 7117 unique tracks added.
#
# Batch 5/20 | Processing file 29 of 50
# 36578 tracks processed, 7834 unique tracks added.
#
# Batch 5/20 | Processing file 30 of 50
# 34225 tracks processed, 6385 unique tracks added.
#
# Batch 5/20 | Processing file 31 of 50
# 34424 tracks processed, 6915 unique tracks added.
#
# Batch 5/20 | Processing file 32 of 50
# 36199 tracks processed, 6824 unique tracks added.
#
# Batch 5/20 | Processing file 33 of 50
# 37120 tracks processed, 7372 unique tracks added.
#
# Batch 5/20 | Processing file 34 of 50
# 35047 tracks processed, 6550 unique tracks added.
#
# Batch 5/20 | Processing file 35 of 50
# 35476 tracks processed, 6566 unique tracks added.
#
# Batch 5/20 | Processing file 36 of 50
# 34613 tracks processed, 6198 unique tracks added.
#
# Batch 5/20 | Processing file 37 of 50
# 34474 tracks processed, 5639 unique tracks added.
#
# Batch 5/20 | Processing file 38 of 50
# 35483 tracks processed, 6094 unique tracks added.
#
# Batch 5/20 | Processing file 39 of 50
# 37297 tracks processed, 6288 unique tracks added.
#
# Batch 5/20 | Processing file 40 of 50
# 35271 tracks processed, 5909 unique tracks added.
#
# Batch 5/20 | Processing file 41 of 50
# 35320 tracks processed, 5878 unique tracks added.
#
# Batch 5/20 | Processing file 42 of 50
# 36051 tracks processed, 6204 unique tracks added.
#
# Batch 5/20 | Processing file 43 of 50
# 34807 tracks processed, 5391 unique tracks added.
#
# Batch 5/20 | Processing file 44 of 50
# 34831 tracks processed, 5621 unique tracks added.
#
# Batch 5/20 | Processing file 45 of 50
# 34525 tracks processed, 5392 unique tracks added.
#
# Batch 5/20 | Processing file 46 of 50
# 33819 tracks processed, 5159 unique tracks added.
#
# Batch 5/20 | Processing file 47 of 50
# 36937 tracks processed, 5992 unique tracks added.
#
# Batch 5/20 | Processing file 48 of 50
# 31773 tracks processed, 4914 unique tracks added.
#
# Batch 5/20 | Processing file 49 of 50
# 35356 tracks processed, 5539 unique tracks added.
#
# Batch 5/20 | Processing file 50 of 50
# 34682 tracks processed, 4996 unique tracks added.
#
#
# Batch 5 complete.
#
# df final shape (461654, 7).
# ___________________________________________________________________
#
#
# Beginning batch #6 of 20
#
# df beginning with shape (64318, 9)
#
# Batch 6/20 | Processing file 1 of 50
# 32980 tracks processed, 0 unique tracks added.
#
# Batch 6/20 | Processing file 2 of 50
# 36103 tracks processed, 23788 unique tracks added.
#
# Batch 6/20 | Processing file 3 of 50
# 35153 tracks processed, 18929 unique tracks added.
#
# Batch 6/20 | Processing file 4 of 50
# 35019 tracks processed, 16671 unique tracks added.
#
# Batch 6/20 | Processing file 5 of 50
# 34778 tracks processed, 15434 unique tracks added.
#
# Batch 6/20 | Processing file 6 of 50
# 35199 tracks processed, 14356 unique tracks added.
#
# Batch 6/20 | Processing file 7 of 50
# 35844 tracks processed, 13921 unique tracks added.
#
# Batch 6/20 | Processing file 8 of 50
# 33208 tracks processed, 11015 unique tracks added.
#
# Batch 6/20 | Processing file 9 of 50
# 35365 tracks processed, 12519 unique tracks added.
#
# Batch 6/20 | Processing file 10 of 50
# 35982 tracks processed, 11470 unique tracks added.
#
# Batch 6/20 | Processing file 11 of 50
# 35098 tracks processed, 10584 unique tracks added.
#
# Batch 6/20 | Processing file 12 of 50
# 35362 tracks processed, 10295 unique tracks added.
#
# Batch 6/20 | Processing file 13 of 50
# 35744 tracks processed, 10708 unique tracks added.
#
# Batch 6/20 | Processing file 14 of 50
# 35574 tracks processed, 9908 unique tracks added.
#
# Batch 6/20 | Processing file 15 of 50
# 35158 tracks processed, 9121 unique tracks added.
#
# Batch 6/20 | Processing file 16 of 50
# 36349 tracks processed, 10197 unique tracks added.
#
# Batch 6/20 | Processing file 17 of 50
# 35126 tracks processed, 9168 unique tracks added.
#
# Batch 6/20 | Processing file 18 of 50
# 35823 tracks processed, 9624 unique tracks added.
#
# Batch 6/20 | Processing file 19 of 50
# 36912 tracks processed, 9575 unique tracks added.
#
# Batch 6/20 | Processing file 20 of 50
# 36604 tracks processed, 8764 unique tracks added.
#
# Batch 6/20 | Processing file 21 of 50
# 35337 tracks processed, 7842 unique tracks added.
#
# Batch 6/20 | Processing file 22 of 50
# 34215 tracks processed, 7407 unique tracks added.
#
# Batch 6/20 | Processing file 23 of 50
# 34629 tracks processed, 7482 unique tracks added.
#
# Batch 6/20 | Processing file 24 of 50
# 36685 tracks processed, 8003 unique tracks added.
#
# Batch 6/20 | Processing file 25 of 50
# 35920 tracks processed, 7966 unique tracks added.
#
# Batch 6/20 | Processing file 26 of 50
# 34968 tracks processed, 7249 unique tracks added.
#
# Batch 6/20 | Processing file 27 of 50
# 33034 tracks processed, 6340 unique tracks added.
#
# Batch 6/20 | Processing file 28 of 50
# 36501 tracks processed, 7812 unique tracks added.
#
# Batch 6/20 | Processing file 29 of 50
# 35288 tracks processed, 7062 unique tracks added.
#
# Batch 6/20 | Processing file 30 of 50
# 36269 tracks processed, 7119 unique tracks added.
#
# Batch 6/20 | Processing file 31 of 50
# 35141 tracks processed, 7155 unique tracks added.
#
# Batch 6/20 | Processing file 32 of 50
# 35322 tracks processed, 6634 unique tracks added.
#
# Batch 6/20 | Processing file 33 of 50
# 34561 tracks processed, 6099 unique tracks added.
#
# Batch 6/20 | Processing file 34 of 50
# 34536 tracks processed, 6085 unique tracks added.
#
# Batch 6/20 | Processing file 35 of 50
# 36207 tracks processed, 6479 unique tracks added.
#
# Batch 6/20 | Processing file 36 of 50
# 34236 tracks processed, 6026 unique tracks added.
#
# Batch 6/20 | Processing file 37 of 50
# 35629 tracks processed, 6184 unique tracks added.
#
# Batch 6/20 | Processing file 38 of 50
# 34239 tracks processed, 5795 unique tracks added.
#
# Batch 6/20 | Processing file 39 of 50
# 34429 tracks processed, 6270 unique tracks added.
#
# Batch 6/20 | Processing file 40 of 50
# 35335 tracks processed, 5793 unique tracks added.
#
# Batch 6/20 | Processing file 41 of 50
# 34690 tracks processed, 6155 unique tracks added.
#
# Batch 6/20 | Processing file 42 of 50
# 36637 tracks processed, 6157 unique tracks added.
#
# Batch 6/20 | Processing file 43 of 50
# 34565 tracks processed, 5774 unique tracks added.
#
# Batch 6/20 | Processing file 44 of 50
# 35376 tracks processed, 5509 unique tracks added.
#
# Batch 6/20 | Processing file 45 of 50
# 34400 tracks processed, 5374 unique tracks added.
#
# Batch 6/20 | Processing file 46 of 50
# 34820 tracks processed, 5751 unique tracks added.
#
# Batch 6/20 | Processing file 47 of 50
# 35232 tracks processed, 5728 unique tracks added.
#
# Batch 6/20 | Processing file 48 of 50
# 35926 tracks processed, 5898 unique tracks added.
#
# Batch 6/20 | Processing file 49 of 50
# 34728 tracks processed, 4803 unique tracks added.
#
# Batch 6/20 | Processing file 50 of 50
# 35605 tracks processed, 5641 unique tracks added.
#
#
# Batch 6 complete.
#
# df final shape (462619, 7).
# ___________________________________________________________________
#
#
# Beginning batch #7 of 20
#
# df beginning with shape (68208, 9)
#
# Batch 7/20 | Processing file 1 of 50
# 34624 tracks processed, 0 unique tracks added.
#
# Batch 7/20 | Processing file 2 of 50
# 33542 tracks processed, 21131 unique tracks added.
#
# Batch 7/20 | Processing file 3 of 50
# 33542 tracks processed, 17755 unique tracks added.
#
# Batch 7/20 | Processing file 4 of 50
# 34610 tracks processed, 16659 unique tracks added.
#
# Batch 7/20 | Processing file 5 of 50
# 33507 tracks processed, 14021 unique tracks added.
#
# Batch 7/20 | Processing file 6 of 50
# 33960 tracks processed, 12810 unique tracks added.
#
# Batch 7/20 | Processing file 7 of 50
# 36153 tracks processed, 14275 unique tracks added.
#
# Batch 7/20 | Processing file 8 of 50
# 33823 tracks processed, 12117 unique tracks added.
#
# Batch 7/20 | Processing file 9 of 50
# 34148 tracks processed, 11466 unique tracks added.
#
# Batch 7/20 | Processing file 10 of 50
# 34342 tracks processed, 10605 unique tracks added.
#
# Batch 7/20 | Processing file 11 of 50
# 34335 tracks processed, 11120 unique tracks added.
#
# Batch 7/20 | Processing file 12 of 50
# 36039 tracks processed, 11577 unique tracks added.
#
# Batch 7/20 | Processing file 13 of 50
# 33211 tracks processed, 9394 unique tracks added.
#
# Batch 7/20 | Processing file 14 of 50
# 33828 tracks processed, 9596 unique tracks added.
#
# Batch 7/20 | Processing file 15 of 50
# 35567 tracks processed, 10235 unique tracks added.
#
# Batch 7/20 | Processing file 16 of 50
# 34535 tracks processed, 9198 unique tracks added.
#
# Batch 7/20 | Processing file 17 of 50
# 35754 tracks processed, 9861 unique tracks added.
#
# Batch 7/20 | Processing file 18 of 50
# 35999 tracks processed, 9670 unique tracks added.
#
# Batch 7/20 | Processing file 19 of 50
# 34049 tracks processed, 8291 unique tracks added.
#
# Batch 7/20 | Processing file 20 of 50
# 34415 tracks processed, 8568 unique tracks added.
#
# Batch 7/20 | Processing file 21 of 50
# 35930 tracks processed, 9034 unique tracks added.
#
# Batch 7/20 | Processing file 22 of 50
# 35278 tracks processed, 8379 unique tracks added.
#
# Batch 7/20 | Processing file 23 of 50
# 36332 tracks processed, 8373 unique tracks added.
#
# Batch 7/20 | Processing file 24 of 50
# 35257 tracks processed, 7853 unique tracks added.
#
# Batch 7/20 | Processing file 25 of 50
# 35640 tracks processed, 8176 unique tracks added.
#
# Batch 7/20 | Processing file 26 of 50
# 34440 tracks processed, 7133 unique tracks added.
#
# Batch 7/20 | Processing file 27 of 50
# 34741 tracks processed, 6888 unique tracks added.
#
# Batch 7/20 | Processing file 28 of 50
# 35497 tracks processed, 7112 unique tracks added.
#
# Batch 7/20 | Processing file 29 of 50
# 34230 tracks processed, 6413 unique tracks added.
#
# Batch 7/20 | Processing file 30 of 50
# 37079 tracks processed, 7722 unique tracks added.
#
# Batch 7/20 | Processing file 31 of 50
# 35702 tracks processed, 7491 unique tracks added.
#
# Batch 7/20 | Processing file 32 of 50
# 35743 tracks processed, 7059 unique tracks added.
#
# Batch 7/20 | Processing file 33 of 50
# 34316 tracks processed, 6166 unique tracks added.
#
# Batch 7/20 | Processing file 34 of 50
# 36760 tracks processed, 7097 unique tracks added.
#
# Batch 7/20 | Processing file 35 of 50
# 34878 tracks processed, 6114 unique tracks added.
#
# Batch 7/20 | Processing file 36 of 50
# 37099 tracks processed, 7406 unique tracks added.
#
# Batch 7/20 | Processing file 37 of 50
# 34430 tracks processed, 5859 unique tracks added.
#
# Batch 7/20 | Processing file 38 of 50
# 33851 tracks processed, 5659 unique tracks added.
#
# Batch 7/20 | Processing file 39 of 50
# 34148 tracks processed, 5607 unique tracks added.
#
# Batch 7/20 | Processing file 40 of 50
# 34653 tracks processed, 5471 unique tracks added.
#
# Batch 7/20 | Processing file 41 of 50
# 32608 tracks processed, 4971 unique tracks added.
#
# Batch 7/20 | Processing file 42 of 50
# 35118 tracks processed, 5763 unique tracks added.
#
# Batch 7/20 | Processing file 43 of 50
# 35933 tracks processed, 6482 unique tracks added.
#
# Batch 7/20 | Processing file 44 of 50
# 35223 tracks processed, 5410 unique tracks added.
#
# Batch 7/20 | Processing file 45 of 50
# 36093 tracks processed, 5643 unique tracks added.
#
# Batch 7/20 | Processing file 46 of 50
# 34842 tracks processed, 5480 unique tracks added.
#
# Batch 7/20 | Processing file 47 of 50
# 33735 tracks processed, 4976 unique tracks added.
#
# Batch 7/20 | Processing file 48 of 50
# 35704 tracks processed, 6155 unique tracks added.
#
# Batch 7/20 | Processing file 49 of 50
# 34694 tracks processed, 5162 unique tracks added.
#
# Batch 7/20 | Processing file 50 of 50
# 33823 tracks processed, 5002 unique tracks added.
#
#
# Batch 7 complete.
#
# df final shape (459029, 7).
# ___________________________________________________________________
#
#
# Beginning batch #8 of 20
#
# df beginning with shape (66352, 9)
#
# Batch 8/20 | Processing file 1 of 50
# 33948 tracks processed, 0 unique tracks added.
#
# Batch 8/20 | Processing file 2 of 50
# 36698 tracks processed, 24335 unique tracks added.
#
# Batch 8/20 | Processing file 3 of 50
# 34777 tracks processed, 18587 unique tracks added.
#
# Batch 8/20 | Processing file 4 of 50
# 35445 tracks processed, 17249 unique tracks added.
#
# Batch 8/20 | Processing file 5 of 50
# 36032 tracks processed, 16059 unique tracks added.
#
# Batch 8/20 | Processing file 6 of 50
# 36666 tracks processed, 15255 unique tracks added.
#
# Batch 8/20 | Processing file 7 of 50
# 36226 tracks processed, 13817 unique tracks added.
#
# Batch 8/20 | Processing file 8 of 50
# 34251 tracks processed, 12278 unique tracks added.
#
# Batch 8/20 | Processing file 9 of 50
# 36954 tracks processed, 12467 unique tracks added.
#
# Batch 8/20 | Processing file 10 of 50
# 35963 tracks processed, 11368 unique tracks added.
#
# Batch 8/20 | Processing file 11 of 50
# 35305 tracks processed, 10877 unique tracks added.
#
# Batch 8/20 | Processing file 12 of 50
# 36236 tracks processed, 11125 unique tracks added.
#
# Batch 8/20 | Processing file 13 of 50
# 33533 tracks processed, 8950 unique tracks added.
#
# Batch 8/20 | Processing file 14 of 50
# 33802 tracks processed, 8923 unique tracks added.
#
# Batch 8/20 | Processing file 15 of 50
# 34341 tracks processed, 9459 unique tracks added.
#
# Batch 8/20 | Processing file 16 of 50
# 34014 tracks processed, 8611 unique tracks added.
#
# Batch 8/20 | Processing file 17 of 50
# 34525 tracks processed, 8975 unique tracks added.
#
# Batch 8/20 | Processing file 18 of 50
# 34498 tracks processed, 9061 unique tracks added.
#
# Batch 8/20 | Processing file 19 of 50
# 34350 tracks processed, 8477 unique tracks added.
#
# Batch 8/20 | Processing file 20 of 50
# 35564 tracks processed, 8713 unique tracks added.
#
# Batch 8/20 | Processing file 21 of 50
# 35333 tracks processed, 8408 unique tracks added.
#
# Batch 8/20 | Processing file 22 of 50
# 35801 tracks processed, 8545 unique tracks added.
#
# Batch 8/20 | Processing file 23 of 50
# 34971 tracks processed, 7964 unique tracks added.
#
# Batch 8/20 | Processing file 24 of 50
# 35971 tracks processed, 7920 unique tracks added.
#
# Batch 8/20 | Processing file 25 of 50
# 34268 tracks processed, 7421 unique tracks added.
#
# Batch 8/20 | Processing file 26 of 50
# 36269 tracks processed, 8258 unique tracks added.
#
# Batch 8/20 | Processing file 27 of 50
# 35117 tracks processed, 7216 unique tracks added.
#
# Batch 8/20 | Processing file 28 of 50
# 33552 tracks processed, 7170 unique tracks added.
#
# Batch 8/20 | Processing file 29 of 50
# 34800 tracks processed, 7070 unique tracks added.
#
# Batch 8/20 | Processing file 30 of 50
# 34896 tracks processed, 6961 unique tracks added.
#
# Batch 8/20 | Processing file 31 of 50
# 35704 tracks processed, 7395 unique tracks added.
#
# Batch 8/20 | Processing file 32 of 50
# 35151 tracks processed, 7156 unique tracks added.
#
# Batch 8/20 | Processing file 33 of 50
# 34258 tracks processed, 6116 unique tracks added.
#
# Batch 8/20 | Processing file 34 of 50
# 35022 tracks processed, 7010 unique tracks added.
#
# Batch 8/20 | Processing file 35 of 50
# 34478 tracks processed, 5980 unique tracks added.
#
# Batch 8/20 | Processing file 36 of 50
# 34464 tracks processed, 6193 unique tracks added.
#
# Batch 8/20 | Processing file 37 of 50
# 34306 tracks processed, 6115 unique tracks added.
#
# Batch 8/20 | Processing file 38 of 50
# 34321 tracks processed, 5352 unique tracks added.
#
# Batch 8/20 | Processing file 39 of 50
# 37909 tracks processed, 7365 unique tracks added.
#
# Batch 8/20 | Processing file 40 of 50
# 34786 tracks processed, 5641 unique tracks added.
#
# Batch 8/20 | Processing file 41 of 50
# 34417 tracks processed, 5550 unique tracks added.
#
# Batch 8/20 | Processing file 42 of 50
# 33584 tracks processed, 5181 unique tracks added.
#
# Batch 8/20 | Processing file 43 of 50
# 35242 tracks processed, 6168 unique tracks added.
#
# Batch 8/20 | Processing file 44 of 50
# 35137 tracks processed, 5459 unique tracks added.
#
# Batch 8/20 | Processing file 45 of 50
# 35140 tracks processed, 5757 unique tracks added.
#
# Batch 8/20 | Processing file 46 of 50
# 35311 tracks processed, 5487 unique tracks added.
#
# Batch 8/20 | Processing file 47 of 50
# 34689 tracks processed, 5476 unique tracks added.
#
# Batch 8/20 | Processing file 48 of 50
# 36368 tracks processed, 6279 unique tracks added.
#
# Batch 8/20 | Processing file 49 of 50
# 34804 tracks processed, 5392 unique tracks added.
#
# Batch 8/20 | Processing file 50 of 50
# 34940 tracks processed, 5016 unique tracks added.
#
#
# Batch 8 complete.
#
# df final shape (465555, 7).
# ___________________________________________________________________
#
#
# Beginning batch #9 of 20
#
# df beginning with shape (64003, 9)
#
# Batch 9/20 | Processing file 1 of 50
# 34171 tracks processed, 0 unique tracks added.
#
# Batch 9/20 | Processing file 2 of 50
# 33956 tracks processed, 22020 unique tracks added.
#
# Batch 9/20 | Processing file 3 of 50
# 34413 tracks processed, 18315 unique tracks added.
#
# Batch 9/20 | Processing file 4 of 50
# 34803 tracks processed, 16739 unique tracks added.
#
# Batch 9/20 | Processing file 5 of 50
# 36462 tracks processed, 15655 unique tracks added.
#
# Batch 9/20 | Processing file 6 of 50
# 34611 tracks processed, 13657 unique tracks added.
#
# Batch 9/20 | Processing file 7 of 50
# 36130 tracks processed, 14210 unique tracks added.
#
# Batch 9/20 | Processing file 8 of 50
# 36134 tracks processed, 13570 unique tracks added.
#
# Batch 9/20 | Processing file 9 of 50
# 35465 tracks processed, 12100 unique tracks added.
#
# Batch 9/20 | Processing file 10 of 50
# 34941 tracks processed, 10894 unique tracks added.
#
# Batch 9/20 | Processing file 11 of 50
# 36409 tracks processed, 11417 unique tracks added.
#
# Batch 9/20 | Processing file 12 of 50
# 33248 tracks processed, 8869 unique tracks added.
#
# Batch 9/20 | Processing file 13 of 50
# 33815 tracks processed, 9669 unique tracks added.
#
# Batch 9/20 | Processing file 14 of 50
# 34449 tracks processed, 9160 unique tracks added.
#
# Batch 9/20 | Processing file 15 of 50
# 34378 tracks processed, 9039 unique tracks added.
#
# Batch 9/20 | Processing file 16 of 50
# 33940 tracks processed, 8943 unique tracks added.
#
# Batch 9/20 | Processing file 17 of 50
# 35958 tracks processed, 8955 unique tracks added.
#
# Batch 9/20 | Processing file 18 of 50
# 34948 tracks processed, 8486 unique tracks added.
#
# Batch 9/20 | Processing file 19 of 50
# 35409 tracks processed, 8641 unique tracks added.
#
# Batch 9/20 | Processing file 20 of 50
# 34671 tracks processed, 8558 unique tracks added.
#
# Batch 9/20 | Processing file 21 of 50
# 34614 tracks processed, 7871 unique tracks added.
#
# Batch 9/20 | Processing file 22 of 50
# 34724 tracks processed, 8222 unique tracks added.
#
# Batch 9/20 | Processing file 23 of 50
# 34666 tracks processed, 7334 unique tracks added.
#
# Batch 9/20 | Processing file 24 of 50
# 35838 tracks processed, 8306 unique tracks added.
#
# Batch 9/20 | Processing file 25 of 50
# 34172 tracks processed, 7198 unique tracks added.
#
# Batch 9/20 | Processing file 26 of 50
# 36044 tracks processed, 8514 unique tracks added.
#
# Batch 9/20 | Processing file 27 of 50
# 34926 tracks processed, 7027 unique tracks added.
#
# Batch 9/20 | Processing file 28 of 50
# 32633 tracks processed, 5942 unique tracks added.
#
# Batch 9/20 | Processing file 29 of 50
# 35954 tracks processed, 7356 unique tracks added.
#
# Batch 9/20 | Processing file 30 of 50
# 34593 tracks processed, 6441 unique tracks added.
#
# Batch 9/20 | Processing file 31 of 50
# 34062 tracks processed, 6442 unique tracks added.
#
# Batch 9/20 | Processing file 32 of 50
# 35572 tracks processed, 6919 unique tracks added.
#
# Batch 9/20 | Processing file 33 of 50
# 36325 tracks processed, 6795 unique tracks added.
#
# Batch 9/20 | Processing file 34 of 50
# 35453 tracks processed, 6843 unique tracks added.
#
# Batch 9/20 | Processing file 35 of 50
# 36404 tracks processed, 6968 unique tracks added.
#
# Batch 9/20 | Processing file 36 of 50
# 33926 tracks processed, 6571 unique tracks added.
#
# Batch 9/20 | Processing file 37 of 50
# 35786 tracks processed, 6226 unique tracks added.
#
# Batch 9/20 | Processing file 38 of 50
# 34903 tracks processed, 6092 unique tracks added.
#
# Batch 9/20 | Processing file 39 of 50
# 34163 tracks processed, 5705 unique tracks added.
#
# Batch 9/20 | Processing file 40 of 50
# 36850 tracks processed, 7131 unique tracks added.
#
# Batch 9/20 | Processing file 41 of 50
# 34361 tracks processed, 5641 unique tracks added.
#
# Batch 9/20 | Processing file 42 of 50
# 35661 tracks processed, 6382 unique tracks added.
#
# Batch 9/20 | Processing file 43 of 50
# 34773 tracks processed, 6352 unique tracks added.
#
# Batch 9/20 | Processing file 44 of 50
# 35855 tracks processed, 5949 unique tracks added.
#
# Batch 9/20 | Processing file 45 of 50
# 34752 tracks processed, 5305 unique tracks added.
#
# Batch 9/20 | Processing file 46 of 50
# 34334 tracks processed, 5645 unique tracks added.
#
# Batch 9/20 | Processing file 47 of 50
# 35548 tracks processed, 5879 unique tracks added.
#
# Batch 9/20 | Processing file 48 of 50
# 36490 tracks processed, 6155 unique tracks added.
#
# Batch 9/20 | Processing file 49 of 50
# 36626 tracks processed, 6157 unique tracks added.
#
# Batch 9/20 | Processing file 50 of 50
# 35677 tracks processed, 5292 unique tracks added.
#
#
# Batch 9 complete.
#
# df final shape (461728, 7).
# ___________________________________________________________________
#
#
# Beginning batch #10 of 20
#
# df beginning with shape (66709, 9)
#
# Batch 10/20 | Processing file 1 of 50
# 34686 tracks processed, 0 unique tracks added.
#
# Batch 10/20 | Processing file 2 of 50
# 36699 tracks processed, 23922 unique tracks added.
#
# Batch 10/20 | Processing file 3 of 50
# 35478 tracks processed, 19072 unique tracks added.
#
# Batch 10/20 | Processing file 4 of 50
# 33500 tracks processed, 15663 unique tracks added.
#
# Batch 10/20 | Processing file 5 of 50
# 35289 tracks processed, 15510 unique tracks added.
#
# Batch 10/20 | Processing file 6 of 50
# 33465 tracks processed, 13148 unique tracks added.
#
# Batch 10/20 | Processing file 7 of 50
# 36398 tracks processed, 13954 unique tracks added.
#
# Batch 10/20 | Processing file 8 of 50
# 35613 tracks processed, 12784 unique tracks added.
#
# Batch 10/20 | Processing file 9 of 50
# 36040 tracks processed, 12277 unique tracks added.
#
# Batch 10/20 | Processing file 10 of 50
# 35344 tracks processed, 11529 unique tracks added.
#
# Batch 10/20 | Processing file 11 of 50
# 34025 tracks processed, 10172 unique tracks added.
#
# Batch 10/20 | Processing file 12 of 50
# 36044 tracks processed, 11187 unique tracks added.
#
# Batch 10/20 | Processing file 13 of 50
# 36004 tracks processed, 10382 unique tracks added.
#
# Batch 10/20 | Processing file 14 of 50
# 34071 tracks processed, 9187 unique tracks added.
#
# Batch 10/20 | Processing file 15 of 50
# 35140 tracks processed, 10053 unique tracks added.
#
# Batch 10/20 | Processing file 16 of 50
# 35506 tracks processed, 9264 unique tracks added.
#
# Batch 10/20 | Processing file 17 of 50
# 33190 tracks processed, 8191 unique tracks added.
#
# Batch 10/20 | Processing file 18 of 50
# 33925 tracks processed, 8178 unique tracks added.
#
# Batch 10/20 | Processing file 19 of 50
# 36103 tracks processed, 9307 unique tracks added.
#
# Batch 10/20 | Processing file 20 of 50
# 36580 tracks processed, 8959 unique tracks added.
#
# Batch 10/20 | Processing file 21 of 50
# 33854 tracks processed, 7899 unique tracks added.
#
# Batch 10/20 | Processing file 22 of 50
# 34350 tracks processed, 7531 unique tracks added.
#
# Batch 10/20 | Processing file 23 of 50
# 33828 tracks processed, 7750 unique tracks added.
#
# Batch 10/20 | Processing file 24 of 50
# 33369 tracks processed, 6706 unique tracks added.
#
# Batch 10/20 | Processing file 25 of 50
# 35462 tracks processed, 7405 unique tracks added.
#
# Batch 10/20 | Processing file 26 of 50
# 36060 tracks processed, 7694 unique tracks added.
#
# Batch 10/20 | Processing file 27 of 50
# 34262 tracks processed, 6919 unique tracks added.
#
# Batch 10/20 | Processing file 28 of 50
# 35465 tracks processed, 7762 unique tracks added.
#
# Batch 10/20 | Processing file 29 of 50
# 35092 tracks processed, 6756 unique tracks added.
#
# Batch 10/20 | Processing file 30 of 50
# 34707 tracks processed, 6841 unique tracks added.
#
# Batch 10/20 | Processing file 31 of 50
# 34217 tracks processed, 6647 unique tracks added.
#
# Batch 10/20 | Processing file 32 of 50
# 35608 tracks processed, 7010 unique tracks added.
#
# Batch 10/20 | Processing file 33 of 50
# 33569 tracks processed, 5744 unique tracks added.
#
# Batch 10/20 | Processing file 34 of 50
# 36103 tracks processed, 7312 unique tracks added.
#
# Batch 10/20 | Processing file 35 of 50
# 37968 tracks processed, 7587 unique tracks added.
#
# Batch 10/20 | Processing file 36 of 50
# 36025 tracks processed, 7071 unique tracks added.
#
# Batch 10/20 | Processing file 37 of 50
# 33466 tracks processed, 5268 unique tracks added.
#
# Batch 10/20 | Processing file 38 of 50
# 35387 tracks processed, 6370 unique tracks added.
#
# Batch 10/20 | Processing file 39 of 50
# 34887 tracks processed, 6293 unique tracks added.
#
# Batch 10/20 | Processing file 40 of 50
# 36786 tracks processed, 7305 unique tracks added.
#
# Batch 10/20 | Processing file 41 of 50
# 34068 tracks processed, 5797 unique tracks added.
#
# Batch 10/20 | Processing file 42 of 50
# 33584 tracks processed, 5841 unique tracks added.
#
# Batch 10/20 | Processing file 43 of 50
# 35791 tracks processed, 5828 unique tracks added.
#
# Batch 10/20 | Processing file 44 of 50
# 35661 tracks processed, 5978 unique tracks added.
#
# Batch 10/20 | Processing file 45 of 50
# 34576 tracks processed, 5488 unique tracks added.
#
# Batch 10/20 | Processing file 46 of 50
# 33724 tracks processed, 5479 unique tracks added.
#
# Batch 10/20 | Processing file 47 of 50
# 36126 tracks processed, 5806 unique tracks added.
#
# Batch 10/20 | Processing file 48 of 50
# 35670 tracks processed, 5600 unique tracks added.
#
# Batch 10/20 | Processing file 49 of 50
# 35764 tracks processed, 5597 unique tracks added.
#
# Batch 10/20 | Processing file 50 of 50
# 34418 tracks processed, 5643 unique tracks added.
#
#
# Batch 10 complete.
#
# df final shape (464352, 7).
# ___________________________________________________________________
#
#
# Beginning batch #11 of 20
#
# df beginning with shape (65625, 9)
#
# Batch 11/20 | Processing file 1 of 50
# 35129 tracks processed, 0 unique tracks added.
#
# Batch 11/20 | Processing file 2 of 50
# 35922 tracks processed, 23590 unique tracks added.
#
# Batch 11/20 | Processing file 3 of 50
# 37329 tracks processed, 20673 unique tracks added.
#
# Batch 11/20 | Processing file 4 of 50
# 35243 tracks processed, 16585 unique tracks added.
#
# Batch 11/20 | Processing file 5 of 50
# 35089 tracks processed, 15475 unique tracks added.
#
# Batch 11/20 | Processing file 6 of 50
# 34949 tracks processed, 14244 unique tracks added.
#
# Batch 11/20 | Processing file 7 of 50
# 34347 tracks processed, 12245 unique tracks added.
#
# Batch 11/20 | Processing file 8 of 50
# 33904 tracks processed, 11812 unique tracks added.
#
# Batch 11/20 | Processing file 9 of 50
# 36018 tracks processed, 11772 unique tracks added.
#
# Batch 11/20 | Processing file 10 of 50
# 34888 tracks processed, 11146 unique tracks added.
#
# Batch 11/20 | Processing file 11 of 50
# 33806 tracks processed, 9826 unique tracks added.
#
# Batch 11/20 | Processing file 12 of 50
# 35191 tracks processed, 10882 unique tracks added.
#
# Batch 11/20 | Processing file 13 of 50
# 34233 tracks processed, 9373 unique tracks added.
#
# Batch 11/20 | Processing file 14 of 50
# 34875 tracks processed, 9081 unique tracks added.
#
# Batch 11/20 | Processing file 15 of 50
# 34330 tracks processed, 9107 unique tracks added.
#
# Batch 11/20 | Processing file 16 of 50
# 37146 tracks processed, 10725 unique tracks added.
#
# Batch 11/20 | Processing file 17 of 50
# 34114 tracks processed, 8411 unique tracks added.
#
# Batch 11/20 | Processing file 18 of 50
# ...
#
# Batch 17/20 | Processing file 32 of 50
# 35104 tracks processed, 6713 unique tracks added.
#
# Batch 17/20 | Processing file 33 of 50
# 35785 tracks processed, 7141 unique tracks added.
#
# Batch 17/20 | Processing file 34 of 50
# 33209 tracks processed, 5526 unique tracks added.
#
# Batch 17/20 | Processing file 35 of 50
# 35411 tracks processed, 6011 unique tracks added.
#
# Batch 17/20 | Processing file 36 of 50
# 35632 tracks processed, 6347 unique tracks added.
#
# Batch 17/20 | Processing file 37 of 50
# 35594 tracks processed, 6125 unique tracks added.
#
# Batch 17/20 | Processing file 38 of 50
# 34036 tracks processed, 5938 unique tracks added.
#
# Batch 17/20 | Processing file 39 of 50
# 33183 tracks processed, 5630 unique tracks added.
#
# Batch 17/20 | Processing file 40 of 50
# 35095 tracks processed, 5762 unique tracks added.
#
# Batch 17/20 | Processing file 41 of 50
# 36199 tracks processed, 6601 unique tracks added.
#
# Batch 17/20 | Processing file 42 of 50
# 35205 tracks processed, 6197 unique tracks added.
#
# Batch 17/20 | Processing file 43 of 50
# 35371 tracks processed, 6011 unique tracks added.
#
# Batch 17/20 | Processing file 44 of 50
# 34715 tracks processed, 6255 unique tracks added.
#
# Batch 17/20 | Processing file 45 of 50
# 35064 tracks processed, 5485 unique tracks added.
#
# Batch 17/20 | Processing file 46 of 50
# 35563 tracks processed, 5883 unique tracks added.
#
# Batch 17/20 | Processing file 47 of 50
# 35329 tracks processed, 5191 unique tracks added.
#
# Batch 17/20 | Processing file 48 of 50
# 33615 tracks processed, 5198 unique tracks added.
#
# Batch 17/20 | Processing file 49 of 50
# 35867 tracks processed, 6141 unique tracks added.
#
# Batch 17/20 | Processing file 50 of 50
# 34119 tracks processed, 4924 unique tracks added.
#
#
# Batch 17 complete.
#
# df final shape (464381, 7).
# ___________________________________________________________________
#
#
# Beginning batch #18 of 20
#
# df beginning with shape (69722, 9)
#
# Batch 18/20 | Processing file 1 of 50
# 35701 tracks processed, 0 unique tracks added.
#
# Batch 18/20 | Processing file 2 of 50
# 35362 tracks processed, 22638 unique tracks added.
#
# Batch 18/20 | Processing file 3 of 50
# 34169 tracks processed, 18220 unique tracks added.
#
# Batch 18/20 | Processing file 4 of 50
# 35654 tracks processed, 17557 unique tracks added.
#
# Batch 18/20 | Processing file 5 of 50
# 34522 tracks processed, 14437 unique tracks added.
#
# Batch 18/20 | Processing file 6 of 50
# 35487 tracks processed, 14872 unique tracks added.
#
# Batch 18/20 | Processing file 7 of 50
# 34676 tracks processed, 13203 unique tracks added.
#
# Batch 18/20 | Processing file 8 of 50
# 34718 tracks processed, 12444 unique tracks added.
#
# Batch 18/20 | Processing file 9 of 50
# 34874 tracks processed, 11604 unique tracks added.
#
# Batch 18/20 | Processing file 10 of 50
# 33661 tracks processed, 11261 unique tracks added.
#
# Batch 18/20 | Processing file 11 of 50
# 34356 tracks processed, 10681 unique tracks added.
#
# Batch 18/20 | Processing file 12 of 50
# 34453 tracks processed, 10209 unique tracks added.
#
# Batch 18/20 | Processing file 13 of 50
# 35615 tracks processed, 10924 unique tracks added.
#
# Batch 18/20 | Processing file 14 of 50
# 35465 tracks processed, 10342 unique tracks added.
#
# Batch 18/20 | Processing file 15 of 50
# 34582 tracks processed, 9502 unique tracks added.
#
# Batch 18/20 | Processing file 16 of 50
# 34755 tracks processed, 8992 unique tracks added.
#
# Batch 18/20 | Processing file 17 of 50
# 35770 tracks processed, 8998 unique tracks added.
#
# Batch 18/20 | Processing file 18 of 50
# 36855 tracks processed, 9969 unique tracks added.
#
# Batch 18/20 | Processing file 19 of 50
# 34990 tracks processed, 8649 unique tracks added.
#
# Batch 18/20 | Processing file 20 of 50
# 35165 tracks processed, 8296 unique tracks added.
#
# Batch 18/20 | Processing file 21 of 50
# 36966 tracks processed, 9286 unique tracks added.
#
# Batch 18/20 | Processing file 22 of 50
# 36006 tracks processed, 8472 unique tracks added.
#
# Batch 18/20 | Processing file 23 of 50
# 35837 tracks processed, 8432 unique tracks added.
#
# Batch 18/20 | Processing file 24 of 50
# 34679 tracks processed, 7565 unique tracks added.
#
# Batch 18/20 | Processing file 25 of 50
# 34556 tracks processed, 6968 unique tracks added.
#
# Batch 18/20 | Processing file 26 of 50
# 33768 tracks processed, 6698 unique tracks added.
#
# Batch 18/20 | Processing file 27 of 50
# 34644 tracks processed, 6927 unique tracks added.
#
# Batch 18/20 | Processing file 28 of 50
# 33200 tracks processed, 6701 unique tracks added.
#
# Batch 18/20 | Processing file 29 of 50
# 35141 tracks processed, 6740 unique tracks added.
#
# Batch 18/20 | Processing file 30 of 50
# 35940 tracks processed, 6982 unique tracks added.
#
# Batch 18/20 | Processing file 31 of 50
# 34424 tracks processed, 6035 unique tracks added.
#
# Batch 18/20 | Processing file 32 of 50
# 33368 tracks processed, 6025 unique tracks added.
#
# Batch 18/20 | Processing file 33 of 50
# 34491 tracks processed, 7002 unique tracks added.
#
# Batch 18/20 | Processing file 34 of 50
# 34783 tracks processed, 6338 unique tracks added.
#
# Batch 18/20 | Processing file 35 of 50
# 34691 tracks processed, 6450 unique tracks added.
#
# Batch 18/20 | Processing file 36 of 50
# 35790 tracks processed, 6783 unique tracks added.
#
# Batch 18/20 | Processing file 37 of 50
# 35298 tracks processed, 6248 unique tracks added.
#
# Batch 18/20 | Processing file 38 of 50
# 34630 tracks processed, 6099 unique tracks added.
#
# Batch 18/20 | Processing file 39 of 50
# 36075 tracks processed, 6514 unique tracks added.
#
# Batch 18/20 | Processing file 40 of 50
# 35490 tracks processed, 5904 unique tracks added.
#
# Batch 18/20 | Processing file 41 of 50
# 36299 tracks processed, 6222 unique tracks added.
#
# Batch 18/20 | Processing file 42 of 50
# 33818 tracks processed, 5687 unique tracks added.
#
# Batch 18/20 | Processing file 43 of 50
# 34610 tracks processed, 5496 unique tracks added.
#
# Batch 18/20 | Processing file 44 of 50
# 35882 tracks processed, 5379 unique tracks added.
#
# Batch 18/20 | Processing file 45 of 50
# 33636 tracks processed, 5085 unique tracks added.
#
# Batch 18/20 | Processing file 46 of 50
# 36230 tracks processed, 5564 unique tracks added.
#
# Batch 18/20 | Processing file 47 of 50
# 35729 tracks processed, 5960 unique tracks added.
#
# Batch 18/20 | Processing file 48 of 50
# 34121 tracks processed, 5150 unique tracks added.
#
# Batch 18/20 | Processing file 49 of 50
# 35832 tracks processed, 6165 unique tracks added.
#
# Batch 18/20 | Processing file 50 of 50
# 34897 tracks processed, 5630 unique tracks added.
#
#
# Batch 18 complete.
#
# df final shape (463006, 7).
# ___________________________________________________________________
#
#
# Beginning batch #19 of 20
#
# df beginning with shape (65664, 9)
#
# Batch 19/20 | Processing file 1 of 50
# 35780 tracks processed, 0 unique tracks added.
#
# Batch 19/20 | Processing file 2 of 50
# 34140 tracks processed, 21800 unique tracks added.
#
# Batch 19/20 | Processing file 3 of 50
# 33963 tracks processed, 18322 unique tracks added.
#
# Batch 19/20 | Processing file 4 of 50
# 36265 tracks processed, 18093 unique tracks added.
#
# Batch 19/20 | Processing file 5 of 50
# 35732 tracks processed, 16129 unique tracks added.
#
# Batch 19/20 | Processing file 6 of 50
# 34123 tracks processed, 13431 unique tracks added.
#
# Batch 19/20 | Processing file 7 of 50
# 33394 tracks processed, 12373 unique tracks added.
#
# Batch 19/20 | Processing file 8 of 50
# 34726 tracks processed, 12594 unique tracks added.
#
# Batch 19/20 | Processing file 9 of 50
# 33619 tracks processed, 11214 unique tracks added.
#
# Batch 19/20 | Processing file 10 of 50
# 34926 tracks processed, 11630 unique tracks added.
#
# Batch 19/20 | Processing file 11 of 50
# 35444 tracks processed, 11198 unique tracks added.
#
# Batch 19/20 | Processing file 12 of 50
# 34881 tracks processed, 10274 unique tracks added.
#
# Batch 19/20 | Processing file 13 of 50
# 33801 tracks processed, 9194 unique tracks added.
#
# Batch 19/20 | Processing file 14 of 50
# 34896 tracks processed, 10002 unique tracks added.
#
# Batch 19/20 | Processing file 15 of 50
# 33509 tracks processed, 9129 unique tracks added.
#
# Batch 19/20 | Processing file 16 of 50
# 34862 tracks processed, 9046 unique tracks added.
#
# Batch 19/20 | Processing file 17 of 50
# 33156 tracks processed, 8368 unique tracks added.
#
# Batch 19/20 | Processing file 18 of 50
# 35927 tracks processed, 9439 unique tracks added.
#
# Batch 19/20 | Processing file 19 of 50
# 34340 tracks processed, 8714 unique tracks added.
#
# Batch 19/20 | Processing file 20 of 50
# 35144 tracks processed, 8658 unique tracks added.
#
# Batch 19/20 | Processing file 21 of 50
# 35772 tracks processed, 8693 unique tracks added.
#
# Batch 19/20 | Processing file 22 of 50
# 34335 tracks processed, 7836 unique tracks added.
#
# Batch 19/20 | Processing file 23 of 50
# 35498 tracks processed, 8048 unique tracks added.
#
# Batch 19/20 | Processing file 24 of 50
# 36809 tracks processed, 8604 unique tracks added.
#
# Batch 19/20 | Processing file 25 of 50
# 33558 tracks processed, 6692 unique tracks added.
#
# Batch 19/20 | Processing file 26 of 50
# 36550 tracks processed, 8197 unique tracks added.
#
# Batch 19/20 | Processing file 27 of 50
# 34423 tracks processed, 7135 unique tracks added.
#
# Batch 19/20 | Processing file 28 of 50
# 35910 tracks processed, 8229 unique tracks added.
#
# Batch 19/20 | Processing file 29 of 50
# 35372 tracks processed, 7395 unique tracks added.
#
# Batch 19/20 | Processing file 30 of 50
# 35036 tracks processed, 7168 unique tracks added.
#
# Batch 19/20 | Processing file 31 of 50
# 35621 tracks processed, 6491 unique tracks added.
#
# Batch 19/20 | Processing file 32 of 50
# 33943 tracks processed, 6605 unique tracks added.
#
# Batch 19/20 | Processing file 33 of 50
# 35970 tracks processed, 7268 unique tracks added.
#
# Batch 19/20 | Processing file 34 of 50
# 35192 tracks processed, 6668 unique tracks added.
#
# Batch 19/20 | Processing file 35 of 50
# 35179 tracks processed, 6276 unique tracks added.
#
# Batch 19/20 | Processing file 36 of 50
# 34352 tracks processed, 6335 unique tracks added.
#
# Batch 19/20 | Processing file 37 of 50
# 36298 tracks processed, 6863 unique tracks added.
#
# Batch 19/20 | Processing file 38 of 50
# 33278 tracks processed, 5608 unique tracks added.
#
# Batch 19/20 | Processing file 39 of 50
# 35169 tracks processed, 6025 unique tracks added.
#
# Batch 19/20 | Processing file 40 of 50
# 34684 tracks processed, 5697 unique tracks added.
#
# Batch 19/20 | Processing file 41 of 50
# 34117 tracks processed, 5080 unique tracks added.
#
# Batch 19/20 | Processing file 42 of 50
# 35944 tracks processed, 5975 unique tracks added.
#
# Batch 19/20 | Processing file 43 of 50
# 36926 tracks processed, 6297 unique tracks added.
#
# Batch 19/20 | Processing file 44 of 50
# 36142 tracks processed, 6489 unique tracks added.
#
# Batch 19/20 | Processing file 45 of 50
# 34462 tracks processed, 5377 unique tracks added.
#
# Batch 19/20 | Processing file 46 of 50
# 34910 tracks processed, 5437 unique tracks added.
#
# Batch 19/20 | Processing file 47 of 50
# 37374 tracks processed, 6386 unique tracks added.
#
# Batch 19/20 | Processing file 48 of 50
# 34417 tracks processed, 5450 unique tracks added.
#
# Batch 19/20 | Processing file 49 of 50
# 34932 tracks processed, 5301 unique tracks added.
#
# Batch 19/20 | Processing file 50 of 50
# 35451 tracks processed, 5622 unique tracks added.
#
#
# Batch 19 complete.
#
# df final shape (464635, 7).
# ___________________________________________________________________
#
#
# Beginning batch #20 of 20
#
# df beginning with shape (64071, 9)
#
# Batch 20/20 | Processing file 1 of 50
# 34098 tracks processed, 0 unique tracks added.
#
# Batch 20/20 | Processing file 2 of 50
# 33918 tracks processed, 21871 unique tracks added.
#
# Batch 20/20 | Processing file 3 of 50
# 33900 tracks processed, 18279 unique tracks added.
#
# Batch 20/20 | Processing file 4 of 50
# 33290 tracks processed, 15710 unique tracks added.
#
# Batch 20/20 | Processing file 5 of 50
# 35858 tracks processed, 16247 unique tracks added.
#
# Batch 20/20 | Processing file 6 of 50
# 33746 tracks processed, 13647 unique tracks added.
#
# Batch 20/20 | Processing file 7 of 50
# 34193 tracks processed, 13248 unique tracks added.
#
# Batch 20/20 | Processing file 8 of 50
# 34852 tracks processed, 12898 unique tracks added.
#
# Batch 20/20 | Processing file 9 of 50
# 34487 tracks processed, 11711 unique tracks added.
#
# Batch 20/20 | Processing file 10 of 50
# 35242 tracks processed, 11911 unique tracks added.
#
# Batch 20/20 | Processing file 11 of 50
# 35622 tracks processed, 11606 unique tracks added.
#
# Batch 20/20 | Processing file 12 of 50
# 34386 tracks processed, 10705 unique tracks added.
#
# Batch 20/20 | Processing file 13 of 50
# 35928 tracks processed, 10440 unique tracks added.
#
# Batch 20/20 | Processing file 14 of 50
# 33803 tracks processed, 9279 unique tracks added.
#
# Batch 20/20 | Processing file 15 of 50
# 35059 tracks processed, 9111 unique tracks added.
#
# Batch 20/20 | Processing file 16 of 50
# 33882 tracks processed, 9007 unique tracks added.
#
# Batch 20/20 | Processing file 17 of 50
# 34231 tracks processed, 8684 unique tracks added.
#
# Batch 20/20 | Processing file 18 of 50
# 35265 tracks processed, 9007 unique tracks added.
#
# Batch 20/20 | Processing file 19 of 50
# 35887 tracks processed, 8870 unique tracks added.
#
# Batch 20/20 | Processing file 20 of 50
# 34964 tracks processed, 8159 unique tracks added.
#
# Batch 20/20 | Processing file 21 of 50
# 36277 tracks processed, 8894 unique tracks added.
#
# Batch 20/20 | Processing file 22 of 50
# 34916 tracks processed, 7918 unique tracks added.
#
# Batch 20/20 | Processing file 23 of 50
# 35454 tracks processed, 8234 unique tracks added.
#
# Batch 20/20 | Processing file 24 of 50
# 36990 tracks processed, 8690 unique tracks added.
#
# Batch 20/20 | Processing file 25 of 50
# 34396 tracks processed, 7548 unique tracks added.
#
# Batch 20/20 | Processing file 26 of 50
# 36030 tracks processed, 7486 unique tracks added.
#
# Batch 20/20 | Processing file 27 of 50
# 34582 tracks processed, 6895 unique tracks added.
#
# Batch 20/20 | Processing file 28 of 50
# 35117 tracks processed, 7043 unique tracks added.
#
# Batch 20/20 | Processing file 29 of 50
# 35610 tracks processed, 7641 unique tracks added.
#
# Batch 20/20 | Processing file 30 of 50
# 35632 tracks processed, 7503 unique tracks added.
#
# Batch 20/20 | Processing file 31 of 50
# 34430 tracks processed, 6704 unique tracks added.
#
# Batch 20/20 | Processing file 32 of 50
# 34769 tracks processed, 6454 unique tracks added.
#
# Batch 20/20 | Processing file 33 of 50
# 35053 tracks processed, 6385 unique tracks added.
#
# Batch 20/20 | Processing file 34 of 50
# 34207 tracks processed, 6787 unique tracks added.
#
# Batch 20/20 | Processing file 35 of 50
# 36726 tracks processed, 7625 unique tracks added.
#
# Batch 20/20 | Processing file 36 of 50
# 33323 tracks processed, 5614 unique tracks added.
#
# Batch 20/20 | Processing file 37 of 50
# 34430 tracks processed, 5779 unique tracks added.
#
# Batch 20/20 | Processing file 38 of 50
# 34468 tracks processed, 5947 unique tracks added.
#
# Batch 20/20 | Processing file 39 of 50
# 35480 tracks processed, 6377 unique tracks added.
#
# Batch 20/20 | Processing file 40 of 50
# 35579 tracks processed, 5756 unique tracks added.
#
# Batch 20/20 | Processing file 41 of 50
# 33732 tracks processed, 5683 unique tracks added.
#
# Batch 20/20 | Processing file 42 of 50
# 35900 tracks processed, 6268 unique tracks added.
#
# Batch 20/20 | Processing file 43 of 50
# 35399 tracks processed, 5848 unique tracks added.
#
# Batch 20/20 | Processing file 44 of 50
# 35036 tracks processed, 6191 unique tracks added.
#
# Batch 20/20 | Processing file 45 of 50
# 33623 tracks processed, 5144 unique tracks added.
#
# Batch 20/20 | Processing file 46 of 50
# 34016 tracks processed, 5553 unique tracks added.
#
# Batch 20/20 | Processing file 47 of 50
# 35077 tracks processed, 5269 unique tracks added.
#
# Batch 20/20 | Processing file 48 of 50
# 34704 tracks processed, 5632 unique tracks added.
#
# Batch 20/20 | Processing file 49 of 50
# 35523 tracks processed, 6017 unique tracks added.
#
# Batch 20/20 | Processing file 50 of 50
# 35816 tracks processed, 5886 unique tracks added.
#
#
# Batch 20 complete.
#
# df final shape (463259, 7).
# ___________________________________________________________________
#
#
# Now combining batches...
#
#
# Now saving unique tracks to csv...
# unique_tracks.csv saved to ../data

# %%
pd.read_csv(f"{output_filepath_root}/unique_tracks.csv")
# Out:
#                                                 track_name  \
# 0                                 FUCKING BEST SONG EVERRR
# 1                                            #STUPiDFACEDD
# 2                                I Got Soul, I'm So Wasted
# 3        We Are Young (feat. Janelle Monáe) - feat. Jan...
# 4                                                Boyfriend
# ...                                                    ...
# 2262287                               Now You're a Dreamer
# 2262288                         The Least of Your Brothers
# 2262289                                          Blood Red
# 2262290                          Poseidon's Fury Unleashed
# 2262291                                       Harlem Shake
#
#                                     track_uri                album_name  \
# 0        spotify:track:6SbAbLqAWf2tnTdUy6Gmm5  FUCKING BEST SONG EVERRR
# 1        spotify:track:1MvpPH6BTP3IrLnTjEA2gw             #STUPiDFACEDD
# 2        spotify:track:1wBsDNh4BMUyjmGc0fgHJv               Doodoo Face
# 3        spotify:track:5rgy6ghBq1eRApCkeUdJXf               Some Nights
# 4        spotify:track:07dYGGSrzPeg6a3KZjWX65                   Believe
# ...                                       ...                       ...
# 2262287  spotify:track:45t7ZbypVdTYbrs0WfL1sI                    Tattoo
# 2262288  spotify:track:464nM8hYCcKhTsZIYHNjSH           Leverage Models
# 2262289  spotify:track:2gnbjeFwGoWjF86uJfmPVA      Seasons In The Abyss
# 2262290  spotify:track:2CTu7Hk7ejfTNh3922pFrc          Through the Gale
# 2262291  spotify:track:6dgQxjDC48pghxVXDW2wLE  50 Best Summer Hits 2013
#
#                                     album_uri              artist_name  \
# 0        spotify:album:1hmvZb81DAeTx67G1FaTjZ               Wallpaper.
# 1        spotify:album:1c7wJm9mghFyIKnQJOobW8               Wallpaper.
# 2        spotify:album:0zSZPABfVbwm2Eo06M7DLV               Wallpaper.
# 3        spotify:album:7m7F7SQ3BXvIpvOgjW51Gp                     fun.
# 4        spotify:album:7BWK3eXcbAdwYeulyQj5Kw            Justin Bieber
# ...                                       ...                      ...
# 2262287  spotify:album:7xqtwaOCctSSqsHUxRiD16                 Raindeer
# 2262288  spotify:album:6iPAonht2Qkv9GM8Zg9hZU          Leverage Models
# 2262289  spotify:album:1OV8gLNyoCSAijC54d1RAM                   Slayer
# 2262290  spotify:album:2s5iW3fhyjy3blw1XTJ5qN  Asaf Avidan & the Mojos
# 2262291  spotify:album:1tFN5wyqNDGeHRsZAVgeSb                  DJ Hush
#
#                                     artist_uri  duration_ms
# 0        spotify:artist:6NMcnx3vKGSAeqSMbySlpw       217800
# 1        spotify:artist:6NMcnx3vKGSAeqSMbySlpw       184026
# 2        spotify:artist:6NMcnx3vKGSAeqSMbySlpw       188666
# 3        spotify:artist:5nCi3BB41mBaMH9gfr6Su0       250626
# 4        spotify:artist:1uNFoZAHBGtllmzznpCI3s       171333
# ...                                        ...          ...
# 2262287  spotify:artist:6DtbmyUQDSdTgEer4Ov0mk       228000
# 2262288  spotify:artist:29f5yeDOR0NP9IwDpWhRYl       287413
# 2262289  spotify:artist:1IQ2e1buppatiN1bxUVkrk       167946
# 2262290  spotify:artist:2TwepUY7feaTuipStcyzLZ       308825
# 2262291  spotify:artist:3TfeTqSuNmFx12rikZDKe9       198818
#
# [2262292 rows x 7 columns]

# %% [markdown]
# # 4. Create URI Dictionaries

# %%
# Load df of unique tracks
df = pd.read_csv(f"{output_filepath_root}/unique_tracks.csv")

unique_albums = df.drop_duplicates(subset=['album_uri']).drop(columns=['track_name', 'track_uri', 'artist_name', 'artist_uri', 'duration_ms'])
display(unique_albums)

unique_artists = df.drop_duplicates(subset=['artist_uri']).drop(columns=['track_name', 'track_uri', 'album_name', 'album_uri', 'duration_ms'])
display(unique_artists)

# Save these new DFs to csv and load them in subsequent notebook and convert to dictionaries
try:
    unique_albums.to_csv(f"{output_filepath_root}/unique_albums.csv", index=False)
    print(f"unique_albums.csv saved to {output_filepath_root}")
    unique_artists.to_csv(f"{output_filepath_root}/unique_artists.csv", index=False)
    print(f"unique_artists.csv saved to {output_filepath_root}")
except:
    print("CSV saving failed.")
# Out:
#                                                album_name  \
# 0                                FUCKING BEST SONG EVERRR
# 1                                           #STUPiDFACEDD
# 2                                             Doodoo Face
# 3                                             Some Nights
# 4                                                 Believe
# ...                                                   ...
# 2262276  Nos plus belles années en karaoké (2010, Vol. 3)
# 2262278                                    Hinos Cristãos
# 2262280                              Projeto Sola, Vol. 1
# 2262281                                      Eu Sou Livre
# 2262285                                           Atenção
#
#                                     album_uri
# 0        spotify:album:1hmvZb81DAeTx67G1FaTjZ
# 1        spotify:album:1c7wJm9mghFyIKnQJOobW8
# 2        spotify:album:0zSZPABfVbwm2Eo06M7DLV
# 3        spotify:album:7m7F7SQ3BXvIpvOgjW51Gp
# 4        spotify:album:7BWK3eXcbAdwYeulyQj5Kw
# ...                                       ...
# 2262276  spotify:album:3DbpnzDllFgVrYokPoiAoB
# 2262278  spotify:album:0Lv5WPtHWyTUZZNl2ISpww
# 2262280  spotify:album:0kDdi8xm92orRihrMbilRV
# 2262281  spotify:album:23O2Sf7BGe62TzjYdVP8wu
# 2262285  spotify:album:2rHADG7y9aT9e3MZIqg5zD
#
# [734684 rows x 2 columns]
#              artist_name                             artist_uri
# 0             Wallpaper.  spotify:artist:6NMcnx3vKGSAeqSMbySlpw
# 3                   fun.  spotify:artist:5nCi3BB41mBaMH9gfr6Su0
# 4          Justin Bieber  spotify:artist:1uNFoZAHBGtllmzznpCI3s
# 5               Flo Rida  spotify:artist:0jnsk9HBra6NMjO2oANoPY
# 6          One Direction  spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq
# ...                  ...                                    ...
# 2262261           Patrin  spotify:artist:1RDa9v2OMcvWYoHRoL29tw
# 2262262       M.A.S 0094  spotify:artist:5nrFv8M9OSiVAAbTdZobyR
# 2262265         H.M.A.K.  spotify:artist:6Ulu5YIzdOHWyOJnd9kodK
# 2262278  Agostinho Silva  spotify:artist:0TXLDLJB5yPsXs3lhshSrs
# 2262281               PG  spotify:artist:5K2gAsDWIVqU9rlCyxp4jM
#
# [295860 rows x 2 columns]
# unique_albums.csv saved to ../data
# unique_artists.csv saved to ../data

# %% [markdown]
# ___
