# %% [markdown]
# # Testing the Baseline Models
# Saved in the `baselinemodels` module

# %% [markdown]
# ### Imports

# %%
import random
import os
import csv

# from tqdm import tqdm # for scripts
from tqdm.auto import tqdm # for notebooks
tqdm.pandas()

import numpy as np
import pandas as pd

import tensorflow as tf

# Update as needed, for example: from jlj.baselinemodels import BaselineModels
from baselinemodels import BaselineModels

# %% [markdown]
# # Importing 2017 data
# Copying cells from `load_2017_data.ipynb` notebook, which produces the following:
#
# Loads the following csv's into **DataFrames**:
# - `playlist_2017.csv` $\rightarrow$ `playlist_df`
# - `tracks_2017.csv` $\rightarrow$ `track_df`
# - `albums_2017.csv` $\rightarrow$ `album_df`
# - `artist_2017.csv` $\rightarrow$ `artist_df`
#
# Then, the following **dictionaries** are created:
# - `playlist_dict`
# - `track_dict`
# - `album_dict`
# - `artist_dict`
#
# As well as the following **functions**:
# - `get_playlist_feature(PID, feature)`
# - `get_track_feature(URI, feature)`
# - `get_album_feature(URI, feature)`
# - `get_artist_feature(URI, feature)`

# %% [markdown]
# ### Update data path as needed

# %%
# path to the DIRECTORY where CSV files are saved relative to this notebook
path = '../data'
output_filepath_root = os.path.relpath(path)
print(output_filepath_root)
# Out:
# ../data

# %% [markdown]
# ## Load 2017 CSVs to DFs

# %% [markdown]
# ### Playlists

# %%
playlist_df = pd.read_csv(os.path.join(output_filepath_root, 'playlists_2017.csv'), index_col='pid')
playlist_df.head(5)
# Out:
#             name description  modified_at  num_artists  num_albums  \
# pid
# 434000       Sad         NaN   1488240000           24          26
# 434001      pb&j   faves tbh   1487808000           35          38
# 434004  Whatever         NaN   1506816000           36          57
# 434005  roadtrip         NaN   1492905600           30          35
# 434007   Cumbias         NaN   1507507200           23          42
#
#         num_tracks  num_followers  num_edits  duration_ms  collaborative  ...  \
# pid                                                                       ...
# 434000          27              1          6      6081757          False  ...
# 434001          39              1          9      8959761          False  ...
# 434004          79              1         46     18874072          False  ...
# 434005          70              1         18     15696608          False  ...
# 434007          50              1         21     10255699          False  ...
#
#                           track_14_album_uri  \
# pid
# 434000  spotify:album:4M9Ti6t5h54aDMX4SizDfT
# 434001  spotify:album:6deiaArbeoqp1xPEGdEKp1
# 434004  spotify:album:2Tyx5dLhHYkx6zeAdVaTzN
# 434005  spotify:album:6DwdzG4UGYLxJ2p7bd483v
# 434007  spotify:album:392uNMyh5D6fqkBS385XJd
#
#                           track_14_artist_uri  \
# pid
# 434000  spotify:artist:4vVfuZfXWu18vk5Z4C7wbm
# 434001  spotify:artist:0L8ExT028jH3ddEcZwqJJ5
# 434004  spotify:artist:4LLpKhyESsyAXpc4laK94U
# 434005  spotify:artist:2Q0MyH5YMI5HPQjFjlq5g3
# 434007  spotify:artist:3zzeZVLuOeetfimOd4k8rE
#
#                                 track_15_uri  \
# pid
# 434000  spotify:track:3yrVRdwCbEeKODZgG2mVZX
# 434001  spotify:track:5E30LdtzQTGqRvNd7l6kG5
# 434004  spotify:track:0htTZnlk6okQ1HIq4EvFQ6
# 434005  spotify:track:4XvKjZWIqsHvvza89lMTAH
# 434007  spotify:track:1yOLrH7nF0R7MWDuuva6va
#
#                           track_15_album_uri  \
# pid
# 434000  spotify:album:3SCJmoy3Z45p84IfuaM9YQ
# 434001  spotify:album:18iFxjZugvKhuNNMbLjZJF
# 434004  spotify:album:6liIoWzpvrff945pUI7fHt
# 434005  spotify:album:6izXZb0VGaUHqm5GaXq4YC
# 434007  spotify:album:2rXbAorimO8C06RkqS2oq5
#
#                           track_15_artist_uri modified_at_date  \
# pid
# 434000  spotify:artist:2EO56JK4txid1Pss9GVbOL       2017-02-28
# 434001  spotify:artist:77SW9BnxLY8rJ0RciFqkHh       2017-02-23
# 434004  spotify:artist:02kJSzxNuaWGqwubyUba0Z       2017-10-01
# 434005  spotify:artist:5IXalAOiV9I8LgLMGZydmt       2017-04-23
# 434007  spotify:artist:0OhiQFSqbnnmB52NWEpsO5       2017-10-09
#
#        modified_at_year modified_at_month modified_at_day modified_at_dow
# pid
# 434000             2017                 2              28               1
# 434001             2017                 2              23               3
# 434004             2017                10               1               6
# 434005             2017                 4              23               6
# 434007             2017                10               9               0
#
# [5 rows x 60 columns]

# %% [markdown]
# ### Tracks

# %%
track_df = pd.read_csv(os.path.join(output_filepath_root, 'tracks_2017.csv'), index_col='track_uri')
track_df.head(5)
# Out:
#                                       index  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5      0
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw      1
# spotify:track:5rgy6ghBq1eRApCkeUdJXf      2
# spotify:track:07dYGGSrzPeg6a3KZjWX65      3
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3      4
#
#                                                                              track_name  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5                           FUCKING BEST SONG EVERRR
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw                                      #STUPiDFACEDD
# spotify:track:5rgy6ghBq1eRApCkeUdJXf  We Are Young (feat. Janelle Monáe) - feat. Jan...
# spotify:track:07dYGGSrzPeg6a3KZjWX65                                          Boyfriend
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3                              Wild Ones (feat. Sia)
#
#                                                     album_name  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5  FUCKING BEST SONG EVERRR
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw             #STUPiDFACEDD
# spotify:track:5rgy6ghBq1eRApCkeUdJXf               Some Nights
# spotify:track:07dYGGSrzPeg6a3KZjWX65                   Believe
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3                 Wild Ones
#
#                                                                  album_uri  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5  spotify:album:1hmvZb81DAeTx67G1FaTjZ
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw  spotify:album:1c7wJm9mghFyIKnQJOobW8
# spotify:track:5rgy6ghBq1eRApCkeUdJXf  spotify:album:7m7F7SQ3BXvIpvOgjW51Gp
# spotify:track:07dYGGSrzPeg6a3KZjWX65  spotify:album:7BWK3eXcbAdwYeulyQj5Kw
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3  spotify:album:7eLwoxxWs6lfkVYJGkGNbk
#
#                                         artist_name  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5     Wallpaper.
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw     Wallpaper.
# spotify:track:5rgy6ghBq1eRApCkeUdJXf           fun.
# spotify:track:07dYGGSrzPeg6a3KZjWX65  Justin Bieber
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3       Flo Rida
#
#                                                                  artist_uri  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5  spotify:artist:6NMcnx3vKGSAeqSMbySlpw
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw  spotify:artist:6NMcnx3vKGSAeqSMbySlpw
# spotify:track:5rgy6ghBq1eRApCkeUdJXf  spotify:artist:5nCi3BB41mBaMH9gfr6Su0
# spotify:track:07dYGGSrzPeg6a3KZjWX65  spotify:artist:1uNFoZAHBGtllmzznpCI3s
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3  spotify:artist:0jnsk9HBra6NMjO2oANoPY
#
#                                       duration_ms  appears_in_count  \
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5       217800                53
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw       184026                39
# spotify:track:5rgy6ghBq1eRApCkeUdJXf       250626              1276
# spotify:track:07dYGGSrzPeg6a3KZjWX65       171333               704
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3       232946               952
#
#                                       popularity
# track_uri
# spotify:track:6SbAbLqAWf2tnTdUy6Gmm5          53
# spotify:track:1MvpPH6BTP3IrLnTjEA2gw          39
# spotify:track:5rgy6ghBq1eRApCkeUdJXf        1276
# spotify:track:07dYGGSrzPeg6a3KZjWX65         704
# spotify:track:1NpW5kyvO4XrNJ3rnfcNy3         952

# %% [markdown]
# ### Albums

# %%
album_df = pd.read_csv(os.path.join(output_filepath_root, 'albums_2017.csv'), index_col='album_uri')
album_df.head(5)
# Out:
#                                                     album_name    artist_name
# album_uri
# spotify:album:1hmvZb81DAeTx67G1FaTjZ  FUCKING BEST SONG EVERRR     Wallpaper.
# spotify:album:1c7wJm9mghFyIKnQJOobW8             #STUPiDFACEDD     Wallpaper.
# spotify:album:7m7F7SQ3BXvIpvOgjW51Gp               Some Nights           fun.
# spotify:album:7BWK3eXcbAdwYeulyQj5Kw                   Believe  Justin Bieber
# spotify:album:7eLwoxxWs6lfkVYJGkGNbk                 Wild Ones       Flo Rida

# %% [markdown]
# ### Artists

# %%
artist_df = pd.read_csv(os.path.join(output_filepath_root, 'artists_2017.csv'), index_col='artist_uri')
artist_df.head(5)
# Out:
#                                          artist_name
# artist_uri
# spotify:artist:6NMcnx3vKGSAeqSMbySlpw     Wallpaper.
# spotify:artist:5nCi3BB41mBaMH9gfr6Su0           fun.
# spotify:artist:1uNFoZAHBGtllmzznpCI3s  Justin Bieber
# spotify:artist:0jnsk9HBra6NMjO2oANoPY       Flo Rida
# spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq  One Direction

# %% [markdown]
# ## Create Dictionaries

# %% [markdown]
# ### Playlists

# %%
playlist_dict = playlist_df.to_dict()

# %%
def get_playlist_feature(pid, feature='name', dictionary=playlist_dict):
    """
    Given a playlist PID (as a integer) and the playlist dictionary, return the requested feature.
    
    Features include:
        - 'name'
        - 'description'
        - 'modified_at'
        - 'modified_at_date'
        - 'modified_at_year'
        - 'modified_at_month'
        - 'modified_at_day'
        - 'modified_at_dow'
        - 'num_artists'
        - 'num_albums'
        - 'num_tracks'
        - 'num_followers'
        - 'num_edits'
        - 'duration_ms'
        - 'collaborative'
        - 'track_X_uri'
        - 'track_X_album_uri'
        - 'track_X_artist_uri'
    """
    # Convert PID to integer
    try:
        pid = int(pid)
    except Exception as e:
        return e
    # Lookup in dictionary
    try:
        return dictionary[feature][pid]
    except Exception as e:
        return e

# %%
get_playlist_feature('434004', 'name')
# Out:
# 'Whatever'

# %% [markdown]
# ### Tracks

# %%
track_dict = track_df.to_dict()

# %%
def get_track_feature(uri, feature='track_name', dictionary=track_dict):
    """
    Given a track uri (as a string) and the track dictionary, return the requested feature.
    
    Features include:
        - 'track_name'
        - 'album_name'
        - 'album_uri'
        - 'artist_name'
        - 'artist_uri'
        - 'duration_ms'
    """
    try:
        return dictionary[feature][uri]
    except Exception as e:
        return e

# %%
get_track_feature('spotify:track:5rgy6ghBq1eRApCkeUdJXf', 'album_name')
# Out:
# 'Some Nights'

# %% [markdown]
# ### Albums

# %%
album_dict = album_df.to_dict()

# %%
def get_album_feature(uri, feature='album_name', dictionary=album_dict):
    """
    Given an album uri (as a string) and the album dictionary, return the requested feature.
    
    Features include:
        - 'album_name'
        - 'artist_name'
    """
    try:
        return dictionary[feature][uri]
    except Exception as e:
        return e

# %%
get_album_feature('spotify:album:7BWK3eXcbAdwYeulyQj5Kw', 'artist_name')
# Out:
# 'Justin Bieber'

# %% [markdown]
# ### Artists

# %%
artist_dict = artist_df.to_dict()

# %%
def get_artist_feature(uri, feature='artist_name', dictionary=artist_dict):
    """
    Given an artist uri (as a string) and the artist dictionary, return the requested feature.
    
    Features include:
        - 'artist_name'
    """
    try:
        return dictionary[feature][uri]
    except Exception as e:
        return e

# %%
get_artist_feature('spotify:artist:1uNFoZAHBGtllmzznpCI3s')
# Out:
# 'Justin Bieber'

# %%
track_uri_cols = [col for col in playlist_df.columns
                  if 'uri' in col
                  and 'album' not in col
                  and 'artist' not in col]
track_uri_cols
# Out:
# ['track_1_uri',
#  'track_2_uri',
#  'track_3_uri',
#  'track_4_uri',
#  'track_5_uri',
#  'track_6_uri',
#  'track_7_uri',
#  'track_8_uri',
#  'track_9_uri',
#  'track_10_uri',
#  'track_11_uri',
#  'track_12_uri',
#  'track_13_uri',
#  'track_14_uri',
#  'track_15_uri']

# %% [markdown]
# ___
# # Baseline Models
# Initialize with `BaselineModels(playlist_df, track_df)`
#
# Functions:
# - `calculate_track_popularities(pop_col_name=<string>)`
# - `recommend_tracks_by_artists(num_tracks=5, input_track_uris=[], popularity=True)`
# - `recommend_tracks_by_albums(num_tracks=5, input_track_uris=[], popularity=True)`
# - `recommend_popular_tracks(num_tracks=5, input_track_uris=[], popularity=True)`

# %%
def random_tracks(num_tracks=5):
    return track_df.sample(num_tracks).reset_index()

# %% [markdown]
# ## Baseline 1 — Artist

# %%
get_track_feature('spotify:track:6SbAbLqAWf2tnTdUy6Gmm5')
# Out:
# 'FUCKING BEST SONG EVERRR'

# %%
baseline_models = BaselineModels(playlist_df=playlist_df, track_df=track_df)

# %%
tracks = random_tracks(20)
display(tracks)
track_uris = tracks.track_uri.to_list()
display(track_uris)
display([get_track_feature(uri) for uri in track_uris])
display([get_track_feature(uri, 'artist_name') for uri in track_uris])
# Out:
#                                track_uri   index  \
# 0   spotify:track:2z2HMfMK1vR4BZLL6JIWgV  230277
# 1   spotify:track:2oA6tAT5u3cc8ND5crtH0k   90261
# 2   spotify:track:5Am1Vy5vnBnu7pbTJUBzlc  446895
# 3   spotify:track:6xlw9Qx9VDEvTdxOT98wFd   98622
# 4   spotify:track:6I2fP8K1GbElogsAekOQfd  195992
# 5   spotify:track:0Hap9hOcxX0ywu8q9FkcQO  250837
# 6   spotify:track:4qpBYiY4YeTRN2D4Iv3tcF  491749
# 7   spotify:track:4K84p5DmcoUm3pp64qzkHY  355713
# 8   spotify:track:78U6lqeWK6Uie4jneibj9o  124300
# 9   spotify:track:79MZL2xQVtxULJIOqrJ4lA  253830
# 10  spotify:track:7cQnIhLin7koR2sO2bt2KS   30707
# 11  spotify:track:4nBW45Y4EVoaeggnS2r2Xp  609625
# 12  spotify:track:688DZF6e1MH5Uf409dwaHm    4845
# 13  spotify:track:1EmE0i81dj6zuqqDdY4B0o   23694
# 14  spotify:track:6tkFPLPrY97itA4Hbpa3Dp  242827
# 15  spotify:track:6HsKzNUXenFnXhpEteenK8   23865
# 16  spotify:track:3t708maRP7qBBuvRmNbWxS  422630
# 17  spotify:track:0FXfAepEmqVCMnvOpb8Hoj   41769
# 18  spotify:track:5aIVRSOeadwiwvkssC2aut  558152
# 19  spotify:track:1LdBSURpSKoZAzdLj9FrlH  501999
#
#                                   track_name  \
# 0                          Te quiero, te amo
# 1                                 Black Eyes
# 2                                    Fastnet
# 3                               BillyThe Kid
# 4     Dragon Soul (From "Dragon Ball Z Kai")
# 5         Unravel (Tokyo Ghoul OP (Acoustic)
# 6                     Intro (Primus/Antipop)
# 7                                     Mecnun
# 8     Once in a While (feat. Sonya Kitchell)
# 9                                The Waiting
# 10  So Am I (feat. Damian Marley & Skrillex)
# 11                              O Astronauta
# 12                        The Wilhelm Scream
# 13                                 Wonderful
# 14                          Beautiful Alarms
# 15                                Cold Water
# 16                                      Lora
# 17                         Hell Breaks Loose
# 18                              Rainbow Ends
# 19                           See You In Hell
#
#                                 album_name  \
# 0                                Tu Sombra
# 1               The Family Tree: The Roots
# 2                                 Cascades
# 3                                     Echo
# 4   Dragon Soul (from "Dragon Ball Z Kai")
# 5       Unravel (Tokyo Ghoul OP (Acoustic)
# 6                                  Antipop
# 7                                  Sahiden
# 8                            Seven Bridges
# 9                              Fading Love
# 10                           Beach House 3
# 11                  Baden Powell À Vontade
# 12                             James Blake
# 13                             Live & Grow
# 14                           Vessel States
# 15                                   Grace
# 16                                    Lora
# 17                         Relapse: Refill
# 18                            Rainbow Ends
# 19                        Life After Death
#
#                                album_uri                      artist_name  \
# 0   spotify:album:2d7tfROtI0Sdsy2TYJMDpe                           Pesado
# 1   spotify:album:7sU8zin3JDka5r87BGKpo4                     Radical Face
# 2   spotify:album:63DzFVIYUZgy24E8GRIuQS                       High Highs
# 3   spotify:album:1lsBEh2R9B39hWfEo4iZSW  Tom Petty and the Heartbreakers
# 4   spotify:album:5pSvoIvSEFl8DB4sWS3pFe                NateWantsToBattle
# 5   spotify:album:7zp3GuHlCnMhwNZj9SDLAP                        Theishter
# 6   spotify:album:23gj6qqto5Y2yYcocJPkmB                           Primus
# 7   spotify:album:5X8RxGuAlwaNQg0g4FZw9K                            Buray
# 8   spotify:album:76HffpRQ7URIZGkUo4eDWt                    Break Science
# 9   spotify:album:1v6BipCE7YBMOBcAN0j0EH                George FitzGerald
# 10  spotify:album:7Dj0aaKI4RpehMPqOu56mW                    Ty Dolla $ign
# 11  spotify:album:5fc0pBKm05YQpaeZj5T232                     Baden Powell
# 12  spotify:album:0qY6lBQSi8IMJjHYDPdAqX                      James Blake
# 13  spotify:album:4YsS6HUCoyntWFTReZD1GU                    Casey Veggies
# 14  spotify:album:7qMfwer7v8DEoaxP2nCE0N                       Wilderness
# 15  spotify:album:1DDUNZPxUgt4e0sGMSfgG1                     Grace Grundy
# 16  spotify:album:7ERC0cVpUV0VDojcJN95JA                             Coma
# 17  spotify:album:7MZzYkbHL9Tk3O6WeD4Z0Z                           Eminem
# 18  spotify:album:25L6dfCmxv7ZcFolxwnmmp                     Emitt Rhodes
# 19  spotify:album:2FrvcZBhuDvVwWrI5s7wp6                    The Creepshow
#
#                                artist_uri  duration_ms  appears_in_count  \
# 0   spotify:artist:4BwiodzEp9Hwes5HeFjMVK       216893                11
# 1   spotify:artist:5EM6xJN2QNk0cL7EEm9HR9       284200                 6
# 2   spotify:artist:1cXVTtkpqSXVhyD32f9MS4       242440                 3
# 3   spotify:artist:4tX2TplrkIP4v05BNC903e       248933                 1
# 4   spotify:artist:0Vb15td3iKkAzdGD5Sj9Ky        99259                 4
# 5   spotify:artist:2Hqn367geFndjn7SaFNn49       262622                 3
# 6   spotify:artist:64mPnRMMeudAet0E62ypkx        17053                 1
# 7   spotify:artist:1qZ684TB9E1BjH58btdtYd       200272                 1
# 8   spotify:artist:1O9rhv6tMHchfb6Qx2yd6O       193411                21
# 9   spotify:artist:3KOHpygRuo1ruQAbEneR3t       268268                 2
# 10  spotify:artist:7c0XG5cIJTrrAgEC3ULPiq       225953               102
# 11  spotify:artist:0VSgciOd32tP2Yna1w4vDr       148853                 1
# 12  spotify:artist:53KwLdlmrlCelAZMaLVZqU       273840               111
# 13  spotify:artist:0uFc6StTmJBvdHPZFDkdJy       236000                59
# 14  spotify:artist:52BLvwP4JWBFLzc9TytOFt       297840                 2
# 15  spotify:artist:3pFPBG84k5bQVbL9apf2PD       151953                 1
# 16  spotify:artist:5t9SPy7c5n665XZCoAuR52       307349                 3
# 17  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR       244160                12
# 18  spotify:artist:1yap1SgRPMxgyfrrDlQ95y       199080                 1
# 19  spotify:artist:7rHGFWPlIoy2qOWBDLAWNt       205280                 1
#
#     popularity
# 0           11
# 1            6
# 2            3
# 3            1
# 4            4
# 5            3
# 6            1
# 7            1
# 8           21
# 9            2
# 10         102
# 11           1
# 12         111
# 13          59
# 14           2
# 15           1
# 16           3
# 17          12
# 18           1
# 19           1
# ['spotify:track:2z2HMfMK1vR4BZLL6JIWgV',
#  'spotify:track:2oA6tAT5u3cc8ND5crtH0k',
#  'spotify:track:5Am1Vy5vnBnu7pbTJUBzlc',
#  'spotify:track:6xlw9Qx9VDEvTdxOT98wFd',
#  'spotify:track:6I2fP8K1GbElogsAekOQfd',
#  'spotify:track:0Hap9hOcxX0ywu8q9FkcQO',
#  'spotify:track:4qpBYiY4YeTRN2D4Iv3tcF',
#  'spotify:track:4K84p5DmcoUm3pp64qzkHY',
#  'spotify:track:78U6lqeWK6Uie4jneibj9o',
#  'spotify:track:79MZL2xQVtxULJIOqrJ4lA',
#  'spotify:track:7cQnIhLin7koR2sO2bt2KS',
#  'spotify:track:4nBW45Y4EVoaeggnS2r2Xp',
#  'spotify:track:688DZF6e1MH5Uf409dwaHm',
#  'spotify:track:1EmE0i81dj6zuqqDdY4B0o',
#  'spotify:track:6tkFPLPrY97itA4Hbpa3Dp',
#  'spotify:track:6HsKzNUXenFnXhpEteenK8',
#  'spotify:track:3t708maRP7qBBuvRmNbWxS',
#  'spotify:track:0FXfAepEmqVCMnvOpb8Hoj',
#  'spotify:track:5aIVRSOeadwiwvkssC2aut',
#  'spotify:track:1LdBSURpSKoZAzdLj9FrlH']
# ['Te quiero, te amo',
#  'Black Eyes',
#  'Fastnet',
#  'BillyThe Kid',
#  'Dragon Soul (From "Dragon Ball Z Kai")',
#  'Unravel (Tokyo Ghoul OP (Acoustic)',
#  'Intro (Primus/Antipop)',
#  'Mecnun',
#  'Once in a While (feat. Sonya Kitchell)',
#  'The Waiting',
#  'So Am I (feat. Damian Marley & Skrillex)',
#  'O Astronauta',
#  'The Wilhelm Scream',
#  'Wonderful',
#  'Beautiful Alarms',
#  'Cold Water',
#  'Lora',
#  'Hell Breaks Loose',
#  'Rainbow Ends',
#  'See You In Hell']
# ['Pesado',
#  'Radical Face',
#  'High Highs',
#  'Tom Petty and the Heartbreakers',
#  'NateWantsToBattle',
#  'Theishter',
#  'Primus',
#  'Buray',
#  'Break Science',
#  'George FitzGerald',
#  'Ty Dolla $ign',
#  'Baden Powell',
#  'James Blake',
#  'Casey Veggies',
#  'Wilderness',
#  'Grace Grundy',
#  'Coma',
#  'Eminem',
#  'Emitt Rhodes',
#  'The Creepshow']

# %%
baseline_1a_songs = baseline_models.recommend_tracks_by_artists(10, input_track_uris=track_uris, popularity=False)
display([get_track_feature(uri) for uri in baseline_1a_songs])
display([get_track_feature(uri, 'artist_name') for uri in baseline_1a_songs])
# Out:
# ['Shepherd in Sheeps Clothing',
#  'Tú como si nada',
#  'Les Dilettantes - Roosevelt Mix',
#  'Desperation',
#  'U.S. 41',
#  'With My Face On The Floor',
#  'Love = Hate, Ulterior Motives',
#  'Sora Ni Utaeba',
#  'Ken Kaniff - Skit',
#  'Yuri!!! on ICE Original Soundtrack - Yuri on ICE']
# ['Wilderness',
#  'Pesado',
#  'Coma',
#  'Eminem',
#  'Tom Petty and the Heartbreakers',
#  'Emitt Rhodes',
#  'Casey Veggies',
#  'NateWantsToBattle',
#  'Eminem',
#  'Theishter']

# %%
baseline_1b_songs = baseline_models.recommend_tracks_by_artists(10, input_track_uris=track_uris, popularity=True)
display([get_track_feature(uri) for uri in baseline_1b_songs])
display([get_track_feature(uri, 'artist_name') for uri in baseline_1b_songs])

# %% [markdown]
# ## Baseline 2 — Album

# %%
baseline_2a_songs = baseline_models.recommend_tracks_by_albums(10, input_track_uris=track_uris, popularity=False)
display([get_track_feature(uri) for uri in baseline_2a_songs])
display([get_track_feature(uri, 'album_name') for uri in baseline_2a_songs])

# %%
baseline_2b_songs = baseline_models.recommend_tracks_by_albums(10, input_track_uris=track_uris, popularity=True)
display([get_track_feature(uri) for uri in baseline_2b_songs])
display([get_track_feature(uri, 'album_name') for uri in baseline_2b_songs])

# %% [markdown]
# ## Baseline 3 — Popularity

# %%
baseline_3_songs = baseline_models.recommend_popular_tracks(10, input_track_uris=track_uris)
display([get_track_feature(uri) for uri in baseline_3_songs])
display([get_track_feature(uri, 'artist_name') for uri in baseline_3_songs])

# %%
def recommend_tracks_by_artist(num_tracks=5, input_track_uris=[], popularity=True):
        """
        Recommend tracks by the same artists as those in input_track_uris.
        If `popularity` is set to True, recommend popular songs by the same artist;
        if False, recommend random songs by the same artist.
        """
        
        recommended_track_uris = []

        # Create list of artists presented in input tracks
        input_artists = []
        for track_uri in input_track_uris:
            artist_uri = get_track_feature(track_uri, 'artist_uri')
            input_artists.append(artist_uri)

        # RECOMMENDING SONGS BY POPULARITY
        if popularity:
            # Create recommendations by randomly picking an artist
            # and finding their most popular tracks
            # that aren't already in the playlist
            while len(recommended_track_uris) < num_tracks:

                # Pick a random artist to get songs by
                this_artist = random.choice(input_artists)

                # Find this artist's top songs and save track_uris in a list
                artist_top_songs = track_df.\
                    sort_values(by='popularity', ascending=False)[track_df.artist_uri == this_artist]\
                    .reset_index()['track_uri']\
                    .to_list()

                # Loop through in order of popularity and add songs not already in playlist
                # and not already in recommendation list
                while True:
                    try_song = artist_top_songs.pop(0)
                    if try_song in input_track_uris or try_song in recommended_track_uris:
                        # If this song is already in the playlist, do nothing
                        # If there are no more songs left to try to recommend, break without appending
                        if len(artist_top_songs) == 0:
                            break
                    else:
                        # If not already in playlist, add this song to the recommendations and break
                        recommended_track_uris.append(try_song)
                        break
        
        # RECOMMENDING ARTIST SONGS RANDOMLY
        else:
            # Create recommendations by randomly picking an artist
            # and recommending a random song by them
            while len(recommended_track_uris) < num_tracks:
                print(len(recommended_track_uris))

                # Pick a random artist to get songs by
                this_artist = random.choice(input_artists)
                print(this_artist)

                # Find this artist's songs
                # If no results found, try again
                while True:
                    try:
                        artist_songs_df = track_df[track_df.artist_uri == this_artist].reset_index()
                        break
                    except Exception as e:
                        continue
                print(artist_songs_df.shape)
                
                if artist_songs_df.shape[0] == 1:
                    continue
                
                # Loop until we find a song not already in the playlist
                attempts = 0
                while True or attempts <= artist_songs_df.shape[0]:
                    try_song = artist_songs_df.sample()['track_uri'].iloc[0]
                    print(try_song)

                    if try_song in input_track_uris or try_song in recommended_track_uris:
                        # If this song is already in the playlist, do nothing.
                        attempts += 1
                        print(attempts)
                        pass
                    else:
                        # If not already in playlist, add this song to the recommendations and break
                        recommended_track_uris.append(try_song)
                        break

        # Return recommendations
        return recommended_track_uris

# %%
# test = recommend_tracks_by_artist(num_tracks=10, input_track_uris=track_uris, popularity=False)

# %%
# [get_track_feature(uri) for uri in test]

# %%
# track_df.reset_index().sample()['track_uri'].iloc[0]
